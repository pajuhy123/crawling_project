# %%
# parser.py
import time
import logging
import requests
from bs4 import BeautifulSoup
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "mydjango.settings.prod_aws_eb")
import django
django.setup()

###########
from blog.models import CrawlingData
###########
#data = requests.get("url")  
#print(data.encoding) // 키 값 알아내는 법,,//키==싸이트의 인코딩 방식
encoding_map = {'437': 'cp437',
 '646': 'ascii',
 '850': 'cp850',
 '852': 'cp852',
 '855': 'cp855',
 '857': 'cp857',
 '860': 'cp860',
 '861': 'cp861',
 '862': 'cp862',
 '863': 'cp863',
 '865': 'cp865',
 '866': 'cp866',
 '869': 'cp869',
 '8859': 'latin_1',
 '932': 'cp932',
 '936': 'gbk',
 '949': 'cp949',
 '950': 'cp950',
 'CP-GR': 'cp869',
 'CP-IS': 'cp861',
 'EBCDIC-CP-BE': 'cp500',
 'EBCDIC-CP-CH': 'cp500',
 'EBCDIC-CP-HE': 'cp424',
 'IBM037': 'cp037',
 'IBM039': 'cp037',
 'IBM424': 'cp424',
 'IBM437': 'cp437',
 'IBM500': 'cp500',
 'IBM775': 'cp775',
 'IBM850': 'cp850',
 'IBM852': 'cp852',
 'IBM855': 'cp855',
 'IBM857': 'cp857',
 'IBM860': 'cp860',
 'IBM861': 'cp861',
 'IBM862': 'cp862',
 'IBM863': 'cp863',
 'IBM864': 'cp864',
 'IBM865': 'cp865',
 'IBM866': 'cp866',
 'IBM869': 'cp869',
 'L1': 'latin_1',
 'L2': 'iso8859_2',
 'L3': 'iso8859_3',
 'L4': 'iso8859_4',
 'L5': 'iso8859_9',
 'L6': 'iso8859_10',
 'L8': 'iso8859_14',
 'U16': 'utf_16',
 'U7': 'utf_7',
 'U8': 'utf_8',
 'UTF': 'utf_8',
 'UTF-16BE': 'utf_16_be',
 'UTF-16LE': 'utf_16_le',
 'arabic': 'iso8859_6',
 'big5-hkscs': 'big5hkscs',
 'big5-tw': 'big5',
 'chinese': 'gb2312',
 'cp1361': 'johab',
 'cp154': 'ptcp154',
 'cp819': 'latin_1',
 'cp936': 'gbk',
 'csbig5': 'big5',
 'csiso2022jp': 'iso2022_jp',
 'csiso2022kr': 'iso2022_kr',
 'csiso58gb231280': 'gb2312',
 'csptcp154': 'ptcp154',
 'csshiftjis': 'shift_jis',
 'cyrillic': 'iso8859_5',
 'cyrillic-asian': 'ptcp154',
 'euc-cn': 'gb2312',
 'euccn': 'gb2312',
 'eucgb2312-cn': 'gb2312',
 'eucjis2004': 'euc_jis_2004',
 'eucjisx0213': 'euc_jisx0213',
 'eucjp': 'euc_jp',
 'euckr': 'euc_kr',
 'gb18030-2000': 'gb18030',
 'gb2312-1980': 'gb2312',
 'gb2312-80': 'gb2312',
 'greek': 'iso8859_7',
 'greek8': 'iso8859_7',
 'hebrew': 'iso8859_8',
 'hkscs': 'big5hkscs',
 'hz-gb': 'hz',
 'hz-gb-2312': 'hz',
 'hzgb': 'hz',
 'ibm1026': 'cp1026',
 'ibm1140': 'cp1140',
 'iso-2022-jp': 'iso2022_jp',
 'iso-2022-jp-1': 'iso2022_jp_1',
 'iso-2022-jp-2': 'iso2022_jp_2',
 'iso-2022-jp-2004': 'iso2022_jp_2004',
 'iso-2022-jp-3': 'iso2022_jp_3',
 'iso-2022-jp-ext': 'iso2022_jp_ext',
 'iso-2022-kr': 'iso2022_kr',
 'iso-8859-1': 'latin_1',
 'iso-8859-10': 'iso8859_10',
 'iso-8859-13': 'iso8859_13',
 'iso-8859-14': 'iso8859_14',
 'iso-8859-15': 'iso8859_15',
 'iso-8859-2': 'iso8859_2',
 'iso-8859-3': 'iso8859_3',
 'iso-8859-4': 'iso8859_4',
 'iso-8859-5': 'iso8859_5',
 'iso-8859-6': 'iso8859_6',
 'iso-8859-7': 'iso8859_7',
 'iso-8859-8': 'iso8859_8',
 'iso-8859-9': 'iso8859_9',
 'iso-ir-58': 'gb2312',
 'iso2022jp': 'iso2022_jp',
 'iso2022jp-1': 'iso2022_jp_1',
 'iso2022jp-2': 'iso2022_jp_2',
 'iso2022jp-2004': 'iso2022_jp_2004',
 'iso2022jp-3': 'iso2022_jp_3',
 'iso2022jp-ext': 'iso2022_jp_ext',
 'iso2022kr': 'iso2022_kr',
 'iso8859-1': 'latin_1',
 'jisx0213': 'euc_jis_2004',
 'korean': 'euc_kr',
 'ks_c-5601': 'euc_kr',
 'ks_c-5601-1987': 'euc_kr',
 'ks_x-1001': 'euc_kr',
 'ksc5601': 'euc_kr',
 'ksx1001': 'euc_kr',
 'latin': 'latin_1',
 'latin1': 'latin_1',
 'latin2': 'iso8859_2',
 'latin3': 'iso8859_3',
 'latin4': 'iso8859_4',
 'latin5': 'iso8859_9',
 'latin6': 'iso8859_10',
 'latin8': 'iso8859_14',
 'maccentraleurope': 'mac_latin2',
 'maccyrillic': 'mac_cyrillic',
 'macgreek': 'mac_greek',
 'maciceland': 'mac_iceland',
 'maclatin2': 'mac_latin2',
 'macroman': 'mac_roman',
 'macturkish': 'mac_turkish',
 'ms-kanji': 'cp932',
 'ms1361': 'johab',
 'ms932': 'cp932',
 'ms936': 'gbk',
 'ms949': 'cp949',
 'ms950': 'cp950',
 'mskanji': 'cp932',
 'pt154': 'ptcp154',
 's_jis': 'shift_jis',
 's_jisx0213': 'shift_jisx0213',
 'shiftjis': 'shift_jis',
 'shiftjis2004': 'shift_jis_2004',
 'shiftjisx0213': 'shift_jisx0213',
 'sjis': 'shift_jis',
 'sjis2004': 'shift_jis_2004',
 'sjis_2004': 'shift_jis_2004',
 'sjisx0213': 'shift_jisx0213',
 'u-jis': 'euc_jp',
 'uhc': 'cp949',
 'ujis': 'euc_jp',
 'us-ascii': 'ascii',
 'utf16': 'utf_16',
 'utf8': 'utf_8',
 'windows-1250': 'cp1250',
 'windows-1251': 'cp1251',
 'windows-1252': 'cp1252',
 'windows-1253': 'cp1253',
 'windows-1254': 'cp1254',
 'windows-1255': 'cp1255',
 'windows-1257': 'cp1257',
 'windows-1258': 'cp1258',
 'windows1256': 'cp1256',

}

def delete():
    a=CrawlingData.objects.all()
    a.delete()

def parse():
    ## 설정
    data={
               0 : { },#instiz
               1  : { },#clien
               2 :  { },#fmkorea
               3 : { },#ou
               4 : { },#pan
               5 : { }, #slr
               6 : { }, #mlb
               7 : { },#inben
               8 : { },#ruri
               9 : { },#utde
              10 : { },#bobe
               11 : { },#ygosu
               12 : { },#drip
               13 : { },#theqoo
               14 : { },#dogge
               15 : { }, #namsung
               16 : { }, #flash1
               17 : { }, #flash2
               18 : { }, #dream1
               19 : { }, #dream2
               20 : { }, #bobe2
               21 : { },#fomos1
               22 : { },#fomos2
               23 : { },#ilbe
    }
    #instiz
    req = requests.get('http://www.instiz.net/bbs/list.php?id=pt&srd=1&srt=3&k=&stype=&stype2=&stype3=').text
    soup_instiz = BeautifulSoup(req, 'html.parser')
    #clien
    req = requests.get('https://www.clien.net/service/group/board_all?od=T33').text
    soup_clien = BeautifulSoup(req, 'html.parser')
    #fmkorea
    req = requests.get('http://www.fmkorea.com/index.php?mid=best&listStyle=list&page=1').text
    soup_fmkorea = BeautifulSoup(req, 'html.parser')
    #ou
    req = requests.get('http://www.todayhumor.co.kr/board/list.php?table=bestofbest').text
    soup_ou = BeautifulSoup(req, 'html.parser')
    #pan
    req = requests.get('http://pann.nate.com/talk/ranking').text
    soup_pan = BeautifulSoup(req, 'html.parser')
    #slr
    req = requests.get('http://www.slrclub.com/bbs/zboard.php?id=best_article&category=1&setsearch=category').text
    soup_slr = BeautifulSoup(req, 'html.parser')
    #mlb
    req = requests.get('http://mlbpark.donga.com/mp/best.php?b=bullpen&m=view').text
    soup_mlb = BeautifulSoup(req, 'html.parser')
    #inben
    req = requests.get('http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&query=list&my=chu&category=%EC%9C%A0%EB%A8%B8&sort=PID&name=&subject=&content=&keyword=&orderby=&iskin=webzine').text
    soup_inben = BeautifulSoup(req, 'html.parser')
    #ruri
    req = requests.get('http://bbs.ruliweb.com/best/selection').text
    soup_ruri = BeautifulSoup(req, 'html.parser')
    #utde
    req = requests.get('http://web.humoruniv.com/board/humor/list.html?table=pds&st=day').text.encode(encoding_map['iso-8859-1'])
    soup_utde = BeautifulSoup(req, 'html.parser')
    #bobe
    req = requests.get('http://www.bobaedream.co.kr/list?code=best').text.encode(encoding_map['iso-8859-1'])
    soup_bobe = BeautifulSoup(req, 'html.parser')
    #ygosu
    req = requests.get('http://www.ygosu.com/community/real_article').text
    soup_ygosu = BeautifulSoup(req, 'html.parser')
    #drip
    req = requests.get('http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc').text
    soup_drip = BeautifulSoup(req, 'html.parser')
    #theqoo
    req = requests.get('http://theqoo.net/tbest?filter_mode=normal').text
    soup_theqoo = BeautifulSoup(req, 'html.parser')
    #dogge
    req = requests.get('http://dkbnews.donga.com/Board?p=1&tcode=bbs_dkbnews&s=date&key=&query=').text
    soup_dogge = BeautifulSoup(req, 'html.parser')
    #namsung
    req1= requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=ggolit').text
    soup_namsung1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=celeb').text
    soup_namsung2 = BeautifulSoup(req2, 'html.parser')
    #flash1
    req1= requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=star&page=2&page=1').text.encode(encoding_map['iso-8859-1'])
    soup_flash1 = BeautifulSoup(req1, 'html.parser')
    #flash2
    req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
    soup_flash2 = BeautifulSoup(req2, 'html.parser')
    #dream1
    req1= requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_star&is_image=Y').text
    soup_dream1 = BeautifulSoup(req1, 'html.parser')
    #dream2
    req2 = requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_humor&is_image=Y').text
    soup_dream2 = BeautifulSoup(req2, 'html.parser')
    #bobe2
    req1= requests.get('http://www.bobaedream.co.kr/list?code=girl&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=Subject&s_key=&level_no=&vdate=&type=list&page=1')
    req1 =req1.text.encode(encoding_map['iso-8859-1'])
    soup_bobe2 = BeautifulSoup(req1, 'html.parser')
    #fomos1
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=5').text
    soup_fomos1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=6').text
    soup_fomos2 = BeautifulSoup(req2, 'html.parser')
    #fomos2
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=3').text
    soup_fomos3 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=4').text
    soup_fomos4 = BeautifulSoup(req2, 'html.parser')
    #ilbe
    req1= requests.get('http://www.ilbe.com/ilbe').text
    soup_ilbe = BeautifulSoup(req1, 'html.parser')

    
    ## json에 저장
    #instiz
    for title in soup_instiz.select('#subject a'): 
                    a = title.get('href')
                    b=a.replace(".." , "instiz.net")
                    data[0][title.text] = b
    #clien
    n=0
    for title in soup_clien.select('.list-title .list-subject'): 
        if n == 0:
            n+=1
            continue
        else:
            a = title.get('href')
            if not a==None:
                    a='clien.net' + a
                    str=" ".join(title.text.strip().split())
                    data[1][str] = a
    #fmkorea
    for title in soup_fmkorea.select('.hx'): 
                    a = title.get('href')
                    data[2][title.text.strip()] = a
    #ou
    for title in soup_ou.select('.subject a'): 
                    a = title.get('href')
                    a='todayhumor.co.kr' + a
                    data[3][title.text] = a
    #pan
    for title in soup_pan.select('dt a'): 
                    a = title.get('href')
                    data[4][title.text] = a
    #slr
    for title in soup_slr.select('.sbj a'): 
                    a = title.get('href')
                    a='slrclub.com'+a
                    data[5][title.text] = a
    #mlb
    for title in soup_mlb.select('.t_left a'): 
                    a = title.get('href')
                    data[6][title.text] = a
    #inben
    for title in soup_inben.select('a.sj_ln'): 
                    a = title.get('href')
                    data[7][title.text] = a
    #ruri
    for title in soup_ruri.select('.subject a'): 
                    a = title.get('href')
                    data[8][title.text] = a
     #utde
    for title in soup_utde.select('a.brn3, a.brn2, a.brn1'): 
                    a = title.get('href')
                    a='web.humoruniv.com/board/humor/'+a
                    str=" ".join(title.text.strip().split())
                    data[9][str] = a
    #bobe
    for title in soup_bobe.select('a.bsubject'): 
                    a = title.get('href')
                    a='bobaedream.co.kr'+a
                    data[10][title.text] = a
    #ygosu
    for title in soup_ygosu.select('.tit a'): 
                    a = title.get('href')
                    data[11][title.text] = a
     #drip
    n=0
    for title in soup_drip.select('td.title a'): 
                if n == 0:
                      n+=1
                      continue
                else:
                     a = title.get('href')
                     data[12][title.text.strip()] = a
    #theqoo
    j=0 
    n=1
    x=1
    m=2
    for title in soup_theqoo.select('td.title a'): 
            if j < 8 :
                     j+=1
                     continue
            else:
                    if  n == m:
                            a=title.get('href')
                            a='theqoo.net'+a.replace('_comment','') 
                            n+=1
                            x+=1
                            m=2*x
                            data[13][title.text] = a
                            continue
                    else:
                            n+=1
                            continue
    #dogge
    for title in soup_dogge.select('.txt a'): 
                    a = title.get('href')
                    a ='http://dkbnews.donga.com/Board'+a
                    data[14][title.text.strip()] = a
    #namsung
    n=0
    for title in soup_namsung1.select('.list-subject a'): 
                    if n < 10:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                    else:
                          break                   
    for title in soup_namsung2.select('.list-subject a'): 
                     if n < 19:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                     else:
                          break
    #flash1
    n=0
    for title in soup_flash1.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[16][title.text]=a
     #flash2
    n=0
    for title in soup_flash2.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[17][title.text]=a
    #dream1
    n=1
    x=1
    m=2
    for title in soup_dream1.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[18][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #dream2
    n=1
    x=1
    m=2
    for title in soup_dream2.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[19][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #bobe2
    for title in soup_bobe2.select('.pl14 a.bsubject'): 
                    a=title.get('href')
                    a='bobaedream.co.kr'+a
                    data[20][title.text.strip()]=a
    #fomos1
    n=0
    for title in soup_fomos1.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos2.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    #fomos2
    n=0
    for title in soup_fomos3.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos4.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
     #ilbe
    n=0
    for title in soup_ilbe.select('.title a'): 
                    if n == 0:
                            n+=1
                            continue
                    else:
                            a=title.get('href')
                            data[23][title.text.strip()]=a


     #한꺼번에 DB 에  insert 하기 위한 함수
    
    def allsave(x):
            crawling = CrawlingData()
            list = [
                       [crawling.instiz, crawling.link_instiz], [crawling.clien, crawling.link_clien], [crawling.fmkorea, crawling.link_fmkorea],
                       [crawling.ou, crawling.link_ou] ,[crawling.pan, crawling.link_pan],[crawling.slr, crawling.link_slr],[crawling.mlb, crawling.link_mlb],
                       [crawling.inben, crawling.link_inben],[crawling.ruri, crawling.link_ruri],[crawling.utde, crawling.link_utde],[crawling.bobe, crawling.link_bobe],
                       [crawling.ygosu, crawling.link_ygosu],[crawling.drip, crawling.link_drip],[crawling.theqoo, crawling.link_theqoo],
                       [crawling.dogge, crawling.link_dogge],[crawling.namsung, crawling.link_namsung],[crawling.flash1, crawling.link_flash1],
                       [crawling.flash2, crawling.link_flash2],[crawling.dream1, crawling.link_dream1],[crawling.dream2, crawling.link_dream2],
                       [crawling.bobe2, crawling.link_bobe2],[crawling.fomos1, crawling.link_fomos1], [crawling.fomos2, crawling.link_fomos2],
                       [crawling.ilbe, crawling.link_ilbe]
                   ]
            for  i in range(len(data)):
                    n=0
                    for t,l in data[i].items():
                        if n == x:
                            list[i][0],list[i][1]= t,l
                            print(list[i][0],list[i][1])
                            break
                        else:
                            n+=1
                            continue
            
            CrawlingData(instiz=list[0][0],link_instiz=list[0][1], clien=list[1][0],link_clien=list[1][1], fmkorea=list[2][0],link_fmkorea=list[2][1],
                                  ou=list[3][0],link_ou=list[3][1], pan=list[4][0],link_pan=list[4][1], slr=list[5][0],link_slr=list[5][1], mlb=list[6][0],link_mlb=list[6][1],
                                  inben=list[7][0],link_inben=list[7][1], ruri=list[8][0],link_ruri=list[8][1], utde=list[9][0],link_utde=list[9][1],
                                  bobe=list[10][0],link_bobe=list[10][1], ygosu=list[11][0],link_ygosu=list[11][1], drip=list[12][0],link_drip=list[12][1],
                                  theqoo=list[13][0],link_theqoo=list[13][1], dogge=list[14][0],link_dogge=list[14][1], namsung=list[15][0],link_namsung=list[15][1],
                                  flash1=list[16][0],link_flash1=list[16][1], flash2=list[17][0],link_flash2=list[17][1], dream1=list[18][0],link_dream1=list[18][1],
                                  dream2=list[19][0],link_dream2=list[19][1], bobe2=list[20][0],link_bobe2=list[20][1], fomos1=list[21][0],link_fomos1=list[21][1],
                                  fomos2=list[22][0],link_fomos2=list[22][1], ilbe=list[23][0],link_ilbe=list[23][1],
                                    ).save() 
            
       ##DB에 저장
    for x in range(len(data[0])):
                    allsave(x)
                    print('-----------')
                    
    
while True:
    print('start parsing')
    delete()
    parse()
    print('parsing ends')
    print('sleep in 40s')
    time.sleep(60)
# Out:
# start parsing
# 실망했던 초밥집에 다시 주문을 했는데.jpg instiz.net/pt?no=4735673&page=1&srt=3&k=&srd=1
# 모공 [릴레이 29일차] 삼성은 장충기 clien.net/service/board/park/11167117?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 갓본의 생물학병기테러.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=769081243
# 안철수 "정말 해도 해도 너무합니다" todayhumor.co.kr/board/view.php?table=bestofbest&no=361329&s_no=361329&page=1
# 마산 또 사라졌네 http://pann.nate.com/talk/338682777
# 성주주민, 문재인 찍은 손가락 잘라내고 싶다. slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259964
# 서예지 졸업사진.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008425102&m=view
#  [유머] 말실수한 북한간첩 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809676
# 파트너가 실수했다면.gif http://bbs.ruliweb.com/best/board/300143/read/34671870
# 대한민국에서는 상상도 못할 교육.JPG [61] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707101
# 밀양 재조사.. bobaedream.co.kr/view?code=best&No=133221&vdate=
# 호불호  http://www.ygosu.com/community/real_article/yeobgi/1244872/?page=0&frombest=Y
# 내뒤에 사람있는줄 모르고 방구낌.ssul http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138466930
# 김연아 코스튬 네일아트.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=563089997
# 이말년의 워너원 뮤비 감상평.jpg이슈포토 http://dkbnews.donga.com/Board?no=16012&m=view&tcode=bbs_dkbnews
# 자세잡는 피규어녀  댓글 : 5 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34372
# 장신영 란제리룩 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73886&page=1
# 치어리더 실수 모음 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82484
# 다원(우주소녀),매드클라운-열린음악회live newsbbs.dreamx.com/view.do?list_id=698012&page=1&bid=cnt_star
# 흥이난  가드 ~. newsbbs.dreamx.com/view.do?list_id=698013&page=1&bid=cnt_humor
# 유라 bobaedream.co.kr/view?code=girl&No=850059&bm=1
# 티아라 지연 엉덩이 힘 ㄷㄷ(2) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258749
# 아직도 양주 사진이 잊혀지지 않는 여자아이돌(2) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258683
# 연예인들한테 환상 품는 순진한 일게이들에게 한마디 한다 http://www.ilbe.com/10010919774
# -----------
# 면접 시 성희롱 관련 질문 모범답안 instiz.net/pt?no=4735262&page=1&srt=3&k=&srd=1
# 모공 성주 시민들의 사드에 대한 진짜 불만은 이겁니다. clien.net/service/board/park/11167062?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 김영철 인생 접을뻔했던날 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=769339588
# 장애인을 위한 나라는 없다. todayhumor.co.kr/board/view.php?table=bestofbest&no=361328&s_no=361328&page=1
# 시어머니가 관심병 말기예요 http://pann.nate.com/talk/338681013
# 제가 싫지 않은사람만 댓글 달아주세요 ㄷㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259963
# 와... 몸매 죽이네요.. http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008422108&m=view
#  [유머] 동성혼 합법시 최대 수혜자 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809625
# 언행불일치 甲 http://bbs.ruliweb.com/best/board/300143/read/34671768
# 히딩크의 안정환 조련법 [81] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707105
# BBC에 소개된 ch2709 bobaedream.co.kr/view?code=best&No=133220&vdate=
# 쿰척 http://www.ygosu.com/community/real_article/animation/199415/?page=0&frombest=Y
# 천종호 판사.....소년법 반응....jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138475047
# 부산여중생사건 정유미 과거 남돌성희롱 (혐) theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=563082251
# 전설로 남은 5년전 솔로대첩ㄷㄷ.jpg이슈포토 http://dkbnews.donga.com/Board?no=16011&m=view&tcode=bbs_dkbnews
# 포복이 힘든 시노자키 아이  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34371
# 레깅스만 입고 다녀라 .. 손나은 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73885&page=1
# 피팅모델 레전드 정윤 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82483
# 머라이어 캐리, 체중 논란 이후 첫 콘서트..건재함 과… newsbbs.dreamx.com/view.do?list_id=698010&page=1&bid=cnt_star
# 과거 유재석 이효리 이상순 함께 찍은 사진 newsbbs.dreamx.com/view.do?list_id=698011&page=1&bid=cnt_humor
# 쯔위 bobaedream.co.kr/view?code=girl&No=850023&bm=1
# 남자들이 가장 설레이는 순간(7) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258747
# 김가연이 임요환을 위해 만든 야식들(12) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258713
# 사하구 여중생 가해자들 일정.schedule http://www.ilbe.com/10011268854
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8B\\xA4\\xEB\\xA7\\x9D...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAA\\xA8\\xEA\\xB3\\xB5...' for column 'clien' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB0\\x93\\xEB\\xB3\\xB8...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x88\\xEC\\xB2\\xA0...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\x88\\xEC\\x82\\xB0...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xB1\\xEC\\xA3\\xBC...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\x9C\\xEC\\x98\\x88...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9C\\xA0\\xEB\\xA8\\xB8...' for column 'inben' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9C\\xA0\\xEB\\xA8\\xB8...' for column 'link_inben' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8C\\x8C\\xED\\x8A\\xB8...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8C\\x80\\xED\\x95\\x9C...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB0\\x80\\xEC\\x96\\x91...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x98\\xB8\\xEB\\xB6\\x88...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x82\\xB4\\xEB\\x92\\xA4...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB9\\x80\\xEC\\x97\\xB0...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xB4\\xEB\\xA7\\x90...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\x90\\xEC\\x84\\xB8...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\xA5\\xEC\\x8B\\xA0...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB9\\x98\\xEC\\x96\\xB4...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8B\\xA4\\xEC\\x9B\\x90...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9D\\xA5\\xEC\\x9D\\xB4...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9C\\xA0\\xEB\\x9D\\xBC' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8B\\xB0\\xEC\\x95\\x84...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xEC\\xA7\\x81...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x97\\xB0\\xEC\\x98\\x88...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA9\\xB4\\xEC\\xA0\\x91...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB9\\x80\\xEC\\x98\\x81...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\xA5\\xEC\\x95\\xA0...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8B\\x9C\\xEC\\x96\\xB4...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x9C\\xEA\\xB0\\x80...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x99\\x80......' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x96\\xB8\\xED\\x96\\x89...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9E\\x88\\xEB\\x94\\xA9...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x97\\x90 \\xEC\\x86...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xBF\\xB0\\xEC\\xB2\\x99' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB2\\x9C\\xEC\\xA2\\x85...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB6\\x80\\xEC\\x82\\xB0...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x84\\xEC\\x84\\xA4...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8F\\xAC\\xEB\\xB3\\xB5...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA0\\x88\\xEA\\xB9\\x85...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x94\\xBC\\xED\\x8C\\x85...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA8\\xB8\\xEB\\x9D\\xBC...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB3\\xBC\\xEA\\xB1\\xB0...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xAF\\x94\\xEC\\x9C\\x84' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x82\\xA8\\xEC\\x9E\\x90...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB9\\x80\\xEA\\xB0\\x80...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x82\\xAC\\xED\\x95\\x98...' for column 'ilbe' at row 1")
#   result = self._query(query)
# -----------
# [공식입장] 방탄소년단 측 "우리는 공갈협박 피해자, 부적절 마케팅 없었다" instiz.net/pt?no=4736012&page=1&srt=3&k=&srd=1
# 모공 상담실을 습격한 100명의 학생들.jpg clien.net/service/board/park/11167904?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 의사가 담배 피는 이유.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=769087203
# 와 우리 까미 발목 날아갈뻔.. ㄷ ㄷ todayhumor.co.kr/board/view.php?table=bestofbest&no=361327&s_no=361327&page=1
# 친구들끼리 차수리비 준걸 지가쓰는 친구 http://pann.nate.com/talk/338680374
# 현직 자산 300억인데 차 뭐 타야 하나요 ㄷㄷㄷㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259962
# 부산 운전이 엄청나긴 한가보네요 ㄷㄷ.gif http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008422003&m=view
#  [유머] 창의력 돋는 그림들 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809623
# 폭행 사태를 키운 경찰 http://bbs.ruliweb.com/best/board/300143/read/34671607
# 네이버 지하감옥 [44] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707177
# 설문조사함 해보겠습니다... bobaedream.co.kr/view?code=best&No=133216&vdate=
# 신규레전드팩 떴냐????????????????????????  http://www.ygosu.com/community/real_article/ffonline2/64841/?page=0&frombest=Y
# 아이유병 걸린 언니... http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138475149
# [단독] “방탄소년단 ‘편법마케팅’ 폭로하겠다” 돈 뜯은 협박범 실형 선고 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562785563
# 보노보노ppt가 생각나는 콘서트 포스터.jpg이슈포토 http://dkbnews.donga.com/Board?no=16010&m=view&tcode=bbs_dkbnews
# 바람직한 드레스  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34366
# 강민경 노래방 갈때 입는 복장 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73884&page=1
# 보이는 라디오 글래머 DJ flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82482
# 꽃아린 ~ newsbbs.dreamx.com/view.do?list_id=698009&page=1&bid=cnt_star
# 괜히  설렘. newsbbs.dreamx.com/view.do?list_id=698008&page=1&bid=cnt_humor
# 모모 bobaedream.co.kr/view?code=girl&No=850075&bm=1
# 속바지 노출해주는 센스 (3) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258748
# 한국드라마 현실고증류 ㄷㄷㄷ www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258723
# 남자들이 예쁜 여자 좋아하는 것 보다 여자들이 잘생긴 남자 좋아하는 정도가... http://www.ilbe.com/10010932536
# -----------
# [단독] "언니들 약 먹어요"..폭행 여중생 '충동조절장애'로 선처 받아 instiz.net/pt?no=4737173&page=1&srt=3&k=&srd=1
# 모공 대한민국에서는 상상도 못할 교육.JPG clien.net/service/board/park/11166984?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 신태용 짜르고 히딩크 데려오자는 사람들 특징.txt http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=769251216
# ‘전세버스 5대 200명’… 자유한국당 9일 장외집회 ‘동원’ 지시 todayhumor.co.kr/board/view.php?table=bestofbest&no=361326&s_no=361326&page=1
# 추석 마지막날 시고모님들 오니까 시댁가자는 남편 (... http://pann.nate.com/talk/338681914
# 경상도 버프인가요??사투린줄 오해..ㄷ ㄷ ㄷ  slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259961
# 회사 동료 여자생각하며 딸 칠때 있습니까? http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008421514&m=view
#  [유머] 형에 대한 존경심이 필요하다는 정준하 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809587
# 소니 트위터의 흔한 데스티니 광고 http://bbs.ruliweb.com/best/board/300143/read/34671597
# 이국주가 나혼자산다에서 하차한이유 [35] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707064
# 사람을 애타게 찾고 있습니다 도와주세요 bobaedream.co.kr/view?code=best&No=133215&vdate=
# 임시완 비주얼 피크 찍었던날 .jpg ㄷㄷㄷㄷㄷ  http://www.ygosu.com/community/real_article/yeobgi/1244831/?page=0&frombest=Y
# (대용량)국대에서 기성용이 손흥민에게 준 패스들 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138466284
# 비정상회담 왕심린 때문에 현재 대만 인터넷 난리.. theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562758987
# [주번나] 아이는 사랑입니다.jpg이슈포토 http://dkbnews.donga.com/Board?no=16009&m=view&tcode=bbs_dkbnews
# 겸손한 조이 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34364
# 하연주 실제 우유저장소 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73883&page=1
# 브라질女 흔한 궁뎅이 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82481
# 러블리즈 블랙미주 newsbbs.dreamx.com/view.do?list_id=698007&page=1&bid=cnt_star
# 맥주 한잔 ~. newsbbs.dreamx.com/view.do?list_id=698006&page=1&bid=cnt_humor
# 하연주 bobaedream.co.kr/view?code=girl&No=850074&bm=1
# 아이돌학교 폭격기 甲 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258707
# 농사 짓는 신혼부부 ㄷㄷㄷ(10) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258712
# 30대 스시녀들의 고민.japannews http://www.ilbe.com/10011684658
# -----------
# 근데 예쁘게 생기지는 않았어요 instiz.net/pt?no=4736917&page=1&srt=3&k=&srd=1
# 모공 "시계는 국민세금" 이정도 총무비서관 clien.net/service/board/park/11168242?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# KBS 파업으로 인한 이번주 KBS K리그 중계진 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=769202566
# 더민주 지지율 50%의 이유 todayhumor.co.kr/board/view.php?table=bestofbest&no=361325&s_no=361325&page=1
# 제 새차를 남친이 D기어에 놓고 내려서 사고가 났는데요 http://pann.nate.com/talk/338679841
# 람보르기니 평균속도 70km 라면 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259960
# 회식간다고 삐진 여친.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008424268&m=view
#  [유머] (일기) 오이갤러가 번호물어본썰 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809576
# 오징어 술잔 http://bbs.ruliweb.com/best/board/300143/read/34671522
# 강원대 강간범 소문 이후 [41] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707098
# Ch2709  현재상황 bobaedream.co.kr/view?code=best&No=133213&vdate=
# ㅋㅋㅋㅋㅋ히딩크 촛불시위 http://www.ygosu.com/community/real_article/soccer/223742/?page=0&frombest=Y
# 내가 드라마를 거르는 기준.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138456488
# 회식가지 말라는 여자친구 카톡 추가버전ㅋㅋㅋㅋㅋ.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562752040
# 정체를 알 수 없는 엄마의 카톡.jpg이슈포토 http://dkbnews.donga.com/Board?no=16008&m=view&tcode=bbs_dkbnews
# 엉덩이가 좋은 배우  댓글 : 3 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34362
# 아이린 비 맞는 허벅지 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73882&page=1
# 피지컬 쩌는 처자들 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82480
# 미시 느낌 나는 조이 newsbbs.dreamx.com/view.do?list_id=698004&page=1&bid=cnt_star
# 이상과 현실 newsbbs.dreamx.com/view.do?list_id=698003&page=1&bid=cnt_humor
# 민아 bobaedream.co.kr/view?code=girl&No=850057&bm=1
# 운전 집중하게 만드는 조수석 매너 복장 (3) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258746
# [더 지니어스] 최정문이 갓갓인 이유 www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258740
# 맘충 때문에 빡친 포르쉐 딜러의 하소연.. http://www.ilbe.com/10011728224
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB3\\xB5\\xEC\\x8B\\x9D...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\x98\\xEC\\x82\\xAC...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x99\\x80 \\xEC\\x9A...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB9\\x9C\\xEA\\xB5\\xAC...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x98\\x84\\xEC\\xA7\\x81...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB6\\x80\\xEC\\x82\\xB0...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8F\\xAD\\xED\\x96\\x89...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x84\\xA4\\xEC\\x9D\\xB4...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xA4\\xEB\\xAC\\xB8...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8B\\xA0\\xEA\\xB7\\x9C...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xEC\\x9D\\xB4...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8B\\xA8\\xEB\\x8F\\x85...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB3\\xB4\\xEB\\x85\\xB8...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB0\\x94\\xEB\\x9E\\x8C...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB0\\x95\\xEB\\xAF\\xBC...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB3\\xB4\\xEC\\x9D\\xB4...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xBD\\x83\\xEC\\x95\\x84...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB4\\x9C\\xED\\x9E\\x88...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAA\\xA8\\xEB\\xAA\\xA8' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x86\\x8D\\xEB\\xB0\\x94...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x95\\x9C\\xEA\\xB5\\xAD...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x82\\xA8\\xEC\\x9E\\x90...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8B\\xA8\\xEB\\x8F\\x85...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8B\\xA0\\xED\\x83\\x9C...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x84\\xEC\\x84\\xB8...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB6\\x94\\xEC\\x84\\x9D...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB2\\xBD\\xEC\\x83\\x81...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9A\\x8C\\xEC\\x82\\xAC...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x86\\x8C\\xEB\\x8B\\x88...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xB4\\xEA\\xB5\\xAD...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x82\\xAC\\xEB\\x9E\\x8C...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\x84\\xEC\\x8B\\x9C...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8C\\x80\\xEC\\x9A\\xA9...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB9\\x84\\xEC\\xA0\\x95...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA3\\xBC\\xEB\\xB2\\x88...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB2\\xB8\\xEC\\x86\\x90...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x95\\x98\\xEC\\x97\\xB0...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB8\\x8C\\xEB\\x9D\\xBC...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x9F\\xAC\\xEB\\xB8\\x94...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\xA5\\xEC\\xA3\\xBC...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x95\\x98\\xEC\\x97\\xB0...' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xEC\\x9D\\xB4...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x86\\x8D\\xEC\\x82\\xAC...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8C\\x80 \\xEC\\x8A...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB7\\xBC\\xEB\\x8D\\xB0...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8C\\x8C\\xEC\\x97\\x85...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8D\\x94\\xEB\\xAF\\xBC...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x9C \\xEC\\x83...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x9E\\x8C\\xEB\\xB3\\xB4...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9A\\x8C\\xEC\\x8B\\x9D...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x98\\xA4\\xEC\\xA7\\x95...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB0\\x95\\xEC\\x9B\\x90...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x98\\x84\\xEC\\x9E\\xAC...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xE3\\x85\\x8B\\xE3\\x85\\x8B...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x82\\xB4\\xEA\\xB0\\x80...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9A\\x8C\\xEC\\x8B\\x9D...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x95\\xEC\\xB2\\xB4...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x97\\x89\\xEB\\x8D\\xA9...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xEC\\x9D\\xB4...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x94\\xBC\\xEC\\xA7\\x80...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAF\\xB8\\xEC\\x8B\\x9C...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xB4\\xEC\\x83\\x81...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAF\\xBC\\xEC\\x95\\x84' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9A\\xB4\\xEC\\xA0\\x84...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8D\\x94 \\xEC\\xA7...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\x98\\xEC\\xB6\\xA9...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9C\\xA0\\xED\\x82\\xA4...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8D\\xB0\\xEC\\x9D\\xB4...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9A\\xB0\\xEB\\xA6\\xAC...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xBC\\xAD \\xEB\\x8B...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9A\\x94\\xEA\\xB1\\xB0...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x97\\xB9\\xEA\\xB0\\x80...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\x88\\xED\\x8A\\xB8...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA7\\xB1\\xEA\\xB5\\xAC...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x9E\\xEC\\x9C\\xBC...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB9\\x80\\xEA\\xB0\\x80...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9B\\x84\\xEB\\xB0\\xA9...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x97\\xAC\\xEB\\x8F\\x99...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB3\\xA0\\xEC\\x96\\x91...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\x98 \\xEC\\x9B...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB2\\xAD\\xEB\\x8B\\xB4...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB2\\x88\\xEA\\xB0\\x9C...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\xA5\\xEC\\x8B\\xAC...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB9\\xB4\\xEB\\xA9\\x94...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8A\\xB9\\xEC\\x97\\xB0' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8B\\xB0\\xED\\x8C\\xAC...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\x9C\\xEC\\x9E\\xA5...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xBC\\xEB\\xB2\\xA0...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB6\\x80\\xEC\\x82\\xB0...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xB8\\xEC\\x8A\\xA4...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\x91\\xEA\\xB0\\x80...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB0\\xA9\\xED\\x83\\x84...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB6\\x95\\xEA\\xB5\\xAC...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x95\\x9C\\xEA\\xB5\\xAD...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xBD\\x94\\xEB\\xAF\\xB9...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB3\\xB5\\xEA\\xB0\\x9C...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAC\\xB8\\xEC\\x9E\\xAC...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x80\\xEB\\x85\\x81...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB0\\x80\\xED\\x96\\xA5...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x97\\xB0\\xEC\\x98\\x88...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8A\\xA4\\xED\\x8A\\xB8...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA4\\x84\\xEB\\x84\\x98...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAF\\xBC\\xEC\\x95\\x84...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x82\\xA8\\xEC\\x9E\\x90...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8C\\x80\\xEC\\xA0\\x84...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA4\\x84\\xEC\\x84\\x9C...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xEC\\x9D\\xB4...' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x82\\xB4\\xEB\\x85\\x84...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xB1\\xEC\\xB0\\xA8...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x9E\\x88\\xEB\\x94\\xA9...' for column 'ilbe' at row 1")
#   result = self._query(query)
# -----------
# 유키스 기섭 측 “뮤비 촬영 중 폭발사고…2도 화상 부상” [공식입장전문] instiz.net/pt?no=4736339&page=1&srt=3&k=&srd=1
# 모공 차 밑을 떠나지 않는 고양이의 사연.jpg clien.net/service/board/park/11167093?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# (데이터/브금)아오지 축구단 - 최후의 결전[完] http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768982826
# 우리 시부모님~이야기도 해봅니다. todayhumor.co.kr/board/view.php?table=bestofbest&no=361324&s_no=361324&page=1
# 꼭 답글부탁. 결혼 후 시댁 일에 관한 생각입니다 http://pann.nate.com/talk/338679781
# MTB 요거 어떤가유? slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259958
# 헹가래 칠때 시리아 경기 안 끝났었다네요 ㄷㄷㄷㄷ.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008421727&m=view
#  [유머] what time is it now? http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809564
# 마트 폐점시간에 서성거리는 독신남녀들.jpg http://bbs.ruliweb.com/best/board/300143/read/34671505
# 짱구는 못말려 치타 의문의 인맥 [32] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707056
# 앞으로 죽을때까지 소장용 ..사진 bobaedream.co.kr/view?code=best&No=133218&vdate=
# 김가연이 임요환을 위해 만든 야식들  http://www.ygosu.com/community/real_article/yeobgi/1244842/?page=0&frombest=Y
# (후방) 보안강화를 위한 아이디, 비밀번호 설정 및 관리 꿀팁! http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138414801
# 여동생 팩트로 두들겨패버리는 친오빠.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562736984
# 고양이 괴롭히지마.jpg이슈포토 http://dkbnews.donga.com/Board?no=16007&m=view&tcode=bbs_dkbnews
# 잘 웃는 여자  댓글 : 11 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34358
# 청담동 건물주 한승연 타이트한 원피스 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73881&page=1
# 번개장터녀 초밀착 원피스! flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82479
# 맥심 최혜연 최근 비키니 대회 newsbbs.dreamx.com/view.do?list_id=698002&page=1&bid=cnt_star
# 카메라맨 레전드. newsbbs.dreamx.com/view.do?list_id=698001&page=1&bid=cnt_humor
# 승연 bobaedream.co.kr/view?code=girl&No=850072&bm=1
# 티팬티 입고나왔다가 딱 걸림.gif(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258846
# 서장훈 팩폭 ㅎㄷㄷㄷ (4) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258772
# 일베간 좆본 여자아이돌 움짤 풀버전 영상.Youtube http://www.ilbe.com/10011620429
# -----------
# 부산 여중생 가해자중 "엄마가 돈많으니 합의하면 괜찮다" 발언 instiz.net/pt?no=4736266&page=1&srt=3&k=&srd=1
# 모공 성주 저 동네 왜 저러는거죠? clien.net/service/board/park/11166932?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 인스타 얼짱녀 화민 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768689070
# 작가별 폭발음 묘사 todayhumor.co.kr/board/view.php?table=bestofbest&no=361323&s_no=361323&page=1
# 방탄 정국 컨포 역대급 고퀄!! http://pann.nate.com/talk/338679668
# 축구협회 "히딩크 언급 불쾌하고 어처구니 없다"  (有) slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259957
# 한국에서 7천만원 더받고 파는차 .jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008427715&m=view
#  [유머] [펌] 장애인 여자애랑 짝이었던 이야기 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809555
# 코믹프라자 의문의 영업방해 http://bbs.ruliweb.com/best/board/300143/read/34670386
# 공개 수치플레이.jpg [27] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=707167
# 문재인 후보시절 사드 bobaedream.co.kr/view?code=best&No=133212&vdate=
# 저녁때 먹은 돈까수  http://www.ygosu.com/community/real_article/food/27970/?page=0&frombest=Y
# 가향 담배 퇴출 추진 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138174286
# 연예인 허언증 베스트3 .JPG theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562678659
# 스트레스 안받고 평온한 직업을 찾는다면 추천.jpg이슈포토 http://dkbnews.donga.com/Board?no=16006&m=view&tcode=bbs_dkbnews
# 줄넘기하는 코스프레녀  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34357
# 민아 초미니 각선미 레전드 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73880&page=1
# 남자들이 환장하는 처자 홀복 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82478
# 대전시티즌 오하영.jpg newsbbs.dreamx.com/view.do?list_id=698000&page=1&bid=cnt_star
# 줄서서 먹는다는 토마토 라면.jpg newsbbs.dreamx.com/view.do?list_id=697999&page=1&bid=cnt_humor
# 아이린 bobaedream.co.kr/view?code=girl&No=850071&bm=1
# 내년에 32살 되는 AV배우 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258690
# ...
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAA\\xA8\\xEB\\xAA\\xA8...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\x90\\xEC\\xA0\\x84...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB0\\x93\\xEC\\x9D\\x80...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x95\\x9C\\xEA\\xB5\\xAD...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x95\\xB4\\xEC\\x9D\\xB8' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x8A\\xA4\\xED\\x83\\x80...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8E\\x98\\xEB\\xB6\\x81...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x98\\x84\\xEC\\x9E\\xAC...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA7\\x84\\xEC\\xA7\\x9C...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xEC\\x9D\\xB4...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x89\\xB4\\xEC\\x8A\\xA4...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x82\\xBC\\xEA\\xB2\\xB9...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8B\\xA8\\xEB\\x8F\\x85...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xB0\\xBD\\xEC\\x9D\\x98...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8B\\xB9\\xED\\x99\\xA9...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAC\\xB4\\xEB\\xA3\\x8C...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xBC\\xEB\\xB2\\xA0...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA4\\x91\\xEA\\xB0\\x84...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x85\\xB8\\xED\\x82\\xA4...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\x8C\\xEC\\x9A\\xB0...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB3\\xA0\\xED\\x99\\x94...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xAF\\x94\\xEC\\x9C\\x84...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9C\\xA1\\xEB\\x8D\\x95...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\x88\\xEC\\x82\\xAC...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEA\\xB9\\x8A\\xEC\\x9D\\x80...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xB8\\xEA\\xB2\\xBD...' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x95\\x84\\xED\\x94\\x84...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x94\\xBC\\xEC\\x9E\\x84...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\x8C\\x80\\xEB\\xA5\\x99...' for column 'ilbe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x97\\xAC\\xEC\\x9E\\x90...' for column 'instiz' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9D\\xBC\\xEB\\xB3\\xB8...' for column 'fmkorea' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAD\\x94\\xEA\\xB0\\x80...' for column 'ou' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x9C \\xEB\\x82...' for column 'pan' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x97\\xAC\\xEC\\x8A\\xA4...' for column 'slr' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xB8\\xEC\\xA2\\x85...' for column 'mlb' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x82\\xAC\\xEC\\x9D\\xB4...' for column 'ruri' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA0\\x84\\xED\\x98\\x84...' for column 'utde' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\xA1\\xB8\\xEC\\x9D\\x8C...' for column 'bobe' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xB8\\xEC\\x9D\\xBC...' for column 'ygosu' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x8E\\x98\\xEB\\xAF\\xB8...' for column 'drip' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9E\\x90\\xEC\\xB7\\xA8...' for column 'theqoo' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x9A\\x94\\xEC\\xA6\\x98...' for column 'dogge' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEC\\x84\\xB9\\xEC\\x8B\\x9C...' for column 'namsung' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB3\\xB4\\xED\\x86\\xB0...' for column 'flash1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x85\\x80\\xEB\\xB8\\x94...' for column 'flash2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xB0\\xB0\\xED\\x8B\\x80...' for column 'dream1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x83\\xB1\\xED\\x83\\xB1...' for column 'dream2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xED\\x98\\x9C\\xEB\\xB9\\x88' for column 'bobe2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA0\\x88\\xEC\\xA0\\x84...' for column 'fomos1' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xA7\\x8C\\xEC\\x84\\x9D...' for column 'fomos2' at row 1")
#   result = self._query(query)
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xEB\\xAC\\xB4\\xEB\\xA6\\x8E...' for column 'ilbe' at row 1")
#   result = self._query(query)
#  www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258751
# 만석 기차 1인 2좌석 논란(56) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258710
# 무릎이라도 굻겠습니다. 한번만 도와주십시요. http://www.ilbe.com/10011645291
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8ce06efbb841> in <module>()
#     566     print('start parsing')
#     567     delete()
# --> 568     parse()
#     569     print('parsing ends')
#     570     print('sleep in 40s')
#
# <ipython-input-1-8ce06efbb841> in parse()
#     559        ##DB에 저장
#     560     for x in range(len(data[0])):
# --> 561                     allsave(x)
#     562                     print('-----------')
#     563
#
# <ipython-input-1-8ce06efbb841> in allsave(x)
#     554                                   flash1=list[16][0],link_flash1=list[16][1], flash2=list[17][0],link_flash2=list[17][1], dream1=list[18][0],link_dream1=list[18][1],
#     555                                   dream2=list[19][0],link_dream2=list[19][1], bobe2=list[20][0],link_bobe2=list[20][1], fomos1=list[21][0],link_fomos1=list[21][1],
# --> 556                                   fomos2=list[22][0],link_fomos2=list[22][1], ilbe=list[23][0],link_ilbe=list[23][1],
#     557                                     ).save()
#     558
#
# /Users/joon/anaconda/lib/python3.6/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     805
#     806         self.save_base(using=using, force_insert=force_insert,
# --> 807                        force_update=force_update, update_fields=update_fields)
#     808     save.alters_data = True
#     809
#
# /Users/joon/anaconda/lib/python3.6/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     835             if not raw:
#     836                 self._save_parents(cls, using, update_fields)
# --> 837             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     838         # Store the database on which the object was saved
#     839         self._state.db = using
#
# /Users/joon/anaconda/lib/python3.6/site-packages/django/db/transaction.py in __exit__(self, exc_type, exc_value, traceback)
#     265                     connection.connection = None
#     266                 else:
# --> 267                     connection.set_autocommit(True)
#     268             # Outermost block exit when autocommit was disabled.
#     269             elif not connection.savepoint_ids and not connection.commit_on_exit:
#
# /Users/joon/anaconda/lib/python3.6/site-packages/django/db/backends/base/base.py in set_autocommit(self, autocommit, force_begin_transaction_with_broken_autocommit)
#     409             self._start_transaction_under_autocommit()
#     410         else:
# --> 411             self._set_autocommit(autocommit)
#     412
#     413         self.autocommit = autocommit
#
# /Users/joon/anaconda/lib/python3.6/site-packages/django/db/backends/mysql/base.py in _set_autocommit(self, autocommit)
#     305     def _set_autocommit(self, autocommit):
#     306         with self.wrap_database_errors:
# --> 307             self.connection.autocommit(autocommit)
#     308
#     309     def disable_constraint_checking(self):
#
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/connections.py in autocommit(self, value)
#     758         current = self.get_autocommit()
#     759         if value != current:
# --> 760             self._send_autocommit_mode()
#     761
#     762     def get_autocommit(self):
#
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/connections.py in _send_autocommit_mode(self)
#     776         self._execute_command(COMMAND.COM_QUERY, "SET AUTOCOMMIT = %s" %
#     777                               self.escape(self.autocommit_mode))
# --> 778         self._read_ok_packet()
#     779
#     780     def begin(self):
#
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/connections.py in _read_ok_packet(self)
#     765
#     766     def _read_ok_packet(self):
# --> 767         pkt = self._read_packet()
#     768         if not pkt.is_ok_packet():
#     769             raise err.OperationalError(2014, "Command Out of Sync")
#
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     985         buff = b''
#     986         while True:
# --> 987             packet_header = self._read_bytes(4)
#     988             if DEBUG: dump_packet(packet_header)
#     989
#
# /Users/joon/anaconda/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#    1019         while True:
#    1020             try:
# -> 1021                 data = self._rfile.read(num_bytes)
#    1022                 break
#    1023             except (IOError, OSError) as e:
#
# /Users/joon/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

req2 = requests.get('').text
soup_flash2 = BeautifulSoup(req2, 'html.parser')

    #ruri
for title in soup_flash2.select(''): 
                    a = title.get('href')
                    print(title.text)
                    print(a)
