# %%
# parser.py
import time
import logging
import requests
from bs4 import BeautifulSoup
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "mydjango.settings")
import django
django.setup()

###########
from blog.models import CrawlingData
###########
#data = requests.get("url")  
#print(data.encoding) // 키 값 알아내는 법,,//키==싸이트의 인코딩 방식
encoding_map = {'437': 'cp437',
 '646': 'ascii',
 '850': 'cp850',
 '852': 'cp852',
 '855': 'cp855',
 '857': 'cp857',
 '860': 'cp860',
 '861': 'cp861',
 '862': 'cp862',
 '863': 'cp863',
 '865': 'cp865',
 '866': 'cp866',
 '869': 'cp869',
 '8859': 'latin_1',
 '932': 'cp932',
 '936': 'gbk',
 '949': 'cp949',
 '950': 'cp950',
 'CP-GR': 'cp869',
 'CP-IS': 'cp861',
 'EBCDIC-CP-BE': 'cp500',
 'EBCDIC-CP-CH': 'cp500',
 'EBCDIC-CP-HE': 'cp424',
 'IBM037': 'cp037',
 'IBM039': 'cp037',
 'IBM424': 'cp424',
 'IBM437': 'cp437',
 'IBM500': 'cp500',
 'IBM775': 'cp775',
 'IBM850': 'cp850',
 'IBM852': 'cp852',
 'IBM855': 'cp855',
 'IBM857': 'cp857',
 'IBM860': 'cp860',
 'IBM861': 'cp861',
 'IBM862': 'cp862',
 'IBM863': 'cp863',
 'IBM864': 'cp864',
 'IBM865': 'cp865',
 'IBM866': 'cp866',
 'IBM869': 'cp869',
 'L1': 'latin_1',
 'L2': 'iso8859_2',
 'L3': 'iso8859_3',
 'L4': 'iso8859_4',
 'L5': 'iso8859_9',
 'L6': 'iso8859_10',
 'L8': 'iso8859_14',
 'U16': 'utf_16',
 'U7': 'utf_7',
 'U8': 'utf_8',
 'UTF': 'utf_8',
 'UTF-16BE': 'utf_16_be',
 'UTF-16LE': 'utf_16_le',
 'arabic': 'iso8859_6',
 'big5-hkscs': 'big5hkscs',
 'big5-tw': 'big5',
 'chinese': 'gb2312',
 'cp1361': 'johab',
 'cp154': 'ptcp154',
 'cp819': 'latin_1',
 'cp936': 'gbk',
 'csbig5': 'big5',
 'csiso2022jp': 'iso2022_jp',
 'csiso2022kr': 'iso2022_kr',
 'csiso58gb231280': 'gb2312',
 'csptcp154': 'ptcp154',
 'csshiftjis': 'shift_jis',
 'cyrillic': 'iso8859_5',
 'cyrillic-asian': 'ptcp154',
 'euc-cn': 'gb2312',
 'euccn': 'gb2312',
 'eucgb2312-cn': 'gb2312',
 'eucjis2004': 'euc_jis_2004',
 'eucjisx0213': 'euc_jisx0213',
 'eucjp': 'euc_jp',
 'euckr': 'euc_kr',
 'gb18030-2000': 'gb18030',
 'gb2312-1980': 'gb2312',
 'gb2312-80': 'gb2312',
 'greek': 'iso8859_7',
 'greek8': 'iso8859_7',
 'hebrew': 'iso8859_8',
 'hkscs': 'big5hkscs',
 'hz-gb': 'hz',
 'hz-gb-2312': 'hz',
 'hzgb': 'hz',
 'ibm1026': 'cp1026',
 'ibm1140': 'cp1140',
 'iso-2022-jp': 'iso2022_jp',
 'iso-2022-jp-1': 'iso2022_jp_1',
 'iso-2022-jp-2': 'iso2022_jp_2',
 'iso-2022-jp-2004': 'iso2022_jp_2004',
 'iso-2022-jp-3': 'iso2022_jp_3',
 'iso-2022-jp-ext': 'iso2022_jp_ext',
 'iso-2022-kr': 'iso2022_kr',
 'iso-8859-1': 'latin_1',
 'iso-8859-10': 'iso8859_10',
 'iso-8859-13': 'iso8859_13',
 'iso-8859-14': 'iso8859_14',
 'iso-8859-15': 'iso8859_15',
 'iso-8859-2': 'iso8859_2',
 'iso-8859-3': 'iso8859_3',
 'iso-8859-4': 'iso8859_4',
 'iso-8859-5': 'iso8859_5',
 'iso-8859-6': 'iso8859_6',
 'iso-8859-7': 'iso8859_7',
 'iso-8859-8': 'iso8859_8',
 'iso-8859-9': 'iso8859_9',
 'iso-ir-58': 'gb2312',
 'iso2022jp': 'iso2022_jp',
 'iso2022jp-1': 'iso2022_jp_1',
 'iso2022jp-2': 'iso2022_jp_2',
 'iso2022jp-2004': 'iso2022_jp_2004',
 'iso2022jp-3': 'iso2022_jp_3',
 'iso2022jp-ext': 'iso2022_jp_ext',
 'iso2022kr': 'iso2022_kr',
 'iso8859-1': 'latin_1',
 'jisx0213': 'euc_jis_2004',
 'korean': 'euc_kr',
 'ks_c-5601': 'euc_kr',
 'ks_c-5601-1987': 'euc_kr',
 'ks_x-1001': 'euc_kr',
 'ksc5601': 'euc_kr',
 'ksx1001': 'euc_kr',
 'latin': 'latin_1',
 'latin1': 'latin_1',
 'latin2': 'iso8859_2',
 'latin3': 'iso8859_3',
 'latin4': 'iso8859_4',
 'latin5': 'iso8859_9',
 'latin6': 'iso8859_10',
 'latin8': 'iso8859_14',
 'maccentraleurope': 'mac_latin2',
 'maccyrillic': 'mac_cyrillic',
 'macgreek': 'mac_greek',
 'maciceland': 'mac_iceland',
 'maclatin2': 'mac_latin2',
 'macroman': 'mac_roman',
 'macturkish': 'mac_turkish',
 'ms-kanji': 'cp932',
 'ms1361': 'johab',
 'ms932': 'cp932',
 'ms936': 'gbk',
 'ms949': 'cp949',
 'ms950': 'cp950',
 'mskanji': 'cp932',
 'pt154': 'ptcp154',
 's_jis': 'shift_jis',
 's_jisx0213': 'shift_jisx0213',
 'shiftjis': 'shift_jis',
 'shiftjis2004': 'shift_jis_2004',
 'shiftjisx0213': 'shift_jisx0213',
 'sjis': 'shift_jis',
 'sjis2004': 'shift_jis_2004',
 'sjis_2004': 'shift_jis_2004',
 'sjisx0213': 'shift_jisx0213',
 'u-jis': 'euc_jp',
 'uhc': 'cp949',
 'ujis': 'euc_jp',
 'us-ascii': 'ascii',
 'utf16': 'utf_16',
 'utf8': 'utf_8',
 'windows-1250': 'cp1250',
 'windows-1251': 'cp1251',
 'windows-1252': 'cp1252',
 'windows-1253': 'cp1253',
 'windows-1254': 'cp1254',
 'windows-1255': 'cp1255',
 'windows-1257': 'cp1257',
 'windows-1258': 'cp1258',
 'windows1256': 'cp1256',

}

def delete():
    a=CrawlingData.objects.all()
    a.delete()

def parse():
    ## 설정
    data={
               0 : { },#instiz
               1  : { },#clien
               2 :  { },#fmkorea
               3 : { },#ou
               4 : { },#pan
               5 : { }, #slr
               6 : { }, #mlb
               7 : { },#inben
               8 : { },#ruri
               9 : { },#utde
              10 : { },#bobe
               11 : { },#ygosu
               12 : { },#drip
               13 : { },#theqoo
               14 : { },#dogge
               15 : { }, #namsung
               16 : { }, #flash1
               17 : { }, #flash2
               18 : { }, #dream1
               19 : { }, #dream2
               20 : { }, #bobe2
               21 : { },#fomos1
               22 : { },#fomos2
               23 : { },#ilbe
    }
    #instiz
    req = requests.get('http://www.instiz.net/bbs/list.php?id=pt&srd=1&srt=3&k=&stype=&stype2=&stype3=').text
    soup_instiz = BeautifulSoup(req, 'html.parser')
    #clien
    req = requests.get('https://www.clien.net/service/group/board_all?od=T33').text
    soup_clien = BeautifulSoup(req, 'html.parser')
    #fmkorea
    req = requests.get('http://www.fmkorea.com/index.php?mid=best&listStyle=list&page=1').text
    soup_fmkorea = BeautifulSoup(req, 'html.parser')
    #ou
    req = requests.get('http://www.todayhumor.co.kr/board/list.php?table=bestofbest').text
    soup_ou = BeautifulSoup(req, 'html.parser')
    #pan
    req = requests.get('http://pann.nate.com/talk/ranking').text
    soup_pan = BeautifulSoup(req, 'html.parser')
    #slr
    req = requests.get('http://www.slrclub.com/bbs/zboard.php?id=best_article&category=1&setsearch=category').text
    soup_slr = BeautifulSoup(req, 'html.parser')
    #mlb
    req = requests.get('http://mlbpark.donga.com/mp/best.php?b=bullpen&m=view').text
    soup_mlb = BeautifulSoup(req, 'html.parser')
    #inben
    req = requests.get('http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&query=list&my=chu&category=%EC%9C%A0%EB%A8%B8&sort=PID&name=&subject=&content=&keyword=&orderby=&iskin=webzine').text
    soup_inben = BeautifulSoup(req, 'html.parser')
    #ruri
    req = requests.get('http://bbs.ruliweb.com/best/selection').text
    soup_ruri = BeautifulSoup(req, 'html.parser')
    #utde
    req = requests.get('http://web.humoruniv.com/board/humor/list.html?table=pds&st=day').text.encode(encoding_map['iso-8859-1'])
    soup_utde = BeautifulSoup(req, 'html.parser')
    #bobe
    req = requests.get('http://www.bobaedream.co.kr/list?code=best').text.encode(encoding_map['iso-8859-1'])
    soup_bobe = BeautifulSoup(req, 'html.parser')
    #ygosu
    req = requests.get('http://www.ygosu.com/community/real_article').text
    soup_ygosu = BeautifulSoup(req, 'html.parser')
    #drip
    req = requests.get('http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc').text
    soup_drip = BeautifulSoup(req, 'html.parser')
    #theqoo
    req = requests.get('http://theqoo.net/tbest?filter_mode=normal').text
    soup_theqoo = BeautifulSoup(req, 'html.parser')
    #dogge
    req = requests.get('http://dkbnews.donga.com/Board?p=1&tcode=bbs_dkbnews&s=date&key=&query=').text
    soup_dogge = BeautifulSoup(req, 'html.parser')
    #namsung
    req1= requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=ggolit').text
    soup_namsung1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=celeb').text
    soup_namsung2 = BeautifulSoup(req2, 'html.parser')
    #flash1
    req1= requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=star&page=2&page=1').text.encode(encoding_map['iso-8859-1'])
    soup_flash1 = BeautifulSoup(req1, 'html.parser')
    #flash2
    req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
    soup_flash2 = BeautifulSoup(req2, 'html.parser')
    #dream1
    req1= requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_star&is_image=Y').text
    soup_dream1 = BeautifulSoup(req1, 'html.parser')
    #dream2
    req2 = requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_humor&is_image=Y').text
    soup_dream2 = BeautifulSoup(req2, 'html.parser')
    #bobe2
    req1= requests.get('http://www.bobaedream.co.kr/list?code=girl&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=Subject&s_key=&level_no=&vdate=&type=list&page=1')
    req1 =req1.text.encode(encoding_map['iso-8859-1'])
    soup_bobe2 = BeautifulSoup(req1, 'html.parser')
    #fomos1
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=5').text
    soup_fomos1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=6').text
    soup_fomos2 = BeautifulSoup(req2, 'html.parser')
    #fomos2
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=3').text
    soup_fomos3 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=4').text
    soup_fomos4 = BeautifulSoup(req2, 'html.parser')
    #ilbe
    req1= requests.get('http://www.ilbe.com/ilbe').text
    soup_ilbe = BeautifulSoup(req1, 'html.parser')

    
    ## json에 저장
    #instiz
    for title in soup_instiz.select('#subject a'): 
                    a = title.get('href')
                    b=a.replace(".." , "instiz.net")
                    data[0][title.text] = b
    #clien
    n=0
    for title in soup_clien.select('.list-title .list-subject'): 
        if n == 0:
            n+=1
            continue
        else:
            a = title.get('href')
            if not a==None:
                    a='clien.net' + a
                    str=" ".join(title.text.strip().split())
                    data[1][str] = a
    #fmkorea
    for title in soup_fmkorea.select('.hx'): 
                    a = title.get('href')
                    data[2][title.text.strip()] = a
    #ou
    for title in soup_ou.select('.subject a'): 
                    a = title.get('href')
                    a='todayhumor.co.kr' + a
                    data[3][title.text] = a
    #pan
    for title in soup_pan.select('dt a'): 
                    a = title.get('href')
                    data[4][title.text] = a
    #slr
    for title in soup_slr.select('.sbj a'): 
                    a = title.get('href')
                    a='slrclub.com'+a
                    data[5][title.text] = a
    #mlb
    for title in soup_mlb.select('.t_left a'): 
                    a = title.get('href')
                    data[6][title.text] = a
    #inben
    for title in soup_inben.select('a.sj_ln'): 
                    a = title.get('href')
                    data[7][title.text] = a
    #ruri
    for title in soup_ruri.select('.subject a'): 
                    a = title.get('href')
                    data[8][title.text] = a
     #utde
    for title in soup_utde.select('a.brn3, a.brn2, a.brn1'): 
                    a = title.get('href')
                    a='web.humoruniv.com/board/humor/'+a
                    str=" ".join(title.text.strip().split())
                    data[9][str] = a
    #bobe
    for title in soup_bobe.select('a.bsubject'): 
                    a = title.get('href')
                    a='bobaedream.co.kr'+a
                    data[10][title.text] = a
    #ygosu
    for title in soup_ygosu.select('.tit a'): 
                    a = title.get('href')
                    data[11][title.text] = a
     #drip
    n=0
    for title in soup_drip.select('td.title a'): 
                if n == 0:
                      n+=1
                      continue
                else:
                     a = title.get('href')
                     data[12][title.text.strip()] = a
    #theqoo
    j=0 
    n=1
    x=1
    m=2
    for title in soup_theqoo.select('td.title a'): 
            if j < 8 :
                     j+=1
                     continue
            else:
                    if  n == m:
                            a=title.get('href')
                            a='theqoo.net'+a.replace('_comment','') 
                            n+=1
                            x+=1
                            m=2*x
                            data[13][title.text] = a
                            continue
                    else:
                            n+=1
                            continue
    #dogge
    for title in soup_dogge.select('.txt a'): 
                    a = title.get('href')
                    a ='http://dkbnews.donga.com/Board'+a
                    data[14][title.text.strip()] = a
    #namsung
    n=0
    for title in soup_namsung1.select('.list-subject a'): 
                    if n < 10:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                    else:
                          break                   
    for title in soup_namsung2.select('.list-subject a'): 
                     if n < 19:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                     else:
                          break
    #flash1
    n=0
    for title in soup_flash1.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[16][title.text]=a
     #flash2
    n=0
    for title in soup_flash2.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[17][title.text]=a
    #dream1
    n=1
    x=1
    m=2
    for title in soup_dream1.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[18][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #dream2
    n=1
    x=1
    m=2
    for title in soup_dream2.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[19][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #bobe2
    for title in soup_bobe2.select('.pl14 a.bsubject'): 
                    a=title.get('href')
                    a='bobaedream.co.kr'+a
                    data[20][title.text.strip()]=a
    #fomos1
    n=0
    for title in soup_fomos1.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos2.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    #fomos2
    n=0
    for title in soup_fomos3.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos4.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
     #ilbe
    n=0
    for title in soup_ilbe.select('.title a'): 
                    if n == 0:
                            n+=1
                            continue
                    else:
                            a=title.get('href')
                            data[23][title.text.strip()]=a


     #한꺼번에 DB 에  insert 하기 위한 함수
    
    def allsave(x):
            crawling = CrawlingData()
            list = [
                       [crawling.instiz, crawling.link_instiz], [crawling.clien, crawling.link_clien], [crawling.fmkorea, crawling.link_fmkorea],
                       [crawling.ou, crawling.link_ou] ,[crawling.pan, crawling.link_pan],[crawling.slr, crawling.link_slr],[crawling.mlb, crawling.link_mlb],
                       [crawling.inben, crawling.link_inben],[crawling.ruri, crawling.link_ruri],[crawling.utde, crawling.link_utde],[crawling.bobe, crawling.link_bobe],
                       [crawling.ygosu, crawling.link_ygosu],[crawling.drip, crawling.link_drip],[crawling.theqoo, crawling.link_theqoo],
                       [crawling.dogge, crawling.link_dogge],[crawling.namsung, crawling.link_namsung],[crawling.flash1, crawling.link_flash1],
                       [crawling.flash2, crawling.link_flash2],[crawling.dream1, crawling.link_dream1],[crawling.dream2, crawling.link_dream2],
                       [crawling.bobe2, crawling.link_bobe2],[crawling.fomos1, crawling.link_fomos1], [crawling.fomos2, crawling.link_fomos2],
                       [crawling.ilbe, crawling.link_ilbe]
                   ]
            for  i in range(len(data)):
                    n=0
                    for t,l in data[i].items():
                        if n == x:
                            list[i][0],list[i][1]= t,l
                            print(list[i][0],list[i][1])
                            break
                        else:
                            n+=1
                            continue
            
            CrawlingData(instiz=list[0][0],link_instiz=list[0][1], clien=list[1][0],link_clien=list[1][1], fmkorea=list[2][0],link_fmkorea=list[2][1],
                                  ou=list[3][0],link_ou=list[3][1], pan=list[4][0],link_pan=list[4][1], slr=list[5][0],link_slr=list[5][1], mlb=list[6][0],link_mlb=list[6][1],
                                  inben=list[7][0],link_inben=list[7][1], ruri=list[8][0],link_ruri=list[8][1], utde=list[9][0],link_utde=list[9][1],
                                  bobe=list[10][0],link_bobe=list[10][1], ygosu=list[11][0],link_ygosu=list[11][1], drip=list[12][0],link_drip=list[12][1],
                                  theqoo=list[13][0],link_theqoo=list[13][1], dogge=list[14][0],link_dogge=list[14][1], namsung=list[15][0],link_namsung=list[15][1],
                                  flash1=list[16][0],link_flash1=list[16][1], flash2=list[17][0],link_flash2=list[17][1], dream1=list[18][0],link_dream1=list[18][1],
                                  dream2=list[19][0],link_dream2=list[19][1], bobe2=list[20][0],link_bobe2=list[20][1], fomos1=list[21][0],link_fomos1=list[21][1],
                                  fomos2=list[22][0],link_fomos2=list[22][1], ilbe=list[23][0],link_ilbe=list[23][1],
                                    ).save() 
            
       ##DB에 저장
    for x in range(len(data[0])):
                    allsave(x)
                    print('-----------')
                    
    
while True:
    print('start parsing')
    delete()
    parse()
    print('parsing ends')
    print('sleep in 40s')
    time.sleep(60)
# Out:
# start parsing
# 이것만 생각하면 9월 한달 개꿀 instiz.net/pt?no=4734191&page=1&srt=3&k=&srd=1
# 모공 [릴레이28일차] 삼성 장충기 문자 보고가시죠. clien.net/service/board/park/11163597?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 박사모 중심으로 여성징병제 청원 11만명 청원한걸로 알려져 충격.. http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768171723
# 캐릭터를 누렁이로 선택하시겠습니까? .gif todayhumor.co.kr/board/view.php?table=bestofbest&no=361146&s_no=361146&page=1
# 임산부 배는 누구나 만져도 되나요? http://pann.nate.com/talk/338667102
# 아버지가 만둣집 차려주신다는데 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259889
# 서예지 졸업사진.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008425102&m=view
#  [유머] 알고보면 한국 축구의 원흉 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809114
# '아인슈타인의 상대성이론 설명' http://bbs.ruliweb.com/best/board/300143/read/34662540
# 믿고 걸러야 할 인간.jpg [66] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706839
# 부산 가해자 집에  오물투척 쇄도 bobaedream.co.kr/view?code=best&No=133093&vdate=
# 92년생 모쏠아다다 질문 받는다 http://www.ygosu.com/community/real_article/love/77690/?page=0&frombest=Y
# 나 얼마전에 직접느낀 보스베이비 후기만화 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138369262
# 김연아 코스튬 네일아트.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=563089997
# 화가 많이 난 박보영.jpg이슈포토 http://dkbnews.donga.com/Board?no=15992&m=view&tcode=bbs_dkbnews
# 일반인 스러운 FC2녀  댓글 : 5 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34321
# 워터파크녀 최설화 비키니 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73840&page=1
# 김태희 세끈한 오피스룩 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82439
# 빚을 지배하는 상민 newsbbs.dreamx.com/view.do?list_id=697919&page=1&bid=cnt_star
# 의외의 벅지녀 newsbbs.dreamx.com/view.do?list_id=697918&page=1&bid=cnt_humor
# av 신작 많은 웹하드 찾았습니다. bobaedream.co.kr/view?code=girl&No=850044&bm=1
# 다큰 성인이 교복을 입는건 무슨 심보인가요?(7) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258243
# 볼때마다 몸매 쩐다고 느껴지는 트와이스 멤...(6) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258228
# 80만명 돌파 완료.jpg http://www.ilbe.com/10009775629
# -----------
# 부산 가해자 정유미 과거 남돌성희롱 instiz.net/pt?no=4736215&page=1&srt=3&k=&srd=1
# 모공 청와대 부산경찰파면청원 clien.net/service/board/park/11163556?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 내일은 SSS급 이등병 .manwha http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768343273
# 코X트코 직원 넋두리2 todayhumor.co.kr/board/view.php?table=bestofbest&no=361145&s_no=361145&page=1
# 남들이 해보지 못했을 경험쓰고가자 http://pann.nate.com/talk/338668737
# 개미녀 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259888
# 와... 몸매 죽이네요.. http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008422108&m=view
#  [유머] 신개념 연예인 기살려주는 소주차(Feat.. http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809100
# 미모의 여직원 : 이번 주 일요일에 뭐 해요? http://bbs.ruliweb.com/best/board/300143/read/34662282
# 공무원의 복수.jpg [73] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706828
# 518 공수부대는 폭도가 맞네요 bobaedream.co.kr/view?code=best&No=133092&vdate=
# 트젠 목소리 반전 레전드   http://www.ygosu.com/community/real_article/yeobgi/1244371/?page=0&frombest=Y
# 육아 팁.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138368123
# 부산여중생사건 정유미 과거 남돌성희롱 (혐) theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=563082251
# 아이돌과 배우의 차이.gif이슈포토 http://dkbnews.donga.com/Board?no=15991&m=view&tcode=bbs_dkbnews
# 코스녀의 몸매 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34320
# 우주소녀 은서 돋보이는 기럭지 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73839&page=1
# 필라테스녀 골반 좀 보소 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82438
# 피오피 설 newsbbs.dreamx.com/view.do?list_id=697917&page=1&bid=cnt_star
# 백종원 대표의 매장관리 노하우 newsbbs.dreamx.com/view.do?list_id=697916&page=1&bid=cnt_humor
# 설화 bobaedream.co.kr/view?code=girl&No=850034&bm=1
# 여자의 완성은 골반인 이유(3) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258232
# 음주운전 재판받으러 가는 가수 길 패션 ㅋㅋ...(5) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258215
# 부산 여중생이 들어갈 소년원에대해아라보자.araboza http://www.ilbe.com/10007830307
# -----------
# 자살 안하고 버틴게 용하다는 한 웹툰 여주의 가정 instiz.net/pt?no=4734784&page=1&srt=3&k=&srd=1
# 모공 위례별초 페미니즘 교사 규탄 회견에서 갓침.txt clien.net/service/board/park/11164587?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 우원재.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768398910
# 문재인 대통령 러시아 순방에 동행한 김정숙 여사 첫날 (청와대 트윗) todayhumor.co.kr/board/view.php?table=bestofbest&no=361144&s_no=361144&page=1
# 마누라가 애낳고 몸매변하면 진짜 이래요? http://pann.nate.com/talk/338669361
# 외제차 사겠다 말씀드리니 '건방지게 뭔 외제차냐'고 ㅠㅠ  slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259887
# 부산 운전이 엄청나긴 한가보네요 ㄷㄷ.gif http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008422003&m=view
#  [유머] 축구협회가 히딩크를 싫어하는 이유 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809096
# 천조국의 cg 퀄리티 수듄 http://bbs.ruliweb.com/best/board/300143/read/34661819
# 비뇨기과 실장의 커플 환자 썰.jpg [102] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706823
# 밀양 bobaedream.co.kr/view?code=best&No=133090&vdate=
# 섬나라 헬반도 생태계 교란종.jpg  http://www.ygosu.com/community/real_article/yeobgi/1244302/?page=0&frombest=Y
# 훼이크에 속은 댕댕이들.gif http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138367010
# [단독] “방탄소년단 ‘편법마케팅’ 폭로하겠다” 돈 뜯은 협박범 실형 선고 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562785563
# [주번나] 역대급 피지컬 양누나.gif이슈포토 http://dkbnews.donga.com/Board?no=15990&m=view&tcode=bbs_dkbnews
# 너무 파인 수영복  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34318
# 하니 VS 모모 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73838&page=1
# 성진국 육상부 여대생 몸매 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82437
# 성소 봉화은어축제 newsbbs.dreamx.com/view.do?list_id=697914&page=1&bid=cnt_star
# 현관문 안전고리만 걸면 위험한 이유 newsbbs.dreamx.com/view.do?list_id=697913&page=1&bid=cnt_humor
# 나영 bobaedream.co.kr/view?code=girl&No=850033&bm=1
# 후방주의) 오버워치갤 인증녀(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258247
# 이미지 세탁 전 이동국(6) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258557
# TV보는데 노짱버섯 나오네 ㅋㅋㅋㅋ http://www.ilbe.com/10009875247
# -----------
# 요즘 소름돋는다고 난리난 타로챗봇 instiz.net/pt?no=4733809&page=1&srt=3&k=&srd=1
# 모공 mbc기자의 팩폭 ㅋㅋ clien.net/service/board/park/11165824?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 빨간맛~ http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767971380
# 집사야 내가 주의를 끌테니 그 사이 도망쳐!.gif todayhumor.co.kr/board/view.php?table=bestofbest&no=361143&s_no=361143&page=1
# 자기가 먹던 음식 주는 여자친구 http://pann.nate.com/talk/338668890
# 추석 대비해서 하나 지름 ㄷㄷㄷㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259886
# 회사 동료 여자생각하며 딸 칠때 있습니까? http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008421514&m=view
#  [유머] (스압)손오공 인성 총정리 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809069
# 소개팅 상대 집에서 똥산 여성의 최후 http://bbs.ruliweb.com/best/board/300143/read/34661393
# 잔인한 조별과제 [31] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706930
# 검찰에게 머리털 300개 뽑힌배우 bobaedream.co.kr/view?code=best&No=133088&vdate=
# 자꾸 히딩크더러 현대축구 못따라간다고 개소리하는데 ㅋㅋㅋㅋ http://www.ygosu.com/community/real_article/soccer/223555/?page=0&frombest=Y
# 한국 드라마 고증 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138368655
# 비정상회담 왕심린 때문에 현재 대만 인터넷 난리.. theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562758987
# 학교 준비물 소금.jpg이슈포토 http://dkbnews.donga.com/Board?no=15989&m=view&tcode=bbs_dkbnews
# 아름답네요 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34317
# AOA 지민 슴받침 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73837&page=1
# 호불호 처자 컵 사이즈 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82436
# 윤아 솔직히 이쁘긴 함 (윤아짤 4장) newsbbs.dreamx.com/view.do?list_id=697912&page=1&bid=cnt_star
# 이병헌 영화 커리어에서 삭제된 작품 newsbbs.dreamx.com/view.do?list_id=697911&page=1&bid=cnt_humor
# 아이유 bobaedream.co.kr/view?code=girl&No=850032&bm=1
# 크롭누나 시스루ㅗㅜㅑ(4) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258214
# 쥐포의 두 얼굴(8) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258182
# 발퀄주의)  본격 메갈응징물.manhwa http://www.ilbe.com/10008096296
# -----------
# [단독] "성관계하면 풀어줄게"…부산 여중생 집단폭행 새 증언 instiz.net/pt?no=4734708&page=1&srt=3&k=&srd=1
# 모공 국민이 부르면 돌아보는 대통령님♡ clien.net/service/board/park/11164311?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 유키스 멤버 기섭, 뮤비 촬영중 폭발사고로 부상 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768327478
# 역사를 바꾼 권총 todayhumor.co.kr/board/view.php?table=bestofbest&no=361142&s_no=361142&page=1
# (++후기) 회사 휴가내고 시댁에 와서 전부치라는 남편 http://pann.nate.com/talk/338670004
# 300억 자게이의 저녁 식사 ㄷㄷㄷㄷㄷㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259884
# 회식간다고 삐진 여친.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008424268&m=view
#  [유머] 흔한 노래 검색 방법 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809041
# 3대 RPG 증후군.jpg http://bbs.ruliweb.com/best/board/300143/read/34661330
# 신개념 연예인 기살려주는 소주차 ㅋㅋㅋㅋㅋㅋ(feat 미우새) [42] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706840
# 부산 여중생 니들은 뒤졌다. bobaedream.co.kr/view?code=best&No=133086&vdate=
# 어깨 평가좀요  http://www.ygosu.com/community/real_article/sports/27070/?page=0&frombest=Y
# 부산 여중생 우리엄마 돈 많다 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138363713
# 회식가지 말라는 여자친구 카톡 추가버전ㅋㅋㅋㅋㅋ.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562752040
# [펌] 얘들아 우리 임신하지말자이슈포토 http://dkbnews.donga.com/Board?no=15988&m=view&tcode=bbs_dkbnews
# 바바 후미카 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34315
# 손나은 봉긋봉긋한 원피스 몸매 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73836&page=1
# 태국의 므흣한 간호사 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82435
# 골반이랑 엉태가 너무 좋아ㅠㅠ newsbbs.dreamx.com/view.do?list_id=697869&page=1&bid=cnt_star
# 영국군 음식 민영화 후 newsbbs.dreamx.com/view.do?list_id=697909&page=1&bid=cnt_humor
# 디애나 소나무 bobaedream.co.kr/view?code=girl&No=850031&bm=1
# 마광수 레전드 섹드립.jpg(6) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258353
# 강용석이 실물로 본 여자들 중 가장 이쁘다는...(4) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258240
# 자연미인...만나야 하는 이유...JPG http://www.ilbe.com/10009892978
# -----------
# “강다니엘 보인다VS안 보인다” 의견 갈린 정성호 패러디 instiz.net/pt?no=4735693&page=1&srt=3&k=&srd=1
# 모공 외교왕 문재인 #데일리문 clien.net/service/board/park/11166090?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 축협이 히딩크를 선임 안하는 팩트 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768265329
# [후방] 이런 바람직한 마을이 다 있나... todayhumor.co.kr/board/view.php?table=bestofbest&no=361141&s_no=361141&page=1
# 추가)시댁여러분.손주는 며느리닮으면 안됩니까? http://pann.nate.com/talk/338667557
# 4인가족 타기에 미니쿠퍼 어떤가요?? slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259883
# 헹가래 칠때 시리아 경기 안 끝났었다네요 ㄷㄷㄷㄷ.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008421727&m=view
#  [유머] 행운의 수업 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809034
# 공약 지키는 고든 램지 http://bbs.ruliweb.com/best/board/300143/read/34660931
# 부산 정유x 카톡읽게하는법 [64] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706902
# 부산 여학생 폭행 새로운 사실 bobaedream.co.kr/view?code=best&No=133091&vdate=
# 세젤귀 러블리즈 Jin(박명은).jpg   http://www.ygosu.com/community/real_article/stars/92553/?page=0&frombest=Y
# 여중생 폭행 말리자 "똑같이 만들어줄까" 가담 협박 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138362358
# 여동생 팩트로 두들겨패버리는 친오빠.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562736984
# 최설화, 무보정 몸매.jpg이슈포토 http://dkbnews.donga.com/Board?no=15987&m=view&tcode=bbs_dkbnews
# 크롭 사장님 몸매  댓글 : 11 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34314
# 데릭 로즈에 뿅간 신아영 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73835&page=1
# 클라스가 다른 피팅모델 허리라인 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82434
# 사나한테 까불다가 맞으면? newsbbs.dreamx.com/view.do?list_id=697908&page=1&bid=cnt_star
# 비상계단 newsbbs.dreamx.com/view.do?list_id=697907&page=1&bid=cnt_humor
# 승옥 bobaedream.co.kr/view?code=girl&No=850030&bm=1
# 양정원 레전드 급꼴 짤.gif(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258245
# 좃간지 나는 류승범 근황(5) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258241
# 아귀포아재 마누라 얼굴복원 http://www.ilbe.com/10009824139
# -----------
# 매우 희귀한 확률로 겪는다는 스탕달 증후군 instiz.net/pt?no=4734382&page=1&srt=3&k=&srd=1
# 모공 79명의 생산직 노동자가 떼 죽음을 당했다.jpg clien.net/service/board/park/11164561?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 홍준표 " 나는 젊은애들 멘토" http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768339833
# 사회초년생 꿀팁 todayhumor.co.kr/board/view.php?table=bestofbest&no=361140&s_no=361140&page=1
# 제왕절개랑 포경수술 비교하는 남편; http://pann.nate.com/talk/338668070
# 35세 실수익 329만원 휴..(질문 추가) 4잡 종류 공개 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259882
# 한국에서 7천만원 더받고 파는차 .jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008427715&m=view
#  [유머] 약속시간 자주 늦는 사람 마인드 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=809018
# 약속시간을 자주 어기는 사람들의 마인드.jpg http://bbs.ruliweb.com/best/board/300143/read/34660928
# 귀귀의 갓-논리 교실.jpg [28] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706922
# 써치라이트 트럭과의 전쟁 후기.jpg bobaedream.co.kr/view?code=best&No=133089&vdate=
# 신기하게 생긴 3층 복층 오피스텔 구조  http://www.ygosu.com/community/real_article/yeobgi/1244341/?page=0&frombest=Y
# 옷 쇼핑몰이 이상해서 보니까 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138287347
# 연예인 허언증 베스트3 .JPG theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562678659
# 실망했다고 초밥집에 후기 남긴 이후.jpg이슈포토 http://dkbnews.donga.com/Board?no=15986&m=view&tcode=bbs_dkbnews
# 속옷 착용샷  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34313
# 스텔라 민희 도톰한 하체 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73834&page=1
# 이희은 뭘 입어도 살아있는 골반 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82433
# 양갈래 헤어밴드 하니 newsbbs.dreamx.com/view.do?list_id=697906&page=1&bid=cnt_star
# 세계에서 가장 가파른 직선 계단 newsbbs.dreamx.com/view.do?list_id=697905&page=1&bid=cnt_humor
# 이한별 bobaedream.co.kr/view?code=girl&No=850029&bm=1
# 페이커 발라버리는 무빙.gif www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258229
# 남자 가수 3대 성관련 구설수 www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258242
# (피꺼솟주의)감자국 여중생집단폭행 가해자들 단톡방내용 http://www.ilbe.com/10009538231
# -----------
# 면접 시 성희롱 관련 질문 모범답안 instiz.net/pt?no=4735262&page=1&srt=3&k=&srd=1
# 모공 [펌] 한국의 개신교 사상 최악의 원톱 사건. clien.net/service/board/park/11163260?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# [더 선] 호세 엔리케, 무릎 부상으로 인해서 은퇴 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768045331
# 먹어보자 킹크랩^^ todayhumor.co.kr/board/view.php?table=bestofbest&no=361139&s_no=361139&page=1
# (추가)아주버님네 애를 키워달래요. http://pann.nate.com/talk/338669066
# 엘지 V10 첨 나왔을때 사진이 잘 나와서 샀는데 지금도 만족중이에요 ㄷㄷㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259881
# [고양이] 내 아들 됐습니다....jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008425864&m=view
#  [유머]  서지혜vs아이린 외모대결고래싸움에 새우등.. http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808987
# 결혼정보회사 상담하는 만화.jpg http://bbs.ruliweb.com/best/board/300143/read/34660912
# 제 친구가 감독님 영화에 출연했었어요!.jpg [22] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706853
# 주진우 기자 페이스북... bobaedream.co.kr/view?code=best&No=133084&vdate=
# 오랜만에 삼국지)이릉대전에 대해서 알아보자.(매우스압)  http://www.ygosu.com/community/real_article/yeobgi/1244335/?page=0&frombest=Y
# 허지웅 인스타그램 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138363569
# 손석희가 또......jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562621219
# 맛집블로거 후기 드립.jpg이슈포토 http://dkbnews.donga.com/Board?no=15985&m=view&tcode=bbs_dkbnews
# 맥심어워즈 늘씬한 뒤태 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34312
# 보일듯한 현아 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73833&page=1
# 포복하는 시노자키아이 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82432
# 정채연 vs 유라 결승전 비주얼 배틀 움짤스 newsbbs.dreamx.com/view.do?list_id=697903&page=1&bid=cnt_star
# 개스프리 키위 출시.jpg newsbbs.dreamx.com/view.do?list_id=697902&page=1&bid=cnt_humor
# 연아 bobaedream.co.kr/view?code=girl&No=850028&bm=1
# 속옷 피팅모델 민아(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258244
# 옷을 할머니처럼 입었는데 얼굴이 캐리 www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258106
# 유키스 디아블로 구걸사건.jpg http://www.ilbe.com/10009825742
# -----------
# [공식입장] 방탄소년단 측 "우리는 공갈협박 피해자, 부적절 마케팅 없었다" instiz.net/pt?no=4736012&page=1&srt=3&k=&srd=1
# 모공 코스트코 가격표의 비밀. clien.net/service/board/park/11165856?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# [실제] 메시가 아르헨티나에서 당하는 일.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768332815
# 새끼때부터 키운 냥이멍이들 특징 todayhumor.co.kr/board/view.php?table=bestofbest&no=361138&s_no=361138&page=1
# 지하동굴에서 청량돌로 돌아온 아이돌 http://pann.nate.com/talk/338666707
# 진심 연기 끝판왕 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259880
# 김사복님 보도 보니까 택시운전사 영화 좀 실망스럽네요. http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008427193&m=view
#  [유머] (고전) 나만 불편해 ? http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808974
# 홍명보한테 반말해서 신난 이영표.JPG http://bbs.ruliweb.com/best/board/300143/read/34660373
# 뤽 베송이 꼽은 최고의 배우.jpg [54] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706882
# 부산여중생 피해자 어머니 힘내세요 bobaedream.co.kr/view?code=best&No=133094&vdate=
# 인스타 교복 처자  http://www.ygosu.com/community/real_article/yeobgi/1244326/?page=0&frombest=Y
# 부산 여중생 폭행 가해자 근황.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138364017
# 이런 저런 교양을 공부하기 좋은 사이트 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562568802
# 레이양, 착시의상 jpg이슈포토 http://dkbnews.donga.com/Board?no=15984&m=view&tcode=bbs_dkbnews
# 패션쇼 비키니 모델의 무브먼트 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34311
# 물오른 가시나 선미 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73832&page=1
# 아프리카 BJ 이대로 정말 괜찮은가? flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82431
# 블랙핑크 지수 예쁘게 나온 직캠 (음악중심 울산 170… newsbbs.dreamx.com/view.do?list_id=697901&page=1&bid=cnt_star
# 여친이 짧은 치마 입었다고 좋아하면 안됩니다.jpg newsbbs.dreamx.com/view.do?list_id=697900&page=1&bid=cnt_humor
# 쯔위 bobaedream.co.kr/view?code=girl&No=850023&bm=1
# 비 맞는 사무직 여성.gif(2) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258262
# 아이돌 군입대 레전드	(6) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258542
# 신태용이 6월에 히딩크밀어내서 신났구나 ㅋㅋㅋㅋ http://www.ilbe.com/10009817424
# -----------
# 실망했던 초밥집에 다시 주문을 했는데.jpg instiz.net/pt?no=4735673&page=1&srt=3&k=&srd=1
# 모공 돈에 미친 상남자.jpg clien.net/service/board/park/11166020?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 샘물교회 목사 다시 아프간 선교중 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768346814
# '공관병 갑질' 박찬주 대장 수사 상황 todayhumor.co.kr/board/view.php?table=bestofbest&no=361137&s_no=361137&page=1
# 인생 ㄹㅇ 인소 같은 아이돌.jpg http://pann.nate.com/talk/338666559
# 이탈리아 렌터카 교통위반 벌금이 나왔네요.. slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259879
# 방송인 강예빈 성형전 jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008429053&m=view
#  [유머] 아파트 이웃의 싸섹싸섹 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808872
# 농어촌 특별전형.jpg http://bbs.ruliweb.com/best/board/300143/read/34659843
# 현 시점 재조명되는 만화 [26] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706920
# ▶ 요즘 유행한다는 사기 수법 bobaedream.co.kr/view?code=best&No=133085&vdate=
# 벌써 7년차 아이돌 윤보미  http://www.ygosu.com/community/real_article/stars/92578/?page=0&frombest=Y
# 치킨시켰는데 젓가락 모자라서 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138360924
# 실망했다고 초밥집에 후기 남긴 이후..jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562567072
# 후쿠시마 농산물 먹은 출연자들의 결말.jpg이슈포토 http://dkbnews.donga.com/Board?no=15983&m=view&tcode=bbs_dkbnews
# 혼자서 난리남  댓글 : 5 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34269
# 상상하게 만드는 임미소 골퍼 몸매 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73831&page=1
# 신작 소식이없는 처자 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82430
# 신민아 궁뎅이 newsbbs.dreamx.com/view.do?list_id=697899&page=1&bid=cnt_star
# 아동 성범죄자 응징하는 미드.jpg newsbbs.dreamx.com/view.do?list_id=697898&page=1&bid=cnt_humor
# 찬미 bobaedream.co.kr/view?code=girl&No=850022&bm=1
# (후방) 호랑이를 그린 누드화(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258472
# 이 중 진심으로 빡친 사람은?(4) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258297
# 요즘 여중생들이 페북스타되려고 하는 EU http://www.ilbe.com/10009822223
# -----------
# 오늘자 인간SK-ll 남자아이돌 instiz.net/pt?no=4736321&page=1&srt=3&k=&srd=1
# 모공 文대통령 "흡수통일 아닌 남북 번영하는 경제공동체 추구" clien.net/service/board/park/11163244?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 알고 나면 소름돋는 아홉 장의 흑백사진 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768054531
# 넥슨 gm이 사고를 쳤다는군요 todayhumor.co.kr/board/view.php?table=bestofbest&no=361136&s_no=361136&page=1
# 안타까운 모모 쌍수 상황.JPG http://pann.nate.com/talk/338671125
# LG V30 카메라 실성능 ㅎㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ 有 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259878
# 공항관련해서는 대구사람들은 진짜 염치도 없네요 ㅋㅋㅋㅋ http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008427094&m=view
#  [유머] 어린이들의 순수함에 당황한 국민 MC http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808843
# 한국국대 감동스토리 http://bbs.ruliweb.com/best/board/300143/read/34659837
# 실망했다고 초밥집에 후기 남긴 이후...jyp [50] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706897
# [재업]여중생 경찰 은폐 - 게시물삭제당함 재업! bobaedream.co.kr/view?code=best&No=133082&vdate=
# 이거갖고 아이린 갤러리 가면 욕먹음?  http://www.ygosu.com/community/real_article/yeobgi/1244396/?page=0&frombest=Y
# 개드립간 1인 2석이 논란이 되는거자체가 이상한이유 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138357695
# 금수저 특징 삼다수로 라면 끓여먹음 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562548814
# 킬라그램 친형 팰라그램.jpg이슈포토 http://dkbnews.donga.com/Board?no=15982&m=view&tcode=bbs_dkbnews
# 잔잔한 라붐 해인 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28361
# 아린이 허벅지 자세히 보세요 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73830&page=1
# 여자의 완성은 골반인 이유 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82429
# 강소라 실물 이런느낌 , 거기만 보여! newsbbs.dreamx.com/view.do?list_id=697897&page=1&bid=cnt_star
# KKK단 1인 시위를 본 흑인 무리의 반응 newsbbs.dreamx.com/view.do?list_id=697895&page=1&bid=cnt_humor
# 하영 bobaedream.co.kr/view?code=girl&No=850021&bm=1
# 몸매가 너무 야한 BJ 도아 ㅓㅜㅑ(1) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258248
# 테사기테사기 거리는 스타1 리마스터 유저들 ...(35) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258107
# 일베간 아이린에대해서 araboza http://www.ilbe.com/10009833239
# -----------
# 백현 인스타_(f.루머 피드백) instiz.net/pt?no=4734130&page=1&srt=3&k=&srd=1
# 모공 학교 수련회 초토화 시킨 썰. JPG clien.net/service/board/park/11165077?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 우리나라에서는 상상도 못할 교육 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768320215
# 자유당 자수 ㅋㅋㅋㅋ todayhumor.co.kr/board/view.php?table=bestofbest&no=361135&s_no=361135&page=1
# 우리 학교 남자애덜 상태••• http://pann.nate.com/talk/338667730
# 방탄소년단 악재 하나 터졌군요. slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259877
# [단독] "히딩크, 한국민이 원한다면 국대 맡을 의사 있다" http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008430436&m=view
#  [유머] 1년간 6만곳 뒤졌지만 몰카하나 못찾아 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808826
# 음주운전 길...첫번째 공판.jpg http://bbs.ruliweb.com/best/board/300143/read/34659770
# 귀귀 명언 모음집.jpg [26] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706899
# ※  여러분 보배드림 유게가 ..... bobaedream.co.kr/view?code=best&No=133081&vdate=
# 여중생) 허지웅 인스타  http://www.ygosu.com/community/real_article/yeobgi/1244391/?page=0&frombest=Y
# 이틀동안 튀어나온 여학생들.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138351354
# 노키즈존이 되는 과정 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562519108
# [주번나] 윤사랑 비키니 자태.jpg이슈포토 http://dkbnews.donga.com/Board?no=15981&m=view&tcode=bbs_dkbnews
# 테니스치마 입은 아린이 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28360
# 미주야 너 몸매가 무시무시하다 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73829&page=1
# 피트니스 모델 서리나 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82428
# 설현 사뿐사뿐 newsbbs.dreamx.com/view.do?list_id=697893&page=1&bid=cnt_star
# BJ 리사 몸매 newsbbs.dreamx.com/view.do?list_id=697892&page=1&bid=cnt_humor
# 은하 bobaedream.co.kr/view?code=girl&No=850020&bm=1
# 김봉준 정지사유 팩트 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258394
# 흔한 익스트림 17학번 신입생 초고속 아싸행 (10) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258169
# (한국전쟁영웅) 연필대신 총을 든 학생유격대 "태극단"에 대해서 ARABOJA http://www.ilbe.com/10009783884
# -----------
# 나 혼자 산다 PD 인생 최고의 선택 instiz.net/pt?no=4735877&page=1&srt=3&k=&srd=1
# 모공 CCTV 공개 막은 부산경찰, 가해자들 나이까지 속였다 clien.net/service/board/park/11165818?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 마광수 교수 별세에 대해 추모의 글을 남긴 허지웅....jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768247021
# 외교왕 문재인 #데일리문 todayhumor.co.kr/board/view.php?table=bestofbest&no=361134&s_no=361134&page=1
# 뷔 진짜 말 이렇게 함? http://pann.nate.com/talk/338667850
# 월급 2백만원으로 혼자 먹고살기도 빠듯한 이유ㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259876
# 세종대왕이 임기중 가장 화났던 순간 http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008423944&m=view
#  [유머] 히오스.jpg http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808805
# 위례별초 페미니즘교사 규탄 학부모대표 일침 http://bbs.ruliweb.com/best/board/300143/read/34659524
# 바나나 먹고 찌뿐 사랑이 근황.jpg [54] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706911
# 왜 부산경찰은 사건을 축소하려 했나? bobaedream.co.kr/view?code=best&No=133083&vdate=
# 간지를 원하는가..?  http://www.ygosu.com/community/real_article/yeobgi/1244332/?page=0&frombest=Y
# 알고보면 한국 축구의 원흉.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138349604
# 자취버전 중국집 볶음밥 레시피.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562472188
# 패리스힐튼 개집.jpg이슈포토 http://dkbnews.donga.com/Board?no=15980&m=view&tcode=bbs_dkbnews
# 오마이걸 지호 뒤태 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28359
# 임나영 전신 짤 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73828&page=1
# 저도 자전거 참 좋아합니다 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82427
# 수영복 서리나 newsbbs.dreamx.com/view.do?list_id=697891&page=1&bid=cnt_star
# 무한도전을 증오하는 한 남자 newsbbs.dreamx.com/view.do?list_id=697890&page=1&bid=cnt_humor
# 시라이시 마이 bobaedream.co.kr/view?code=girl&No=850019&bm=1
# BJ 유은 근황(1) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258422
# 최근 임요환의 드랍쉽.gif(15) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258238
# 오늘날 여중생 폭행사건, 일진미화 만들어낸 근원 http://www.ilbe.com/10009207297
# -----------
# 결혼하면서 신랑이 데려온 강아지가 낯을 가려요 instiz.net/pt?no=4733771&page=1&srt=3&k=&srd=1
# 모공 MBC·KBS·YTN 징계자 명단 clien.net/service/board/park/11165140?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 메갈교사가 또 탄생했다.ㄷㄷ http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768205426
# 주진우 기자 페북, <농협이 소송을 한다고 하네요. MB 나와라!> todayhumor.co.kr/board/view.php?table=bestofbest&no=361133&s_no=361133&page=1
# 곰에게 걸리면 죽었다 생각하셈 http://pann.nate.com/talk/338669060
# 오늘 지하철에서 대박ㄷㄷㄷㅈ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259874
# 문재인 대통령 이 짤은 오랫동안 쓰일 듯.gif http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008433319&m=view
#  [유머] 미국인은 전부 총을 가지고 있나요? http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808774
# 어메이징 27살 공기관직원 일확천금의 꿈.jpg http://bbs.ruliweb.com/best/board/300143/read/34659339
# 펌)실종된 친동생을 찾습니다 [22] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706940
# ●●●부산여중생살인미수사건 JTBC 팩트체크 부탁드려요●●● bobaedream.co.kr/view?code=best&No=133065&vdate=
# 이 중 진심으로 빡친 사람은?  http://www.ygosu.com/community/real_article/yeobgi/1244357/?page=0&frombest=Y
# 장애인 테스트 하고가라... http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138354064
# 한국, 9회 연속 월드컵 진출…세계 6번째 대기록 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562453674
# [후방주의] 기어다니는 ㅊㅈ.gif이슈포토 http://dkbnews.donga.com/Board?no=15979&m=view&tcode=bbs_dkbnews
# 꽃아린 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28358
# 최설화 인스타 근황 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73827&page=1
# 김주희 독기 품은 스키니 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82426
# 유주 newsbbs.dreamx.com/view.do?list_id=697889&page=1&bid=cnt_star
# 대치동 국물 떡볶이 newsbbs.dreamx.com/view.do?list_id=697888&page=1&bid=cnt_humor
# 레이싱 모델 한채이 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850009&bm=1
# 홀스의 골드를 본 소풍반응 ㅋㅋ www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258234
# 편리해진 서울역.jpg(13) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258195
# 38아재  마누라가 아귀포 구워줬다. http://www.ilbe.com/10009797181
# -----------
# 삼성의 기술력ㅋㅋㅋㅋㅋㅋㅋㅋㅋ.jpg instiz.net/pt?no=4733901&page=1&srt=3&k=&srd=1
# 모공 여학생들의 폭력이 진짜 무서운게.... clien.net/service/board/park/11164630?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 손흥민의 압박.GIF http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768232016
# 새 개봉 영화 <저수지 게임> 무료표 이벤트  todayhumor.co.kr/board/view.php?table=bestofbest&no=361132&s_no=361132&page=1
# 요즘에 폭행,인성 관련해서 말인데(사진ㅇ) http://pann.nate.com/talk/338666988
# 팩트 폭격... slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259873
# 고현정 실검1위 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008426527&m=view
#  [유머] 자동차 이상과 현실 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808734
# 소년법 폐지에 대한 한 댓글의 의견 . jpg http://bbs.ruliweb.com/best/board/300143/read/34659164
# 대학교 축제에 간 여자.ssul [17] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706824
# 부산 여학생 폭행의 새로운 사실??? (팩트체크필요) bobaedream.co.kr/view?code=best&No=133060&vdate=
# 금요일에 절개눈매교정할거임ㄷ;  http://www.ygosu.com/community/real_article/fashion/51982/?page=0&frombest=Y
# 병원에서 의료드라마가 금지된이유.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138342573
# 한국 월드컵 본선 진출 당함!! theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562440913
# [주번나] 비키니 입은 운전녀.jpg이슈포토 http://dkbnews.donga.com/Board?no=15978&m=view&tcode=bbs_dkbnews
# 요염한 유라  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28356
# 치명적인 한승연 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73826&page=1
# 강수라 상의는 안입은걸로 친다 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82425
# 이효리 움짤스 newsbbs.dreamx.com/view.do?list_id=697887&page=1&bid=cnt_star
# 내 몸매 어때 newsbbs.dreamx.com/view.do?list_id=697886&page=1&bid=cnt_humor
# 레이싱 모델 김시연 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850008&bm=1
# BJ 이은혜누나 레전드 짤 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258403
# 다이소 회장의 삶(1) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258178
# 5,60년대 청소년 범죄 기사를 모아보았다(개씹스압) http://www.ilbe.com/10009753295
# -----------
# 어른눈에만 사이다로 보이는 장면 instiz.net/pt?no=4734856&page=1&srt=3&k=&srd=1
# 모공 '노무현 대통령 비하 호두과자 사건' 판결이 나왔습니다. clien.net/service/board/park/11165697?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 아이돌 군입대 레전드 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768143820
# 새로운 집이 생겼어요 ㅎ todayhumor.co.kr/board/view.php?table=bestofbest&no=361131&s_no=361131&page=1
# 상대방한테 이런 느낌든적있어? http://pann.nate.com/talk/338666289
# 작고 이쁜녀석 들어왔네요  slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259872
# 최설화 현실몸매.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008435959&m=view
#  [유머] 세상에서 제일 빨리 잠들기 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808729
# 어린아이에게 가차없는 매정한 의사선생님 . jpg http://bbs.ruliweb.com/best/board/300143/read/34659049
# 꽃중년으로 늙는 꿀팁.jpg [35] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706831
# 아니 밑에 G4렉스턴 차 못빠져나가는거 웃기네ㅋㅋ bobaedream.co.kr/view?code=best&No=133078&vdate=
# 병원에 입원해있는데 간호사들 너무매력있다 http://www.ygosu.com/community/real_article/yeobgi/1244380/?page=0&frombest=Y
# 축협이 히딩크 안뽑는 이유 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138354239
# 국민대 좆집남 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562303049
# 신정환 복귀 예능 예고.jpg이슈포토 http://dkbnews.donga.com/Board?no=15977&m=view&tcode=bbs_dkbnews
# 아주 예의가 바른 라붐 해인 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28355
# 소나무 디애나 우월한 비율 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73825&page=1
# 운동하는 여자는 사랑입니다 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82424
# 소녀시대 정규 6집 수영 티저 이미지 newsbbs.dreamx.com/view.do?list_id=697885&page=1&bid=cnt_star
# 도하하는 고양이.gif newsbbs.dreamx.com/view.do?list_id=697883&page=1&bid=cnt_humor
# 레이싱 모델 김하음 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850007&bm=1
# 아프리카tv 고2 여고생 bj www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258390
# 여자들이 선호하는 외제차 순위 (3) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258286
# 축구협회 "히딩크 선임 가능성 '제로'…신태용 본선까지"(종합2보) http://www.ilbe.com/10009760225
# -----------
# 아이돌과 배우의 차이 instiz.net/pt?no=4734818&page=1&srt=3&k=&srd=1
# 모공 [펌] 양성평등 징병 청원자에 대한 경향일보의 응대... clien.net/service/board/park/11164691?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 히딩크도 갱생못시킨 전설의 인물.gif http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=768322328
#  편부모 아이에게 함부로 불쌍하다 말 하지마세요. todayhumor.co.kr/board/view.php?table=bestofbest&no=361130&s_no=361130&page=1
# 추가)은행업무 좀 보게 오전반차 낸다고 했더니 http://pann.nate.com/talk/338669575
# 안철수 “허약한 외교안보팀 바꿀 때” slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259870
# 부산 폭행녀 근황.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008437072&m=view
#  [유머] 가난은 한꺼번에 찾아온다 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808599
# 22세 신예선수가 한국축구의 영웅으로 http://bbs.ruliweb.com/best/board/300143/read/34657059
# 살인을 막은 지식인 ..ㄷㄷ [30] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706852
# 별똥별을 봤어요~ bobaedream.co.kr/view?code=best&No=133073&vdate=
# 맨몸운동 3달 차입니다  http://www.ygosu.com/community/real_article/sports/27016/?page=0&frombest=Y
# 팔도 대통합 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138347696
# 위너 김진우팬이 지하철에 광고 걸어줬는데 난리남 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562270387
# 그리운 마리텔.jpg이슈포토 http://dkbnews.donga.com/Board?no=15976&m=view&tcode=bbs_dkbnews
# 양주 언냐를 움켜잡는 결경이 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28348
# 런온서울 2017 김연아 레깅스핏 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73824&page=1
# 남초에서 여친 삼고싶다는 몸매 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82423
# 러블리즈 케빵 지연,수정 newsbbs.dreamx.com/view.do?list_id=697882&page=1&bid=cnt_star
# 밤에보면 무서울듯...gif newsbbs.dreamx.com/view.do?list_id=697881&page=1&bid=cnt_humor
# 레이싱 모델 송이나 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850006&bm=1
# 고딩이라던데 이 ㅊㅈ 누군지 아는사람? www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258420
# 강릉 여자 중학생을 폭행한 이유 ㄷㄷㄷ(2) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258332
# '택시운전사' 드디어 5.18 민주화 유공자 신입회원으로 확정됨 http://www.ilbe.com/10008742176
# -----------
# 무한도전 스태프들도 미쳐있던 시기.jpgif instiz.net/pt?no=4735705&page=1&srt=3&k=&srd=1
# 모공 폭행피해 여중생 엄마 "가해학생·부모 용서 안할 것" clien.net/service/board/park/11165859?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 연예인을 실제로 본다면? http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767742763
# 안보정당 대표의 거수경례 todayhumor.co.kr/board/view.php?table=bestofbest&no=361129&s_no=361129&page=1
# 우리나라 여자들 진짜 http://pann.nate.com/talk/338667999
# 헐리웃에서 가장 유명한 한국계 배우 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259868
# 역대급 텀블러녀 몸매 http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008426806&m=view
#  [유머] 대한민국 축구 한장 요약 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808544
# 키작은 남자들 조금이라도 커보이는 비법.jpg http://bbs.ruliweb.com/best/board/300143/read/34658077
# 까칠남녀 은하선작가 커밍아웃 [87] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706838
# 펌 부산 가해자 한테 톡 왔습니다 bobaedream.co.kr/view?code=best&No=133058&vdate=
# 이야 에디큐브형님께서 하나만에!  http://www.ygosu.com/community/real_article/maple/9452/?page=0&frombest=Y
# 만석 기차 1인 2좌석 논란 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138345932
# [단독] "성관계하면 풀어줄게"…부산 여중생 집단폭행 새 증언 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562228031
# 순대 처음 본 이탈리아 사람 반응.jpg이슈포토 http://dkbnews.donga.com/Board?no=15975&m=view&tcode=bbs_dkbnews
# 모모.. ㅗㅜㅑ  댓글 : 4 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28346
# 황보미 前 SBS 아나운서 인스타 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73823&page=1
# 성진국 수영 대회 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82422
# 경례 하는 쯔위 ~ newsbbs.dreamx.com/view.do?list_id=697880&page=1&bid=cnt_star
# 미스 맥심걸 정영현 newsbbs.dreamx.com/view.do?list_id=697879&page=1&bid=cnt_humor
# 레이싱 모델 윤미진 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850005&bm=1
# 보조배터리를 모르는 서새봄 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258230
# 흔한 에휴 떠먹여 줘도 甲(1) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258559
# 부산 가해자 여중생 : 우리 애미 부자다, 합의하면 괜찮다. http://www.ilbe.com/10009768680
# -----------
# 미국에서 지금 난리난 사진.twt instiz.net/pt?no=4734281&page=1&srt=3&k=&srd=1
# 모공 ‘장외투쟁’ 한국당, “나가서 죽겠다” 제발 그렇게 해줘! clien.net/service/board/park/11164320?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 모모,,,쩐다 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767915818
# [펌] 햄버거 하니 떠오르는 기억 todayhumor.co.kr/board/view.php?table=bestofbest&no=361128&s_no=361128&page=1
# 방탄 건들다가 큰일난 엑스포츠 http://pann.nate.com/talk/338676352
# 회사에 여자 알바생이 있거든요... slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259865
# 안철수, "文정부 호남 홀대한다" 작심 비판 http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709060008434906&m=view
#  [유머] 월드컵 9회연속 진출!! http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808538
# (소녀전선) 공포의 굿즈 공모전.JPG http://bbs.ruliweb.com/best/board/300143/read/34657865
# 19대 대선 연령별 투표율 나왔네요 [58] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706951
# 축협 저보다 못한 신태용 감독 짤라야 하는 이유 bobaedream.co.kr/view?code=best&No=133057&vdate=
# 님들 아디다스 져지 필요한분??  http://www.ygosu.com/community/real_article/fashion/51989/?page=0&frombest=Y
# 집에서 영화관 느낌내고 싶을때 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138345045
# 소중이노세범이라는 전설의 짤 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562208525
# 고양이도 사람차별 한다.jpg이슈포토 http://dkbnews.donga.com/Board?no=15974&m=view&tcode=bbs_dkbnews
# 라붐 피지컬 대결  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28333
# 개그우먼 흔한 몸매 이한별 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73822&page=1
# 이런 오피 누나 좋아~ flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82421
# 여자친구 갓지 newsbbs.dreamx.com/view.do?list_id=697878&page=1&bid=cnt_star
# 난장판 인천공항 newsbbs.dreamx.com/view.do?list_id=697877&page=1&bid=cnt_humor
# 임나영 움짤 모음 bobaedream.co.kr/view?code=girl&No=850003&bm=1
# 배그 12시간 켠왕 도중에 아들한테 갱당한 풍... www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258302
# 인천에서도 터진 여고생 폭력 www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258261
# 축구계의 금수저 http://www.ilbe.com/10008318604
# -----------
# parsing ends
# sleep in 40s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4730275401f1> in <module>()
#     569     print('parsing ends')
#     570     print('sleep in 40s')
# --> 571     time.sleep(60)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
soup_flash2 = BeautifulSoup(req2, 'html.parser')

    #ruri
for title in soup_flash2.select('.subject a'): 
                    a = title.get('href')
                    print(title.text)
                    print(a)
# Out:
# 게시판 이용안내 및 게시물 삭제 안내
# ../bbs/board.php?bo_table=photo&wr_id=47065
# 코스트코녀 뒤태 앞태
# ../bbs/board.php?bo_table=photo&wr_id=82391
# 홍대에서 흔히 보는 처자 스키니핏
# ../bbs/board.php?bo_table=photo&wr_id=82390
# 모델 김우현 일상
# ../bbs/board.php?bo_table=photo&wr_id=82389
# 오피스텔에서 혼자 사는 아이
# ../bbs/board.php?bo_table=photo&wr_id=82388
# 문세림 대항마 봄수연 몸매
# ../bbs/board.php?bo_table=photo&wr_id=82387
# 바람직한 가정부 리나
# ../bbs/board.php?bo_table=photo&wr_id=82386
# 아낌없이 벗어던진 로드걸 한소율
# ../bbs/board.php?bo_table=photo&wr_id=82385
# 올여름 핫했던 비키니 모델 박다현
# ../bbs/board.php?bo_table=photo&wr_id=82384
# 튜닝이 필요없는 허윤미 볼륨
# ../bbs/board.php?bo_table=photo&wr_id=82383
# 김주희 세끈한 힙업
# ../bbs/board.php?bo_table=photo&wr_id=82382
# 요가 선생님 요염한 자세
# ../bbs/board.php?bo_table=photo&wr_id=82381
# 아재쇼 하나경 몸매 대단했지
# ../bbs/board.php?bo_table=photo&wr_id=82380
# 찰진 줄무늬 원피스 ㅊㅈ
# ../bbs/board.php?bo_table=photo&wr_id=82379
# 제복 끝판왕 후기녀
# ../bbs/board.php?bo_table=photo&wr_id=82378
# 비키니녀 .. 오빠 바나나 따줘
# ../bbs/board.php?bo_table=photo&wr_id=82377
# 이정도면 얼마나 당겨입은거야?
# ../bbs/board.php?bo_table=photo&wr_id=82376
# 하면서 정든다는 커플요가
# ../bbs/board.php?bo_table=photo&wr_id=82375
# 필라테스녀 몸부심
# ../bbs/board.php?bo_table=photo&wr_id=82374
# 극한직업 회장 여비서
# ../bbs/board.php?bo_table=photo&wr_id=82373
# 미스김 커피 한잔 부탁해! 하악~
# ../bbs/board.php?bo_table=photo&wr_id=82372
# 이게바로 길거리 공연의 매력
# ../bbs/board.php?bo_table=photo&wr_id=82371
# 실제 보면 완전설레일것같은 레이싱걸 처자
# ../bbs/board.php?bo_table=photo&wr_id=82370
# 2017 SPOEX 처자
# ../bbs/board.php?bo_table=photo&wr_id=82369
# 탈모가 걱정인 모델
# ../bbs/board.php?bo_table=photo&wr_id=82368
# 코스프레좋아한다는 처자
# ../bbs/board.php?bo_table=photo&wr_id=82367
