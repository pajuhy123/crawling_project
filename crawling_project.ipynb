# %%
# parser.py
import time
import logging
import requests
from bs4 import BeautifulSoup
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "mydjango.settings")
import django
django.setup()

###########
from blog.models import CrawlingData
###########
#data = requests.get("url")  
#print(data.encoding) // 키 값 알아내는 법,,//키==싸이트의 인코딩 방식
encoding_map = {'437': 'cp437',
 '646': 'ascii',
 '850': 'cp850',
 '852': 'cp852',
 '855': 'cp855',
 '857': 'cp857',
 '860': 'cp860',
 '861': 'cp861',
 '862': 'cp862',
 '863': 'cp863',
 '865': 'cp865',
 '866': 'cp866',
 '869': 'cp869',
 '8859': 'latin_1',
 '932': 'cp932',
 '936': 'gbk',
 '949': 'cp949',
 '950': 'cp950',
 'CP-GR': 'cp869',
 'CP-IS': 'cp861',
 'EBCDIC-CP-BE': 'cp500',
 'EBCDIC-CP-CH': 'cp500',
 'EBCDIC-CP-HE': 'cp424',
 'IBM037': 'cp037',
 'IBM039': 'cp037',
 'IBM424': 'cp424',
 'IBM437': 'cp437',
 'IBM500': 'cp500',
 'IBM775': 'cp775',
 'IBM850': 'cp850',
 'IBM852': 'cp852',
 'IBM855': 'cp855',
 'IBM857': 'cp857',
 'IBM860': 'cp860',
 'IBM861': 'cp861',
 'IBM862': 'cp862',
 'IBM863': 'cp863',
 'IBM864': 'cp864',
 'IBM865': 'cp865',
 'IBM866': 'cp866',
 'IBM869': 'cp869',
 'L1': 'latin_1',
 'L2': 'iso8859_2',
 'L3': 'iso8859_3',
 'L4': 'iso8859_4',
 'L5': 'iso8859_9',
 'L6': 'iso8859_10',
 'L8': 'iso8859_14',
 'U16': 'utf_16',
 'U7': 'utf_7',
 'U8': 'utf_8',
 'UTF': 'utf_8',
 'UTF-16BE': 'utf_16_be',
 'UTF-16LE': 'utf_16_le',
 'arabic': 'iso8859_6',
 'big5-hkscs': 'big5hkscs',
 'big5-tw': 'big5',
 'chinese': 'gb2312',
 'cp1361': 'johab',
 'cp154': 'ptcp154',
 'cp819': 'latin_1',
 'cp936': 'gbk',
 'csbig5': 'big5',
 'csiso2022jp': 'iso2022_jp',
 'csiso2022kr': 'iso2022_kr',
 'csiso58gb231280': 'gb2312',
 'csptcp154': 'ptcp154',
 'csshiftjis': 'shift_jis',
 'cyrillic': 'iso8859_5',
 'cyrillic-asian': 'ptcp154',
 'euc-cn': 'gb2312',
 'euccn': 'gb2312',
 'eucgb2312-cn': 'gb2312',
 'eucjis2004': 'euc_jis_2004',
 'eucjisx0213': 'euc_jisx0213',
 'eucjp': 'euc_jp',
 'euckr': 'euc_kr',
 'gb18030-2000': 'gb18030',
 'gb2312-1980': 'gb2312',
 'gb2312-80': 'gb2312',
 'greek': 'iso8859_7',
 'greek8': 'iso8859_7',
 'hebrew': 'iso8859_8',
 'hkscs': 'big5hkscs',
 'hz-gb': 'hz',
 'hz-gb-2312': 'hz',
 'hzgb': 'hz',
 'ibm1026': 'cp1026',
 'ibm1140': 'cp1140',
 'iso-2022-jp': 'iso2022_jp',
 'iso-2022-jp-1': 'iso2022_jp_1',
 'iso-2022-jp-2': 'iso2022_jp_2',
 'iso-2022-jp-2004': 'iso2022_jp_2004',
 'iso-2022-jp-3': 'iso2022_jp_3',
 'iso-2022-jp-ext': 'iso2022_jp_ext',
 'iso-2022-kr': 'iso2022_kr',
 'iso-8859-1': 'latin_1',
 'iso-8859-10': 'iso8859_10',
 'iso-8859-13': 'iso8859_13',
 'iso-8859-14': 'iso8859_14',
 'iso-8859-15': 'iso8859_15',
 'iso-8859-2': 'iso8859_2',
 'iso-8859-3': 'iso8859_3',
 'iso-8859-4': 'iso8859_4',
 'iso-8859-5': 'iso8859_5',
 'iso-8859-6': 'iso8859_6',
 'iso-8859-7': 'iso8859_7',
 'iso-8859-8': 'iso8859_8',
 'iso-8859-9': 'iso8859_9',
 'iso-ir-58': 'gb2312',
 'iso2022jp': 'iso2022_jp',
 'iso2022jp-1': 'iso2022_jp_1',
 'iso2022jp-2': 'iso2022_jp_2',
 'iso2022jp-2004': 'iso2022_jp_2004',
 'iso2022jp-3': 'iso2022_jp_3',
 'iso2022jp-ext': 'iso2022_jp_ext',
 'iso2022kr': 'iso2022_kr',
 'iso8859-1': 'latin_1',
 'jisx0213': 'euc_jis_2004',
 'korean': 'euc_kr',
 'ks_c-5601': 'euc_kr',
 'ks_c-5601-1987': 'euc_kr',
 'ks_x-1001': 'euc_kr',
 'ksc5601': 'euc_kr',
 'ksx1001': 'euc_kr',
 'latin': 'latin_1',
 'latin1': 'latin_1',
 'latin2': 'iso8859_2',
 'latin3': 'iso8859_3',
 'latin4': 'iso8859_4',
 'latin5': 'iso8859_9',
 'latin6': 'iso8859_10',
 'latin8': 'iso8859_14',
 'maccentraleurope': 'mac_latin2',
 'maccyrillic': 'mac_cyrillic',
 'macgreek': 'mac_greek',
 'maciceland': 'mac_iceland',
 'maclatin2': 'mac_latin2',
 'macroman': 'mac_roman',
 'macturkish': 'mac_turkish',
 'ms-kanji': 'cp932',
 'ms1361': 'johab',
 'ms932': 'cp932',
 'ms936': 'gbk',
 'ms949': 'cp949',
 'ms950': 'cp950',
 'mskanji': 'cp932',
 'pt154': 'ptcp154',
 's_jis': 'shift_jis',
 's_jisx0213': 'shift_jisx0213',
 'shiftjis': 'shift_jis',
 'shiftjis2004': 'shift_jis_2004',
 'shiftjisx0213': 'shift_jisx0213',
 'sjis': 'shift_jis',
 'sjis2004': 'shift_jis_2004',
 'sjis_2004': 'shift_jis_2004',
 'sjisx0213': 'shift_jisx0213',
 'u-jis': 'euc_jp',
 'uhc': 'cp949',
 'ujis': 'euc_jp',
 'us-ascii': 'ascii',
 'utf16': 'utf_16',
 'utf8': 'utf_8',
 'windows-1250': 'cp1250',
 'windows-1251': 'cp1251',
 'windows-1252': 'cp1252',
 'windows-1253': 'cp1253',
 'windows-1254': 'cp1254',
 'windows-1255': 'cp1255',
 'windows-1257': 'cp1257',
 'windows-1258': 'cp1258',
 'windows1256': 'cp1256',

}

def delete():
    a=CrawlingData.objects.all()
    a.delete()

def parse():
    ## 설정
    data={
               0 : { },#instiz
               1  : { },#clien
               2 :  { },#fmkorea
               3 : { },#ou
               4 : { },#pan
               5 : { }, #slr
               6 : { }, #mlb
               7 : { },#inben
               8 : { },#ruri
               9 : { },#utde
              10 : { },#bobe
               11 : { },#ygosu
               12 : { },#drip
               13 : { },#theqoo
               14 : { },#dogge
               15 : { }, #namsung
               16 : { }, #flash1
               17 : { }, #flash2
               18 : { }, #dream1
               19 : { }, #dream2
               20 : { }, #bobe2
               21 : { },#fomos1
               22 : { },#fomos2
               23 : { },#ilbe
    }
    #instiz
    req = requests.get('http://www.instiz.net/bbs/list.php?id=pt&srd=1&srt=3&k=&stype=&stype2=&stype3=').text
    soup_instiz = BeautifulSoup(req, 'html.parser')
    #clien
    req = requests.get('https://www.clien.net/service/group/board_all?od=T33').text
    soup_clien = BeautifulSoup(req, 'html.parser')
    #fmkorea
    req = requests.get('http://www.fmkorea.com/index.php?mid=best&listStyle=list&page=1').text
    soup_fmkorea = BeautifulSoup(req, 'html.parser')
    #ou
    req = requests.get('http://www.todayhumor.co.kr/board/list.php?table=bestofbest').text
    soup_ou = BeautifulSoup(req, 'html.parser')
    #pan
    req = requests.get('http://pann.nate.com/talk/ranking').text
    soup_pan = BeautifulSoup(req, 'html.parser')
    #slr
    req = requests.get('http://www.slrclub.com/bbs/zboard.php?id=best_article&category=1&setsearch=category').text
    soup_slr = BeautifulSoup(req, 'html.parser')
    #mlb
    req = requests.get('http://mlbpark.donga.com/mp/best.php?b=bullpen&m=view').text
    soup_mlb = BeautifulSoup(req, 'html.parser')
    #inben
    req = requests.get('http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&query=list&my=chu&category=%EC%9C%A0%EB%A8%B8&sort=PID&name=&subject=&content=&keyword=&orderby=&iskin=webzine').text
    soup_inben = BeautifulSoup(req, 'html.parser')
    #ruri
    req = requests.get('http://bbs.ruliweb.com/best/selection').text
    soup_ruri = BeautifulSoup(req, 'html.parser')
    #utde
    req = requests.get('http://web.humoruniv.com/board/humor/list.html?table=pds&st=day').text.encode(encoding_map['iso-8859-1'])
    soup_utde = BeautifulSoup(req, 'html.parser')
    #bobe
    req = requests.get('http://www.bobaedream.co.kr/list?code=best').text.encode(encoding_map['iso-8859-1'])
    soup_bobe = BeautifulSoup(req, 'html.parser')
    #ygosu
    req = requests.get('http://www.ygosu.com/community/real_article').text
    soup_ygosu = BeautifulSoup(req, 'html.parser')
    #drip
    req = requests.get('http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc').text
    soup_drip = BeautifulSoup(req, 'html.parser')
    #theqoo
    req = requests.get('http://theqoo.net/tbest?filter_mode=normal').text
    soup_theqoo = BeautifulSoup(req, 'html.parser')
    #dogge
    req = requests.get('http://dkbnews.donga.com/Board?p=1&tcode=bbs_dkbnews&s=date&key=&query=').text
    soup_dogge = BeautifulSoup(req, 'html.parser')
    #namsung
    req1= requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=ggolit').text
    soup_namsung1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=celeb').text
    soup_namsung2 = BeautifulSoup(req2, 'html.parser')
    #flash1
    req1= requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=star&page=2&page=1').text.encode(encoding_map['iso-8859-1'])
    soup_flash1 = BeautifulSoup(req1, 'html.parser')
    #flash2
    req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
    soup_flash2 = BeautifulSoup(req2, 'html.parser')
    #dream1
    req1= requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_star&is_image=Y').text
    soup_dream1 = BeautifulSoup(req1, 'html.parser')
    #dream2
    req2 = requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_humor&is_image=Y').text
    soup_dream2 = BeautifulSoup(req2, 'html.parser')
    #bobe2
    req1= requests.get('http://www.bobaedream.co.kr/list?code=girl&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=Subject&s_key=&level_no=&vdate=&type=list&page=1')
    req1 =req1.text.encode(encoding_map['iso-8859-1'])
    soup_bobe2 = BeautifulSoup(req1, 'html.parser')
    #fomos1
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=5').text
    soup_fomos1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=6').text
    soup_fomos2 = BeautifulSoup(req2, 'html.parser')
    #fomos2
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=3').text
    soup_fomos3 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=4').text
    soup_fomos4 = BeautifulSoup(req2, 'html.parser')
    #ilbe
    req1= requests.get('http://www.ilbe.com/ilbe').text
    soup_ilbe = BeautifulSoup(req1, 'html.parser')

    
    ## json에 저장
    #instiz
    for title in soup_instiz.select('#subject a'): 
                    a = title.get('href')
                    b=a.replace(".." , "instiz.net")
                    data[0][title.text] = b
    #clien
    n=0
    for title in soup_clien.select('.list-title .list-subject'): 
        if n == 0:
            n+=1
            continue
        else:
            a = title.get('href')
            if not a==None:
                    a='clien.net' + a
                    str=" ".join(title.text.strip().split())
                    data[1][str] = a
    #fmkorea
    for title in soup_fmkorea.select('.hx'): 
                    a = title.get('href')
                    data[2][title.text.strip()] = a
    #ou
    for title in soup_ou.select('.subject a'): 
                    a = title.get('href')
                    a='todayhumor.co.kr' + a
                    data[3][title.text] = a
    #pan
    for title in soup_pan.select('dt a'): 
                    a = title.get('href')
                    data[4][title.text] = a
    #slr
    for title in soup_slr.select('.sbj a'): 
                    a = title.get('href')
                    a='slrclub.com'+a
                    data[5][title.text] = a
    #mlb
    for title in soup_mlb.select('.t_left a'): 
                    a = title.get('href')
                    data[6][title.text] = a
    #inben
    for title in soup_inben.select('a.sj_ln'): 
                    a = title.get('href')
                    data[7][title.text] = a
    #ruri
    for title in soup_ruri.select('.subject a'): 
                    a = title.get('href')
                    data[8][title.text] = a
     #utde
    for title in soup_utde.select('a.brn3, a.brn2, a.brn1'): 
                    a = title.get('href')
                    a='web.humoruniv.com/board/humor/'+a
                    str=" ".join(title.text.strip().split())
                    data[9][str] = a
    #bobe
    for title in soup_bobe.select('a.bsubject'): 
                    a = title.get('href')
                    a='bobaedream.co.kr'+a
                    data[10][title.text] = a
    #ygosu
    for title in soup_ygosu.select('.tit a'): 
                    a = title.get('href')
                    data[11][title.text] = a
     #drip
    n=0
    for title in soup_drip.select('td.title a'): 
                if n == 0:
                      n+=1
                      continue
                else:
                     a = title.get('href')
                     data[12][title.text.strip()] = a
    #theqoo
    j=0 
    n=1
    x=1
    m=2
    for title in soup_theqoo.select('td.title a'): 
            if j < 8 :
                     j+=1
                     continue
            else:
                    if  n == m:
                            a=title.get('href')
                            a='theqoo.net'+a.replace('_comment','') 
                            n+=1
                            x+=1
                            m=2*x
                            data[13][title.text] = a
                            continue
                    else:
                            n+=1
                            continue
    #dogge
    for title in soup_dogge.select('.txt a'): 
                    a = title.get('href')
                    a ='http://dkbnews.donga.com/Board'+a
                    data[14][title.text.strip()] = a
    #namsung
    n=0
    for title in soup_namsung1.select('.list-subject a'): 
                    if n < 10:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                    else:
                          break                   
    for title in soup_namsung2.select('.list-subject a'): 
                     if n < 19:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                     else:
                          break
    #flash1
    n=0
    for title in soup_flash1.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[16][title.text]=a
     #flash2
    n=0
    for title in soup_flash2.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[17][title.text]=a
    #dream1
    n=1
    x=1
    m=2
    for title in soup_dream1.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[18][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #dream2
    n=1
    x=1
    m=2
    for title in soup_dream2.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[19][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #bobe2
    for title in soup_bobe2.select('.pl14 a.bsubject'): 
                    a=title.get('href')
                    a='bobaedream.co.kr'+a
                    data[20][title.text.strip()]=a
    #fomos1
    n=0
    for title in soup_fomos1.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos2.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    #fomos2
    n=0
    for title in soup_fomos3.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos4.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
     #ilbe
    n=0
    for title in soup_ilbe.select('.title a'): 
                    if n == 0:
                            n+=1
                            continue
                    else:
                            a=title.get('href')
                            data[23][title.text.strip()]=a


     #한꺼번에 DB 에  insert 하기 위한 함수
    
    def allsave(x):
            crawling = CrawlingData()
            list = [
                       [crawling.instiz, crawling.link_instiz], [crawling.clien, crawling.link_clien], [crawling.fmkorea, crawling.link_fmkorea],
                       [crawling.ou, crawling.link_ou] ,[crawling.pan, crawling.link_pan],[crawling.slr, crawling.link_slr],[crawling.mlb, crawling.link_mlb],
                       [crawling.inben, crawling.link_inben],[crawling.ruri, crawling.link_ruri],[crawling.utde, crawling.link_utde],[crawling.bobe, crawling.link_bobe],
                       [crawling.ygosu, crawling.link_ygosu],[crawling.drip, crawling.link_drip],[crawling.theqoo, crawling.link_theqoo],
                       [crawling.dogge, crawling.link_dogge],[crawling.namsung, crawling.link_namsung],[crawling.flash1, crawling.link_flash1],
                       [crawling.flash2, crawling.link_flash2],[crawling.dream1, crawling.link_dream1],[crawling.dream2, crawling.link_dream2],
                       [crawling.bobe2, crawling.link_bobe2],[crawling.fomos1, crawling.link_fomos1], [crawling.fomos2, crawling.link_fomos2],
                       [crawling.ilbe, crawling.link_ilbe]
                   ]
            for  i in range(len(data)):
                    n=0
                    for t,l in data[i].items():
                        if n == x:
                            list[i][0],list[i][1]= t,l
                            print(list[i][0],list[i][1])
                            break
                        else:
                            n+=1
                            continue
            
            CrawlingData(instiz=list[0][0],link_instiz=list[0][1], clien=list[1][0],link_clien=list[1][1], fmkorea=list[2][0],link_fmkorea=list[2][1],
                                  ou=list[3][0],link_ou=list[3][1], pan=list[4][0],link_pan=list[4][1], slr=list[5][0],link_slr=list[5][1], mlb=list[6][0],link_mlb=list[6][1],
                                  inben=list[7][0],link_inben=list[7][1], ruri=list[8][0],link_ruri=list[8][1], utde=list[9][0],link_utde=list[9][1],
                                  bobe=list[10][0],link_bobe=list[10][1], ygosu=list[11][0],link_ygosu=list[11][1], drip=list[12][0],link_drip=list[12][1],
                                  theqoo=list[13][0],link_theqoo=list[13][1], dogge=list[14][0],link_dogge=list[14][1], namsung=list[15][0],link_namsung=list[15][1],
                                  flash1=list[16][0],link_flash1=list[16][1], flash2=list[17][0],link_flash2=list[17][1], dream1=list[18][0],link_dream1=list[18][1],
                                  dream2=list[19][0],link_dream2=list[19][1], bobe2=list[20][0],link_bobe2=list[20][1], fomos1=list[21][0],link_fomos1=list[21][1],
                                  fomos2=list[22][0],link_fomos2=list[22][1], ilbe=list[23][0],link_ilbe=list[23][1],
                                    ).save() 
            
       ##DB에 저장
    for x in range(len(data[0])):
                    allsave(x)
                    print('-----------')
                    
    
while True:
    print('start parsing')
    delete()
    parse()
    print('parsing ends')
    print('sleep in 40s')
    time.sleep(60)
# Out:
# start parsing
# 부산 가해자 여중딩 친구의 의리.JPG instiz.net/pt?no=4733260&page=1&srt=3&k=&srd=1
# 모공 [릴레이27일차] 장충기문자 clien.net/service/board/park/11158404?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# ㅇㅎ) 콥아영.legend http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766322491
# 자유당이 청와대 간 이유(엠팍펌) todayhumor.co.kr/board/view.php?table=bestofbest&no=360862&s_no=360862&page=1
# 나 아파서 엄마가 포도 하나하나 다 까주심ㅜㅠㅠ http://pann.nate.com/talk/338647072
# 부산의 보행자 신호 jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259795
# 부산 여중생들 신상 텁니다 (사진업뎃) jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008341093&m=view
#  [유머] 부산 여중생 폭행사건에 분통터진 페미언냐 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808158
# 블리자드 : 이게 아닌데...;; http://bbs.ruliweb.com/best/board/300143/read/34648575
# 부산여중생폭행사건 관련경찰들 리얼 졷됨 ㅋㅋㅋㅋㅋ [90] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706580
# 2017년판 공업용 우지사건 bobaedream.co.kr/view?code=best&No=132953&vdate=
# 채식주의자 레전드 ..jpg  http://www.ygosu.com/community/real_article/yeobgi/1243845/?page=0&frombest=Y
# 하이고 내 마 고건 몰랐네!!!!! http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138233859
# 자식한테 팩폭당해서 입다문 부모충ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561828448
# 순대 처음 본 이탈리아 사람 반응.jpg이슈포토 http://dkbnews.donga.com/Board?no=15975&m=view&tcode=bbs_dkbnews
# 혼자서 난리남  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34269
# 이상적인 아내 몸매 유민 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73804&page=1
# 코스트코녀 뒤태 앞태 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82391
# 트와이스 사나와 미나의 대결 newsbbs.dreamx.com/view.do?list_id=697800&page=1&bid=cnt_star
# 해운대 엄지척 newsbbs.dreamx.com/view.do?list_id=697802&page=1&bid=cnt_humor
# 공떡 어플 사용후기 bobaedream.co.kr/view?code=girl&No=849994&bm=1
# 35-24-36 이라는 예지 몸매 클라스(3) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257586
# 오늘자 M공영방송사 파업식단.jpg www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257531
# 속보) 병원서 결국 숨져.... http://www.ilbe.com/10007319332
# -----------
# 부산 여중생 폭행사건, 2차 보복범죄 + 야간 흉기 집단폭행 instiz.net/pt?no=4732406&page=1&srt=3&k=&srd=1
# 모공 남자들이 여성 차별 문제에 발끈하는 이유는... clien.net/service/board/park/11157803?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 버스기사가 길 지나가는 시민 잡고 폭행 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766930646
# 흔한 술집 입구 골목에서 시스루 블라우스 갬성 착샷 todayhumor.co.kr/board/view.php?table=bestofbest&no=360861&s_no=360861&page=1
# 2인실 병동에 4인가족이 상주합니다. http://pann.nate.com/talk/338655217
# 폐쇄공포증 환자는 클릭금지.gif slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259794
# 25만원짜리 군화 샀습니다.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008333449&m=view
#  [유머] 친정가서 구박받는 주부 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808132
# 100km 20만원빵 낼 트라이 갑니다. http://bbs.ruliweb.com/best/board/300143/read/34647980
# 전교 꼴찌, 하버드 가다!.jpg [66] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706546
# 강릉폭행 가해자 부모 "거 애들끼리 얼굴좀 다친거 갖고" bobaedream.co.kr/view?code=best&No=132955&vdate=
# 이모든 상황을 알고있던 만화   http://www.ygosu.com/community/real_article/yeobgi/1243808/?page=0&frombest=Y
# 아이폰8 160예상 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138204696
# 현재 천조국 커뮤니티에서 난리난 한국 기자 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561797633
# 고양이도 사람차별 한다.jpg이슈포토 http://dkbnews.donga.com/Board?no=15974&m=view&tcode=bbs_dkbnews
# 복근甲  댓글 : 6 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34267
# 정글 나라 젖은 레깅스 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73803&page=1
# 홍대에서 흔히 보는 처자 스키니핏 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82390
# 눈화장 안한 아이린 newsbbs.dreamx.com/view.do?list_id=697797&page=1&bid=cnt_star
# 역대 가장 유쾌했던 시상식 newsbbs.dreamx.com/view.do?list_id=697798&page=1&bid=cnt_humor
# ㅂㅈ 노출녀 bobaedream.co.kr/view?code=girl&No=849993&bm=1
# 닉값 제대로 하는 bj www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257615
# 한국에서 가장 완벽한 래퍼(17) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257621
# 여교사 여중생 사건보면서 경찰들 병신같은점 http://www.ilbe.com/10007485841
# -----------
# [단독] '아육대', 파업 여파로 연기 아닌 무산 instiz.net/pt?no=4732706&page=1&srt=3&k=&srd=1
# 모공 지대추구의 덫... 부동산 보유세의 전조 (feat. 추미애) clien.net/service/board/park/11157941?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# fm) 현실반영 갓겜 FM http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766922317
# (부고) 마광수 교수 별세 todayhumor.co.kr/board/view.php?table=bestofbest&no=360860&s_no=360860&page=1
# 인연끊은 남동생이 결혼한다고 연락오네요 http://pann.nate.com/talk/338656068
# 2000원짜장면의비밀.jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259792
# 부산 가해자 신상 다 털렸네요.. 사진도 http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008330782&m=view
#  [유머] RPG 3대 유형 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808116
# 남자는 다 커도 애라는 말은 잘못됨 http://bbs.ruliweb.com/best/board/300143/read/34648128
# 극한직업 장윤정 매니저.jpg [33] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706570
# [대박만화] 헬조선의 민낯!!!! bobaedream.co.kr/view?code=best&No=132952&vdate=
# 도둑잡는 삼성  http://www.ygosu.com/community/real_article/yeobgi/1243847/?page=0&frombest=Y
# 지금까지 만들었던 커피잔 몇개 올려봅니다... http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138234382
# 갓세븐 잭슨, 日 활동 중단 선언…"향후 일정 6인 체제 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561770174
# 아이유가 기억하는 김연아.jpg이슈포토 http://dkbnews.donga.com/Board?no=15973&m=view&tcode=bbs_dkbnews
# 신입 여자 BJ  댓글 : 4 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34265
# 브레이브걸스 유정 쩍벌 하체 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73802&page=1
# 모델 김우현 일상 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82389
# 여자친구 신비 털 많네요 newsbbs.dreamx.com/view.do?list_id=697795&page=1&bid=cnt_star
# 포켓몬고 할때 휴대폰 충전 newsbbs.dreamx.com/view.do?list_id=697796&page=1&bid=cnt_humor
# 시구하는 유지  gif bobaedream.co.kr/view?code=girl&No=849992&bm=1
# 태연의 노출.jpg(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257806
# 창원 중국집 짜장면2000원 짬뽕3000원의 비밀(12) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257588
# 마광수 사건으로 일베에 좆유입 똥무식만 가득하다는걸 실감하네 http://www.ilbe.com/10007375399
# -----------
# 워너원 강다니엘 "어릴 때 못생겼다고 왕따 심하게 당해" 고백 instiz.net/pt?no=4732230&page=1&srt=3&k=&srd=1
# 모공 소년법.jpg clien.net/service/board/park/11157927?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 한국 축구 절망편 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766958701
# 청와대에 찾아간 자유한국당 그런데.. todayhumor.co.kr/board/view.php?table=bestofbest&no=360859&s_no=360859&page=1
# 식탐 쩌는 시누한테 머리채 잡혔어요. http://pann.nate.com/talk/338646781
# 아니 ㅅㅂ 국내 남자 존슨 평균이 9.6cm이면 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259791
# 창원 중국집 짜장면2000원 짬뽕3000원의 비밀.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008342278&m=view
#  [유머] 분노조절을 잘하는 직업 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807913
# 그것이 알고 싶다 출연료를 받지 않는 이유... http://bbs.ruliweb.com/best/board/300143/read/34647871
# 다시보는 흙수저갤의 가난그릴스.jpg [84] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706558
# 여성가족부 장관님께 물었습니다. bobaedream.co.kr/view?code=best&No=132949&vdate=
# 쯔위애교 보려다 당황하는 미드패왕 모모   http://www.ygosu.com/community/real_article/yeobgi/1243795/?page=0&frombest=Y
# 오스카 와일드의 명언들 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138167832
# 김혜수의 48번째(실화냐...) 생일 기념 각종 tmi  및 짤털 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561648082
# 이준기 팩폭.jpg이슈포토 http://dkbnews.donga.com/Board?no=15972&m=view&tcode=bbs_dkbnews
# 끌리는 검정브라  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34264
# 클라라 최근 풀고, 묶고, 쪼이고 ~ flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73801&page=1
# 오피스텔에서 혼자 사는 아이 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82388
# 또 오하영 부들부들 newsbbs.dreamx.com/view.do?list_id=697793&page=1&bid=cnt_star
# 신랑신부 입장 newsbbs.dreamx.com/view.do?list_id=697794&page=1&bid=cnt_humor
# 정채연 bobaedream.co.kr/view?code=girl&No=849991&bm=1
# 보정이 아니라면 정말 예술이다(4) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257810
# 정채연처럼 웰시코기형 하체를 소유한 블랙핑...(6) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257596
# 여성징병 최초 청원자 글씀 http://www.ilbe.com/10007478057
# -----------
# 이정도면 팀플 무임승차해도 인정.twt instiz.net/pt?no=4732587&page=1&srt=3&k=&srd=1
# 모공 안보이는 안보 장사꾼들.jpg clien.net/service/board/park/11159104?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 숨막히도록 남친을 구속하는 여친 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766632411
# 김장겸 말하는 꼬라지 보소 todayhumor.co.kr/board/view.php?table=bestofbest&no=360858&s_no=360858&page=1
# 방탄 뜻밖이다..+))움짤추가+))가사추가 http://pann.nate.com/talk/338653114
# 고기묵을때 취향 jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259789
# 유승옥 몸매 근황..........ㄷㄷㄷㄷㄷㄷ.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008330275&m=view
#  [유머] 씨름소녀를 만난 강호동 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807838
# 여자친구가 공무원입니다...jpg http://bbs.ruliweb.com/best/board/300143/read/34647733
# 역대급 미친 방송.jpg [118] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706559
# 부산 사하구 경찰관계자 bobaedream.co.kr/view?code=best&No=132948&vdate=
# 학폭을 조사하는 경찰의 태도(경험담) http://www.ygosu.com/community/real_article/yeobgi/1243825/?page=0&frombest=Y
# 한국 양궁 선수의 삶 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138206911
# 오늘 KBS 안녕하세요 레전드 발언 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561603524
# 남자들의 끝말잇기.jpg이슈포토 http://dkbnews.donga.com/Board?no=15971&m=view&tcode=bbs_dkbnews
# 나름 선별한 최근작품 two  댓글 : 4 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34260
# 오하영 흰티에 청바지면 충분해 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73800&page=1
# 문세림 대항마 봄수연 몸매 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82387
# 드레스 입은 둡나연 newsbbs.dreamx.com/view.do?list_id=697790&page=1&bid=cnt_star
# 스킨십 장난 아니었던 우결 커플 newsbbs.dreamx.com/view.do?list_id=697791&page=1&bid=cnt_humor
# 라임 bobaedream.co.kr/view?code=girl&No=849990&bm=1
# 권나라 강제노출.gif www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257902
# 우리나라 예능에 컴백한 슈가 아유미 와꾸 상태(2) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257606
# 32세 모쏠백수, 마광수선생님 돌아가시고 충격받아 혼술한다.noonmul http://www.ilbe.com/10007466092
# -----------
# 의외로 많이들 느낀다는 일본 여행 전/후 일본 음식에 대한 생각 차이.jpg instiz.net/pt?no=4733142&page=1&srt=3&k=&srd=1
# 모공 손혜원, 전문가인 제가 도와드리겠습니다. 라이브로.. clien.net/service/board/park/11158825?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 킹갓셀루 근황.gif http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766589265
# 우산 좀 씌워주실 수 있나요? 작성자입니다. todayhumor.co.kr/board/view.php?table=bestofbest&no=360857&s_no=360857&page=1
# 간호사는 전문직? 의사랑 동등, 협력 관계? http://pann.nate.com/talk/338655961
# 한국 핵폭탄 기술  ㅎㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259788
# 선제타격인듯 ㄷㄷㄷㄷㄷㄷㄷ http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008331415&m=view
#  [유머] 씬스틸러 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807837
# 탄두 중량 제한 없어지면 우리도 이제 이거 만들수 있는거야? http://bbs.ruliweb.com/best/board/300143/read/34647401
# 갓주민.jpg [39] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706513
# 기상청 근황 bobaedream.co.kr/view?code=best&No=132951&vdate=
# 일베 이씹쌔들은 와고에서 놀기만하고 일은제대로 안하냐? http://www.ygosu.com/community/real_article/yeobgi/1243844/?page=0&frombest=Y
# 순대 처음본 이탈리아 사람들 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138212551
# 방금 문 대통령이 트럼프랑 40분동안 통화하고 만든 대한민국 역대급 업적 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561585384
# 여친이랑 덴마크 가면 안되는 이유.jpg이슈포토 http://dkbnews.donga.com/Board?no=15970&m=view&tcode=bbs_dkbnews
# 분리수거녀  댓글 : 3 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34259
# AOA 찬미 검스각선미 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73799&page=1
# 바람직한 가정부 리나 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82386
# 트와이스 KNOCK KNOCK Someone else! newsbbs.dreamx.com/view.do?list_id=697785&page=1&bid=cnt_star
# 치약으로 양치질만 하진 않겠지? newsbbs.dreamx.com/view.do?list_id=697787&page=1&bid=cnt_humor
# 효성 bobaedream.co.kr/view?code=girl&No=849977&bm=1
# M자세.jpg(3) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257740
# [썰전] 범죄자 신상공개에 대한 유시민의 생각(13) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257601
# 요즘 여중생이 설치고 다니는이유 http://www.ilbe.com/10007501419
# -----------
# [단독] 방탄소년단, '아는형님' 출격..글로벌 대세 뜬다 instiz.net/pt?no=4731927&page=1&srt=3&k=&srd=1
# 모공 청와대 SNS 담당자 근황... clien.net/service/board/park/11158200?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 부모님이랑 말싸움할때 이기는 방법...jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766797798
# 화분이 깨져서 재활용 좀 해봤다 todayhumor.co.kr/board/view.php?table=bestofbest&no=360856&s_no=360856&page=1
# 버디인데 엑소 이번에 각 나온듯(인증0) http://pann.nate.com/talk/338646374
# 회사 앞건물 투신 사망 사고 ㅎㄷㄷㄷㄷ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259786
# 5시 30분 대구 공항 전투기 이륙 다수 http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008331373&m=view
#  [유머] 오마이갓 보틀! http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807760
# 뭔가가 낮이 익은 영화 '그것'의 광대 http://bbs.ruliweb.com/best/board/300143/read/34646554
# 이 시각 공익 갤러리.jpg [61] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706529
# 신동욱 "부산 여중생 폭행, 문재인정부 불신 도미노 현상" .. bobaedream.co.kr/view?code=best&No=132947&vdate=
# 내가 지금껏 봤던 야동 들 (실인게 보내줘) http://www.ygosu.com/community/real_article/secret/22294/?page=0&frombest=Y
# 마광수 교수님 시 하나 읽고 가라 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138228926
# 가수가 절대 하면 안되는 행동 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561458747
# 10월 2일 임시공휴일!.jpg이슈포토 http://dkbnews.donga.com/Board?no=15969&m=view&tcode=bbs_dkbnews
# 해변의 서양녀 피지컬 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34258
# 효은 전율 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73798&page=1
# 아낌없이 벗어던진 로드걸 한소율 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82385
# 정연이 눈곱 떼주는 사나 newsbbs.dreamx.com/view.do?list_id=697783&page=1&bid=cnt_star
# 나무로 만든 욕조 newsbbs.dreamx.com/view.do?list_id=697784&page=1&bid=cnt_humor
# 사나 bobaedream.co.kr/view?code=girl&No=849988&bm=1
# 도서관에서 로망 甲(2) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257764
# 오늘자 6시 내고향 몸매가 예사롭지 않은 미... www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257568
# ㅅㅂ 좆같네 진짜 http://www.ilbe.com/10007237908
# -----------
# 부산 가해자 정유미 빡치기 시작함.jpg instiz.net/pt?no=4732144&page=1&srt=3&k=&srd=1
# 모공 文대통령 "10월2일 공휴일 지정…국민들 휴식시간됐으면" clien.net/service/board/park/11158717?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 대한민국의 흔한 야동평가위원회 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766478512
# 대학교 다닐때 본 신점(점본 설을 보다가) todayhumor.co.kr/board/view.php?table=bestofbest&no=360855&s_no=360855&page=1
# 오늘 친정아빠가 외제차 뽑았는데.. 맘이 이상해 http://pann.nate.com/talk/338650405
# 대한민국평균.jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259784
# 친구가 돈을 빌려달라고 애원합니다....어떻게 해야될까요??? http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008329555&m=view
#  [유머] 주인님, 편지가 왔어요!! http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807738
# 지금 천조국에서 난리난 사진.JPG http://bbs.ruliweb.com/best/board/300143/read/34646542
# 우리나라 청소년 범죄 한짤 요약.jpg [55] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706588
# 며칠전 중고카메라 판다고 한사람 기억하시나요? 사기꾼이네요 bobaedream.co.kr/view?code=best&No=132941&vdate=
# 치안조무사가 화가난 이유  http://www.ygosu.com/community/real_article/yeobgi/1243829/?page=0&frombest=Y
# 스타크래프트 마피아 게임 두번째 이야기 ( 스압, 10mb ) http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138224504
# 부산 가해자 중딩들의 의리 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561435283
# [펌] 상대방을 미치게 하는 방법.jpg이슈포토 http://dkbnews.donga.com/Board?no=15968&m=view&tcode=bbs_dkbnews
# 야시시한 BJ  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34257
# 티파니 다리기럭지 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73797&page=1
# 올여름 핫했던 비키니 모델 박다현 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82384
# 트와이스 MLB 화보 찍었는데 분위기 쩌는 사나, 미나 newsbbs.dreamx.com/view.do?list_id=697781&page=1&bid=cnt_star
# 주차도우미 newsbbs.dreamx.com/view.do?list_id=697782&page=1&bid=cnt_humor
# 소혜 bobaedream.co.kr/view?code=girl&No=849987&bm=1
# 간만에 그라비아 컴백(?)한 시노자키 아이 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257543
# 야식 증후군에 걸린 여자(5) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257599
# 고 마광수 교수의 인생 조언 http://www.ilbe.com/10007386363
# -----------
# 요즘 소름돋는다고 난리난 타로챗봇 instiz.net/pt?no=4733809&page=1&srt=3&k=&srd=1
# 모공 #데일리문 대한민국 미사일주권회복 clien.net/service/board/park/11160385?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 숭의초 대기업 회장 손자 학교폭력 해피엔딩.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766449328
# 정말 채소가격이 엄청 올랐어요....ㅠㅠ todayhumor.co.kr/board/view.php?table=bestofbest&no=360854&s_no=360854&page=1
# 남편 베프의 약혼녀가 과거 왕따 가해자라면? http://pann.nate.com/talk/338652841
# ㅊㅈ 고민 조언 (조공 有) slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259782
# 한국의 앤 헤서웨이 ㄷㄷㄷ...jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008332201&m=view
#  [유머] 지옥보다 못한 한국 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807736
# 요즘 비비탄 총 매장 근황.jpg http://bbs.ruliweb.com/best/board/300143/read/34646170
# 진짜 우주 여신 베이커리 [58] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706538
# 조선족들의 의료보험 이용법 bobaedream.co.kr/view?code=best&No=132944&vdate=
# 충전하고 갑시다  http://www.ygosu.com/community/real_article/yeobgi/1243824/?page=0&frombest=Y
# 故 마광수 교수 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138226439
# 탈덕한 아이돌 더쿠가 남긴 말.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561369594
# 한편의 시같은 연세대학교 5행시.jpg이슈포토 http://dkbnews.donga.com/Board?no=15967&m=view&tcode=bbs_dkbnews
# 황금속옷  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34226
# 이제 그만 놓아 줍시다 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73796&page=1
# 튜닝이 필요없는 허윤미 볼륨 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82383
# 여자친구 애들 같은 다리가 좋음 newsbbs.dreamx.com/view.do?list_id=697779&page=1&bid=cnt_star
# 동안 3대장 newsbbs.dreamx.com/view.do?list_id=697780&page=1&bid=cnt_humor
# 남지현.gif bobaedream.co.kr/view?code=girl&No=849985&bm=1
# 속바지인척하는 팬티 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257766
# 엠마스톤 갈수록 이뻐짐.. www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257589
# 따봉북  드립력 (부산 여중생) http://www.ilbe.com/10007451464
# -----------
# 이것만 생각하면 9월 한달 개꿀 instiz.net/pt?no=4734191&page=1&srt=3&k=&srd=1
# 모공 요새 모공에 남혐조장 메갈 관련 트윗들 퍼나르는 분들 clien.net/service/board/park/11159760?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# [헤럴드경제] 신태용 “김영권은 주장, 분명히 출전한다” http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766669714
# "세무조사 반대"..종교인 과세 앞두고 목사들 집단 반발 todayhumor.co.kr/board/view.php?table=bestofbest&no=360853&s_no=360853&page=1
# 한국남자는.... 어쩔수 없이...... 혐오하게 되는 것 ... http://pann.nate.com/talk/338653185
# 이거 독사 맞쥬?? slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259780
# 이승엽 팬서비스 수준.swf http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008337328&m=view
#  [유머] 팬카페 영구차단짤 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807731
# 오바마가 말하는 외계인 http://bbs.ruliweb.com/best/board/300143/read/34646007
# 김희철 공익근무 당시에 매번 하던 짓;;;.jpg [61] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706518
# 2017년판 공업용 우지 사건 bobaedream.co.kr/view?code=best&No=132950&vdate=
# 저정치의 표본.jpg  http://www.ygosu.com/community/real_article/st/978227/?page=0&frombest=Y
# ㄹㄹ웹의 현실 근황.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138224813
# 여자화장실 최대의 난제 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561347185
# 비와이의 자신감.jpg이슈포토 http://dkbnews.donga.com/Board?no=15966&m=view&tcode=bbs_dkbnews
# 수신료의 가치  댓글 : 4 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34225
# 밸리댄스 배우는 바바후미카 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73795&page=1
# 김주희 세끈한 힙업 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82382
# 유주 몸매 좋음 newsbbs.dreamx.com/view.do?list_id=697776&page=1&bid=cnt_star
# 목소리가 독특한 BJ newsbbs.dreamx.com/view.do?list_id=697777&page=1&bid=cnt_humor
# 섹시한 하영이.gif bobaedream.co.kr/view?code=girl&No=849984&bm=1
# NS윤지 엉덩이 vs 김재경 엉덩이 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257675
# 아이린 착시현상(3) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257655
# 故마광수 교수 명언 보고가자. http://www.ilbe.com/10007338972
# -----------
# 저희조 PPT 망했는데 이거 저 엿맥이는거 맞죠???.gif instiz.net/pt?no=4732248&page=1&srt=3&k=&srd=1
# 모공 개기일식때 사람들이 카메라를 태워먹는 이유 clien.net/service/board/park/11159345?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 회식 가지 말라고 하는 여자친구.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766938793
# TIME지가 왜 문재인 대통령에게 협상가라는 타이틀을 걸어주었는가!! todayhumor.co.kr/board/view.php?table=bestofbest&no=360852&s_no=360852&page=1
# +)+) 여기 있는 애들 다 들어와봐 http://pann.nate.com/talk/338649806
# 카본 사이드미러로 교체 ㅎ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259779
# 부산 여중생 cctv 충격적이네요.. http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008331808&m=view
#  [유머] 어휴 매형 오시면 온다고 미리 말씀을 하.. http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807728
# 20년전 이세계물 http://bbs.ruliweb.com/best/board/300143/read/34645892
# 유병재가 민주에게 대시했던 이야기.jpg [20] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706550
# 홍준표 멘탈 탈탈 터는 기자 ㅋㅋㅋㅋㅋ.jpg bobaedream.co.kr/view?code=best&No=132935&vdate=
# 뉴스보는데 논리지린다. http://www.ygosu.com/community/real_article/yeobgi/1243827/?page=0&frombest=Y
# 당신의 캐릭터를 누렁이로 하시겠습니까? http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138226660
# VOCs 검출 생리대 목록 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561265716
# 부산 가해자 중딩들의 의리.jpg이슈포토 http://dkbnews.donga.com/Board?no=15965&m=view&tcode=bbs_dkbnews
# 라붐 피지컬 대결 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28333
# 쯔위 튼실한 하체 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73794&page=1
# 요가 선생님 요염한 자세 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82381
# 쯔위 유스케 나와서 레전드 찍은날 newsbbs.dreamx.com/view.do?list_id=697774&page=1&bid=cnt_star
# 남지현 최강배달부 newsbbs.dreamx.com/view.do?list_id=697775&page=1&bid=cnt_humor
# 후 후 후방 bobaedream.co.kr/view?code=girl&No=849983&bm=1
# 누나 저는 3초면 끝나는데 어떻하나요?(1) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257773
# 선릉역 짬뽕사건 케찹녀(11) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257552
# 이모든 상황을 알고 예견한 만화 ㅋㅋㅋ http://www.ilbe.com/10007468107
# -----------
# 번호 따 간 사람에게서 카톡이 왔는데 카톡프사가.twt instiz.net/pt?no=4732845&page=1&srt=3&k=&srd=1
# 모공 노회찬 의원 페북.jpg clien.net/service/board/park/11159363?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 키스씬 라인업 ㄷㄷ.gif http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766548721
# 해외 육아 꿀팁 todayhumor.co.kr/board/view.php?table=bestofbest&no=360851&s_no=360851&page=1
# +추가+헐 플레디스 강예빈말이야 http://pann.nate.com/talk/338646770
# 20대는 모르는 밀리터리 장비 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259778
# MBC 노조 출정식.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008341747&m=view
#  [유머] 명탐정 코난 희대의 병맛 에피소드 2 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807687
# 엌ㅋㅋ 나도 이세계 가면 개쩌는거 아니냐? ㅋㅋㅋ http://bbs.ruliweb.com/best/board/300143/read/34645635
# (스압)현재 인성 폐급이라고 욕먹는 안녕하세요 사연.jpg [162] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706628
# [빨간당] 오늘자 자유한국당!!! bobaedream.co.kr/view?code=best&No=132939&vdate=
# 레드벨벳, 우리곰 슬기 139 (노래는 'Luis Fonsi-Despacito')   http://www.ygosu.com/community/real_article/stars/92521/?page=0&frombest=Y
# 현실 여동생과의 카톡.JPG http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138224844
# 부산 여중생 폭행 가해자들이 만날 판사 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561224500
# 유병재가 최근 가장 기뻤을 때.jpg이슈포토 http://dkbnews.donga.com/Board?no=15964&m=view&tcode=bbs_dkbnews
# 쯔위를 찌르는 모모 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28332
# 술 좀 마신다는 경리 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73793&page=1
# 아재쇼 하나경 몸매 대단했지 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82380
# 최고로 살쪘을때 윤아 newsbbs.dreamx.com/view.do?list_id=697772&page=1&bid=cnt_star
# 청와대에서 시계가 더 이상 제작되지 않는 이유 .jpg newsbbs.dreamx.com/view.do?list_id=697773&page=1&bid=cnt_humor
# 후)우리나라에 정말 이런 여성들이 존재하는군요 bobaedream.co.kr/view?code=girl&No=849981&bm=1
# 8년간 절대 공개하지 않았던 안수연의 비키니(2) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257867
# 떡치는 소리에 빡친 이웃주민 www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257581
# 한녀 당해버린 페이스북 댓글 대참사 http://www.ilbe.com/10007455406
# -----------
# 이국주가 나혼자산다에서 하차한 이유.jpg instiz.net/pt?no=4733321&page=1&srt=3&k=&srd=1
# 모공 현 상황에서 우리 입장에서 확실한 신의 한수였던것은.. clien.net/service/board/park/11158315?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# [공홈] 라리가는 UEFA의 PSG에 대한 FFP 위반 조사 개시에 박수갈채를 보냅니다 - 맨시티에 대해서도 동일한 조사 요청 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766168056
# 한국은 정말 작은나라인가? 유럽과 비교해보자! todayhumor.co.kr/board/view.php?table=bestofbest&no=360850&s_no=360850&page=1
# YG JYP 댄스 배틀 레전드 모음 http://pann.nate.com/talk/338656339
# 그간 알아본 SUV 종류... slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259777
# 위대한탄생1 백청강 어떻게 우승한건가요 ㅋㅋㅋㅋ http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008332018&m=view
#  [유머] [스압]웃긴대학주간답글Best! [17... http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807665
# 어제자 조낸 불쌍하게 죽은 일본남자.jpg http://bbs.ruliweb.com/best/board/300143/read/34645634
# 여동생 괴롭히기 [30] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706634
# 표창원 "부산 여중생들, 성인이면 살인미수 적용" bobaedream.co.kr/view?code=best&No=132937&vdate=
# 애 누군지좀..  http://www.ygosu.com/community/real_article/yeobgi/1243781/?page=0&frombest=Y
# 프로의식 없는 직업.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138208829
# 부산여중생 폭행사건 가해자 윤혜린 사과문 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561216449
# 휴식시간의 장인.jpg이슈포토 http://dkbnews.donga.com/Board?no=15963&m=view&tcode=bbs_dkbnews
# 몸푸는 CLC 장승연 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28329
# 인기가요 출근길 청하 찢청 패션 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73792&page=1
# 찰진 줄무늬 원피스 ㅊㅈ flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82379
# 모델 김주희 청바지핏 newsbbs.dreamx.com/view.do?list_id=697770&page=1&bid=cnt_star
# 현재 지구에서 가장 강한 주먹을 가진 남자 newsbbs.dreamx.com/view.do?list_id=697771&page=1&bid=cnt_humor
# 후방 테스트 bobaedream.co.kr/view?code=girl&No=849982&bm=1
# ASL 시즌4 슬픈 철구의 뒷모습 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257767
# 24살 뱃남 처자 vs 40살 한국 처자(7) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257544
# 마 고광수센세의 자살이유를 ARABOJI http://www.ilbe.com/10007369255
# -----------
# 살인을 막은 지식인 instiz.net/pt?no=4733041&page=1&srt=3&k=&srd=1
# 모공 26만9500명을 위한 LG-V30 핸즈온 영상입니다. clien.net/service/board/park/11157701?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 펨코 시작한지도 어언 4달 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766925225
# 30대 여성 데일리룩(:시스루원피스) todayhumor.co.kr/board/view.php?table=bestofbest&no=360849&s_no=360849&page=1
# 주먹이운다 레전드 남학생의 고백 http://pann.nate.com/talk/338656335
# 지금 이차 중고로사면 후회하죠? slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259776
# 송은정 작가 페이스북.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008335675&m=view
#  [유머] 살면서 제일 길게 해 본 데이트 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807655
# 아빠, 저 누나 너무 이뿌다 하아하아... http://bbs.ruliweb.com/best/board/300143/read/34644625
# 갓카오뱅크가 대안인 이유.jpg [67] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706593
# ◆◆◆◆ 강릉 폭행사건 가해자 공개합니다. ◆◆◆◆ bobaedream.co.kr/view?code=best&No=132945&vdate=
# 사모님 알바 카톡왔길래 장난쳐봄 ㅋㅋㅋㅋㅋ  http://www.ygosu.com/community/real_article/yeobgi/1243822/?page=0&frombest=Y
# 故 마광수 교수와 관련된 일화.JPG http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138225010
# 【 왕덬 : 4덬으로 쓴 댓글 참조 + 로리무새 로리타령 딴데가서 쳐하세욘 】 여시하는사람있는데 티비에 아이유나오면 갑자기 어 로리유다 ㅇㅈㄹ함 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561208502
# 흔한 빨대 꽂기.jpg이슈포토 http://dkbnews.donga.com/Board?no=15962&m=view&tcode=bbs_dkbnews
# 탈아이돌 여배우클라스 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28328
# 라붐 율희의 행적.. flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73791&page=1
# 제복 끝판왕 후기녀 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82378
# 20대 최고의 섹시 가수 newsbbs.dreamx.com/view.do?list_id=697768&page=1&bid=cnt_star
# 이걸 실제로 쓰다니 ㄷㄷ newsbbs.dreamx.com/view.do?list_id=697767&page=1&bid=cnt_humor
# 치어리더 강윤이 bobaedream.co.kr/view?code=girl&No=849979&bm=1
# 팬이 준 선물 개봉하다가 영정 당할 뻔(1) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257776
# 반박불가 2017년 최고의 게임(14) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257536
# 문재앙이는 이번 여중딩 사건 관심없다. http://www.ilbe.com/10007427095
# -----------
# 백현 인스타_(f.루머 피드백) instiz.net/pt?no=4734130&page=1&srt=3&k=&srd=1
# 모공 '택시운전사' 김사복-힌츠페터, 함께 찍은 사진 확인 clien.net/service/board/park/11159284?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 부산 사하구 경찰관계자 답변ㅋㅋㅋㅋㅋ http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766911486
# 이승훈님의 서경덕교수 cbs 노컷뉴스 인터뷰 관련...뉴스 해설 todayhumor.co.kr/board/view.php?table=bestofbest&no=360848&s_no=360848&page=1
# 온유랑 박환희 사귀는거 진짜인가? http://pann.nate.com/talk/338648823
# 레이 차주의 당황스러움 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259775
# pic) 에릭남 동생과 결혼할 여친........ㄷㄷㄷ.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008330104&m=view
#  [유머] 캡틴 vs 스타로드 2탄 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807651
# 해외 육아 꿀팁.jpg http://bbs.ruliweb.com/best/board/300143/read/34644514
# 나 진짜 미친놈인가봐ㅋㅋㅋㅋㅋㅋㅋㅋㅋ [24] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706556
# 어제자 최여진 페미 발언 bobaedream.co.kr/view?code=best&No=132942&vdate=
# 10월달에 '바람의검심' 재연재.jpg  http://www.ygosu.com/community/real_article/yeobgi/1243823/?page=0&frombest=Y
# 종교인들 근황 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138200951
# 어릴때 못생겼다고 왕따당했다는 강다니엘 과사 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561119464
# 체인스모커스 공연에 현대카드 부회장 페북.jpg이슈포토 http://dkbnews.donga.com/Board?no=15961&m=view&tcode=bbs_dkbnews
# 딱 보기 좋은 은하 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28326
# 수지 누나 이 자세로는 오래 못버텨! flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73790&page=1
# 비키니녀 .. 오빠 바나나 따줘 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82377
# 실물느낌 유라 뒤태 newsbbs.dreamx.com/view.do?list_id=697766&page=1&bid=cnt_star
# 풋샵하는데도 리듬과 박자가 중요해!! newsbbs.dreamx.com/view.do?list_id=697765&page=1&bid=cnt_humor
# 수애 bobaedream.co.kr/view?code=girl&No=849978&bm=1
# 김봉준 채보미랑 곧 헤어질꺼같은 이유 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257769
# 모르는 여자와 카톡을 했다(2) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257644
# 부산의 운전 의식을 알아보자......jpg http://www.ilbe.com/10007365869
# -----------
# 어릴 때 피아노학원 다닐때 은근 겪어봄 甲 instiz.net/pt?no=4732691&page=1&srt=3&k=&srd=1
# 모공 (속보)檢, '댓글공작' 국정원 퇴직 직원 2명 구속영장 청구 clien.net/service/board/park/11159974?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# (유에파) 첼시 챔스 명단 (코블리 제외) http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766302439
# 이시각  공익갤러리 todayhumor.co.kr/board/view.php?table=bestofbest&no=360847&s_no=360847&page=1
# 부산폭행 가해자한테 페메보냄 http://pann.nate.com/talk/338651285
# 차에 이딴 스티커 왜 쳐붙이나요? slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259774
# (충격,혐오사진주의)부산여중생사건 피해자지인이 올린 글.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008337847&m=view
#  [유머] 어느날 별이 내게 다가와 말을 걸었다.... http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807603
# 슬램덩크에서 잘 몰랐던 사실 Top 7 http://bbs.ruliweb.com/best/board/300143/read/34643499
# 부산 여중생 폭행 가해자들이 만날 판사 [53] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706581
# ■실검1위 강릉폭행(삭제되서 재업) bobaedream.co.kr/view?code=best&No=132931&vdate=
# 똥지려보신분ㅋ  http://www.ygosu.com/community/real_article/yeobgi/1243819/?page=0&frombest=Y
# 열도의 로맨틱 만화 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138213355
# 어머니가 차려주신 밥상 엎어버리는 46세 아들.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561060351
# [펌] 곧 영화관 알바하는데 손님인 척 해줄래?.jpg이슈포토 http://dkbnews.donga.com/Board?no=15960&m=view&tcode=bbs_dkbnews
# 수영장의 손나  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28319
# 혜리 이 정도면 말근육 허벅 ? flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73789&page=1
# 이정도면 얼마나 당겨입은거야? flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82376
# 디스패치가 포기한 연예인ㅋㅋㅋㅋㅋ newsbbs.dreamx.com/view.do?list_id=697764&page=1&bid=cnt_star
# 국립국어원 구내식당밥.jpg newsbbs.dreamx.com/view.do?list_id=697763&page=1&bid=cnt_humor
# 소미 bobaedream.co.kr/view?code=girl&No=849976&bm=1
# 입대 예고 김택용 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257774
# 바로 연예인 데뷔해도 될것같은 이번주 대학... www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257670
# 마광수 교수 ㅋㅋ이오l수 디스 시원하게 했었네 ㅋㅋㅋㅋ http://www.ilbe.com/10007432382
# -----------
# 부산 여중생 폭행 cctv...gif instiz.net/pt?no=4731994&page=1&srt=3&k=&srd=1
# 모공 연봉 안물안궁입니다. clien.net/service/board/park/11160388?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 베스티 유지, 다혜 탈퇴 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766756533
# 털 밀었더니 옆에 안옴 todayhumor.co.kr/board/view.php?table=bestofbest&no=360846&s_no=360846&page=1
# 글 내려요 http://pann.nate.com/talk/338646639
# 제 차에 끝판왕 튜닝했습니다. slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259772
# [소시]소녀시대 태연 UR http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008331100&m=view
#  [유머] 아무리 고문을해도 입을 열지 않는군 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807596
# 부산 신세계에는 찜찔방이 있다. http://bbs.ruliweb.com/best/board/300143/read/34643477
# 여성 징병 청원...네이트...반응....jpg [68] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706544
# 주진우 기자 페북, <이명박 가카께서> bobaedream.co.kr/view?code=best&No=132934&vdate=
# 회사 여직원의 다짐.jpg  http://www.ygosu.com/community/real_article/yeobgi/1243793/?page=0&frombest=Y
# 스타크래프트 마피아게임 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138219549
# 부산 가해자 정유미 빡치기 시작함 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561059266
# 공부할때 집중 잘되는 음악(후기).jpg이슈포토 http://dkbnews.donga.com/Board?no=15959&m=view&tcode=bbs_dkbnews
# 옷입는 태연  댓글 : 3 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28318
# 작정하고 젖은 현아 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73788&page=1
# 하면서 정든다는 커플요가 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82375
# 60대 엄마 ㄷㄷㄷ newsbbs.dreamx.com/view.do?list_id=697762&page=1&bid=cnt_star
# 주꾸미회 먹은 40대 사망.jpg newsbbs.dreamx.com/view.do?list_id=697761&page=1&bid=cnt_humor
# 정순주 아나 bobaedream.co.kr/view?code=girl&No=849975&bm=1
# ASL3/4 본선 최종 진출자/예선 참가자 비교.JPG(1) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257696
# 도대체 인생을 어떻게 살아야 친누나한테 이...(4) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257622
# (마교수님 업적) 마광수 교수님 아니었으면 윤동주는 듣보잡 시인이었다! http://www.ilbe.com/10007377325
# -----------
# 부산 여중생 폭행사건에 대한 황찬성 트윗ㄷㄷㄷ instiz.net/pt?no=4733760&page=1&srt=3&k=&srd=1
# 모공 미국에선 트럼프가 한국 무시했다고 역으로 까이는 중인데 clien.net/service/board/park/11158694?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 우원재 3위 탈락이 씹다행인 이유.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766104811
# 문재인대통령님 트윗입니다.  todayhumor.co.kr/board/view.php?table=bestofbest&no=360845&s_no=360845&page=1
# 제가 며느리의 기본도리를 못하는건가요? http://pann.nate.com/talk/338651986
# 세차 맡겼는데  엔진룸에 물을 마구마구 .. slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259771
# pic) 수영복 입은 안젤리나......ㄷㄷㄷ.....jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008330374&m=view
#  [유머] 흙수저 자취 2년차 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807563
# 모바일 오토겜 돌리는 이유 http://bbs.ruliweb.com/best/board/300143/read/34641549
# 반장 불꺼.jpg [33] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706560
# 밥처먹기전에 일하고 밥을 처먹으라고 bobaedream.co.kr/view?code=best&No=132930&vdate=
# 닥터 슬럼프 봤다ㅋㅋㅋㅋㅋㅋ  http://www.ygosu.com/community/real_article/animation/199181/?page=0&frombest=Y
# 2000원 짜장면의 비밀 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138220297
# 부산 여중생 폭행 가해자 2명 아니고 4명임 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561035595
# 여자친구가 공무원입니다만.jpg이슈포토 http://dkbnews.donga.com/Board?no=15958&m=view&tcode=bbs_dkbnews
# 나라의 헬로비너스 활동  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28317
# 김정민 화이팅 넘치는 레깅스 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73787&page=1
# 필라테스녀 몸부심 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82374
# 문채원 각선미 newsbbs.dreamx.com/view.do?list_id=697760&page=1&bid=cnt_star
# 전설의 무개념 할배 newsbbs.dreamx.com/view.do?list_id=697758&page=1&bid=cnt_humor
# 현아 bobaedream.co.kr/view?code=girl&No=849974&bm=1
# 실력보다 근성으로 승부보는 스트리머.gif www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257645
# 슬램덩크에서 많은 사람들이 몰랐던 사실 Top 7	(3) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257529
# 마광수 시 레전드 http://www.ilbe.com/10007389208
# -----------
# 인생이 부정적이면서 긍정적인 유병재ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ instiz.net/pt?no=4733192&page=1&srt=3&k=&srd=1
# 모공 주진우 기자 페북 clien.net/service/board/park/11159004?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 위엄돋는 피자배달원.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766660596
# 아직까지 "안녕" 곡 경례각 살아있는 우리 서짓뚜 하사님 todayhumor.co.kr/board/view.php?table=bestofbest&no=360844&s_no=360844&page=1
# 어린이집 엄마랑 싸웠어요. http://pann.nate.com/talk/338656579
# 30대 극초반입니다 오늘 입은 옷인데 평가 부탁드립니다.jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259770
# 사하구 여중딩이 곧 만날 사람.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709040008331115&m=view
#  [유머] 효리가 구라에게 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807556
# [2ch] 한국인 "남녀평등을 외칠거면 여성에게도 병역의무를 지게 해야한다" 반응 http://bbs.ruliweb.com/best/board/300143/read/34640679
# 웃대에서 광고하는 향수 절대 사지마라 [55] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706587
# ◆◆◆ 강릉 폭행사건 가해자 공개합니다.. ◆◆◆ bobaedream.co.kr/view?code=best&No=132933&vdate=
# 20번째 클럽선수 오피셜  http://www.ygosu.com/community/real_article/ffonline2/64738/?page=0&frombest=Y
# 한국 만화 근황 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138209663
# [부산 여중생 폭행]현직 경찰들 “구속 불투명, 처벌 안 될 것” theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561022591
# 흔한 커플 카톡.jpg이슈포토 http://dkbnews.donga.com/Board?no=15957&m=view&tcode=bbs_dkbnews
# 미국 왔어유  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28316
# 프리스틴 은우 튀는 자슴감 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73786&page=1
# 극한직업 회장 여비서 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82373
# 손나은 레깅스 newsbbs.dreamx.com/view.do?list_id=697757&page=1&bid=cnt_star
# 학교 폭력 신고 상담원 수준 newsbbs.dreamx.com/view.do?list_id=697756&page=1&bid=cnt_humor
# '맨 다리보다 치명적이죠?'…치어리더, 스타킹으로 섹시 업 bobaedream.co.kr/view?code=girl&No=849964&bm=1
# 아프리카 종합 와꾸 원탑 남여캠(3) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257771
# 오늘자 어메이징 한녀 (4) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257519
# 마광수의 무시무시함.horror http://www.ilbe.com/10007363556
# -----------
# parsing ends
# sleep in 40s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-4730275401f1> in <module>()
#     569     print('parsing ends')
#     570     print('sleep in 40s')
# --> 571     time.sleep(60)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
soup_flash2 = BeautifulSoup(req2, 'html.parser')

    #ruri
for title in soup_flash2.select('.subject a'): 
                    a = title.get('href')
                    print(title.text)
                    print(a)
# Out:
# 게시판 이용안내 및 게시물 삭제 안내
# ../bbs/board.php?bo_table=photo&wr_id=47065
# 코스트코녀 뒤태 앞태
# ../bbs/board.php?bo_table=photo&wr_id=82391
# 홍대에서 흔히 보는 처자 스키니핏
# ../bbs/board.php?bo_table=photo&wr_id=82390
# 모델 김우현 일상
# ../bbs/board.php?bo_table=photo&wr_id=82389
# 오피스텔에서 혼자 사는 아이
# ../bbs/board.php?bo_table=photo&wr_id=82388
# 문세림 대항마 봄수연 몸매
# ../bbs/board.php?bo_table=photo&wr_id=82387
# 바람직한 가정부 리나
# ../bbs/board.php?bo_table=photo&wr_id=82386
# 아낌없이 벗어던진 로드걸 한소율
# ../bbs/board.php?bo_table=photo&wr_id=82385
# 올여름 핫했던 비키니 모델 박다현
# ../bbs/board.php?bo_table=photo&wr_id=82384
# 튜닝이 필요없는 허윤미 볼륨
# ../bbs/board.php?bo_table=photo&wr_id=82383
# 김주희 세끈한 힙업
# ../bbs/board.php?bo_table=photo&wr_id=82382
# 요가 선생님 요염한 자세
# ../bbs/board.php?bo_table=photo&wr_id=82381
# 아재쇼 하나경 몸매 대단했지
# ../bbs/board.php?bo_table=photo&wr_id=82380
# 찰진 줄무늬 원피스 ㅊㅈ
# ../bbs/board.php?bo_table=photo&wr_id=82379
# 제복 끝판왕 후기녀
# ../bbs/board.php?bo_table=photo&wr_id=82378
# 비키니녀 .. 오빠 바나나 따줘
# ../bbs/board.php?bo_table=photo&wr_id=82377
# 이정도면 얼마나 당겨입은거야?
# ../bbs/board.php?bo_table=photo&wr_id=82376
# 하면서 정든다는 커플요가
# ../bbs/board.php?bo_table=photo&wr_id=82375
# 필라테스녀 몸부심
# ../bbs/board.php?bo_table=photo&wr_id=82374
# 극한직업 회장 여비서
# ../bbs/board.php?bo_table=photo&wr_id=82373
# 미스김 커피 한잔 부탁해! 하악~
# ../bbs/board.php?bo_table=photo&wr_id=82372
# 이게바로 길거리 공연의 매력
# ../bbs/board.php?bo_table=photo&wr_id=82371
# 실제 보면 완전설레일것같은 레이싱걸 처자
# ../bbs/board.php?bo_table=photo&wr_id=82370
# 2017 SPOEX 처자
# ../bbs/board.php?bo_table=photo&wr_id=82369
# 탈모가 걱정인 모델
# ../bbs/board.php?bo_table=photo&wr_id=82368
# 코스프레좋아한다는 처자
# ../bbs/board.php?bo_table=photo&wr_id=82367
