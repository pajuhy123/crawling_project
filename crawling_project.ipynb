# %%
# parser.py
import time
import logging
import requests
from bs4 import BeautifulSoup
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "mydjango.settings")
import django
django.setup()

###########
from blog.models import CrawlingData
###########
#data = requests.get("url")  
#print(data.encoding) // 키 값 알아내는 법,,//키==싸이트의 인코딩 방식
encoding_map = {'437': 'cp437',
 '646': 'ascii',
 '850': 'cp850',
 '852': 'cp852',
 '855': 'cp855',
 '857': 'cp857',
 '860': 'cp860',
 '861': 'cp861',
 '862': 'cp862',
 '863': 'cp863',
 '865': 'cp865',
 '866': 'cp866',
 '869': 'cp869',
 '8859': 'latin_1',
 '932': 'cp932',
 '936': 'gbk',
 '949': 'cp949',
 '950': 'cp950',
 'CP-GR': 'cp869',
 'CP-IS': 'cp861',
 'EBCDIC-CP-BE': 'cp500',
 'EBCDIC-CP-CH': 'cp500',
 'EBCDIC-CP-HE': 'cp424',
 'IBM037': 'cp037',
 'IBM039': 'cp037',
 'IBM424': 'cp424',
 'IBM437': 'cp437',
 'IBM500': 'cp500',
 'IBM775': 'cp775',
 'IBM850': 'cp850',
 'IBM852': 'cp852',
 'IBM855': 'cp855',
 'IBM857': 'cp857',
 'IBM860': 'cp860',
 'IBM861': 'cp861',
 'IBM862': 'cp862',
 'IBM863': 'cp863',
 'IBM864': 'cp864',
 'IBM865': 'cp865',
 'IBM866': 'cp866',
 'IBM869': 'cp869',
 'L1': 'latin_1',
 'L2': 'iso8859_2',
 'L3': 'iso8859_3',
 'L4': 'iso8859_4',
 'L5': 'iso8859_9',
 'L6': 'iso8859_10',
 'L8': 'iso8859_14',
 'U16': 'utf_16',
 'U7': 'utf_7',
 'U8': 'utf_8',
 'UTF': 'utf_8',
 'UTF-16BE': 'utf_16_be',
 'UTF-16LE': 'utf_16_le',
 'arabic': 'iso8859_6',
 'big5-hkscs': 'big5hkscs',
 'big5-tw': 'big5',
 'chinese': 'gb2312',
 'cp1361': 'johab',
 'cp154': 'ptcp154',
 'cp819': 'latin_1',
 'cp936': 'gbk',
 'csbig5': 'big5',
 'csiso2022jp': 'iso2022_jp',
 'csiso2022kr': 'iso2022_kr',
 'csiso58gb231280': 'gb2312',
 'csptcp154': 'ptcp154',
 'csshiftjis': 'shift_jis',
 'cyrillic': 'iso8859_5',
 'cyrillic-asian': 'ptcp154',
 'euc-cn': 'gb2312',
 'euccn': 'gb2312',
 'eucgb2312-cn': 'gb2312',
 'eucjis2004': 'euc_jis_2004',
 'eucjisx0213': 'euc_jisx0213',
 'eucjp': 'euc_jp',
 'euckr': 'euc_kr',
 'gb18030-2000': 'gb18030',
 'gb2312-1980': 'gb2312',
 'gb2312-80': 'gb2312',
 'greek': 'iso8859_7',
 'greek8': 'iso8859_7',
 'hebrew': 'iso8859_8',
 'hkscs': 'big5hkscs',
 'hz-gb': 'hz',
 'hz-gb-2312': 'hz',
 'hzgb': 'hz',
 'ibm1026': 'cp1026',
 'ibm1140': 'cp1140',
 'iso-2022-jp': 'iso2022_jp',
 'iso-2022-jp-1': 'iso2022_jp_1',
 'iso-2022-jp-2': 'iso2022_jp_2',
 'iso-2022-jp-2004': 'iso2022_jp_2004',
 'iso-2022-jp-3': 'iso2022_jp_3',
 'iso-2022-jp-ext': 'iso2022_jp_ext',
 'iso-2022-kr': 'iso2022_kr',
 'iso-8859-1': 'latin_1',
 'iso-8859-10': 'iso8859_10',
 'iso-8859-13': 'iso8859_13',
 'iso-8859-14': 'iso8859_14',
 'iso-8859-15': 'iso8859_15',
 'iso-8859-2': 'iso8859_2',
 'iso-8859-3': 'iso8859_3',
 'iso-8859-4': 'iso8859_4',
 'iso-8859-5': 'iso8859_5',
 'iso-8859-6': 'iso8859_6',
 'iso-8859-7': 'iso8859_7',
 'iso-8859-8': 'iso8859_8',
 'iso-8859-9': 'iso8859_9',
 'iso-ir-58': 'gb2312',
 'iso2022jp': 'iso2022_jp',
 'iso2022jp-1': 'iso2022_jp_1',
 'iso2022jp-2': 'iso2022_jp_2',
 'iso2022jp-2004': 'iso2022_jp_2004',
 'iso2022jp-3': 'iso2022_jp_3',
 'iso2022jp-ext': 'iso2022_jp_ext',
 'iso2022kr': 'iso2022_kr',
 'iso8859-1': 'latin_1',
 'jisx0213': 'euc_jis_2004',
 'korean': 'euc_kr',
 'ks_c-5601': 'euc_kr',
 'ks_c-5601-1987': 'euc_kr',
 'ks_x-1001': 'euc_kr',
 'ksc5601': 'euc_kr',
 'ksx1001': 'euc_kr',
 'latin': 'latin_1',
 'latin1': 'latin_1',
 'latin2': 'iso8859_2',
 'latin3': 'iso8859_3',
 'latin4': 'iso8859_4',
 'latin5': 'iso8859_9',
 'latin6': 'iso8859_10',
 'latin8': 'iso8859_14',
 'maccentraleurope': 'mac_latin2',
 'maccyrillic': 'mac_cyrillic',
 'macgreek': 'mac_greek',
 'maciceland': 'mac_iceland',
 'maclatin2': 'mac_latin2',
 'macroman': 'mac_roman',
 'macturkish': 'mac_turkish',
 'ms-kanji': 'cp932',
 'ms1361': 'johab',
 'ms932': 'cp932',
 'ms936': 'gbk',
 'ms949': 'cp949',
 'ms950': 'cp950',
 'mskanji': 'cp932',
 'pt154': 'ptcp154',
 's_jis': 'shift_jis',
 's_jisx0213': 'shift_jisx0213',
 'shiftjis': 'shift_jis',
 'shiftjis2004': 'shift_jis_2004',
 'shiftjisx0213': 'shift_jisx0213',
 'sjis': 'shift_jis',
 'sjis2004': 'shift_jis_2004',
 'sjis_2004': 'shift_jis_2004',
 'sjisx0213': 'shift_jisx0213',
 'u-jis': 'euc_jp',
 'uhc': 'cp949',
 'ujis': 'euc_jp',
 'us-ascii': 'ascii',
 'utf16': 'utf_16',
 'utf8': 'utf_8',
 'windows-1250': 'cp1250',
 'windows-1251': 'cp1251',
 'windows-1252': 'cp1252',
 'windows-1253': 'cp1253',
 'windows-1254': 'cp1254',
 'windows-1255': 'cp1255',
 'windows-1257': 'cp1257',
 'windows-1258': 'cp1258',
 'windows1256': 'cp1256',

}

def delete():
    a=CrawlingData.objects.all()
    a.delete()

def parse():
    ## 설정
    data={
               0 : { },#instiz
               1  : { },#clien
               2 :  { },#fmkorea
               3 : { },#ou
               4 : { },#pan
               5 : { }, #slr
               6 : { }, #mlb
               7 : { },#inben
               8 : { },#ruri
               9 : { },#utde
              10 : { },#bobe
               11 : { },#ygosu
               12 : { },#drip
               13 : { },#theqoo
               14 : { },#dogge
               15 : { }, #namsung
               16 : { }, #flash1
               17 : { }, #flash2
               18 : { }, #dream1
               19 : { }, #dream2
               20 : { }, #bobe2
               21 : { },#fomos1
               22 : { },#fomos2
               23 : { },#ilbe
    }
    #instiz
    req = requests.get('http://www.instiz.net/bbs/list.php?id=pt&srd=1&srt=3&k=&stype=&stype2=&stype3=').text
    soup_instiz = BeautifulSoup(req, 'html.parser')
    #clien
    req = requests.get('https://www.clien.net/service/group/board_all?od=T33').text
    soup_clien = BeautifulSoup(req, 'html.parser')
    #fmkorea
    req = requests.get('http://www.fmkorea.com/index.php?mid=best&listStyle=list&page=1').text
    soup_fmkorea = BeautifulSoup(req, 'html.parser')
    #ou
    req = requests.get('http://www.todayhumor.co.kr/board/list.php?table=bestofbest').text
    soup_ou = BeautifulSoup(req, 'html.parser')
    #pan
    req = requests.get('http://pann.nate.com/talk/ranking').text
    soup_pan = BeautifulSoup(req, 'html.parser')
    #slr
    req = requests.get('http://www.slrclub.com/bbs/zboard.php?id=best_article&category=1&setsearch=category').text
    soup_slr = BeautifulSoup(req, 'html.parser')
    #mlb
    req = requests.get('http://mlbpark.donga.com/mp/best.php?b=bullpen&m=view').text
    soup_mlb = BeautifulSoup(req, 'html.parser')
    #inben
    req = requests.get('http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&query=list&my=chu&category=%EC%9C%A0%EB%A8%B8&sort=PID&name=&subject=&content=&keyword=&orderby=&iskin=webzine').text
    soup_inben = BeautifulSoup(req, 'html.parser')
    #ruri
    req = requests.get('http://bbs.ruliweb.com/best/selection').text
    soup_ruri = BeautifulSoup(req, 'html.parser')
    #utde
    req = requests.get('http://web.humoruniv.com/board/humor/list.html?table=pds&st=day').text.encode(encoding_map['iso-8859-1'])
    soup_utde = BeautifulSoup(req, 'html.parser')
    #bobe
    req = requests.get('http://www.bobaedream.co.kr/list?code=best').text.encode(encoding_map['iso-8859-1'])
    soup_bobe = BeautifulSoup(req, 'html.parser')
    #ygosu
    req = requests.get('http://www.ygosu.com/community/real_article').text
    soup_ygosu = BeautifulSoup(req, 'html.parser')
    #drip
    req = requests.get('http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc').text
    soup_drip = BeautifulSoup(req, 'html.parser')
    #theqoo
    req = requests.get('http://theqoo.net/tbest?filter_mode=normal').text
    soup_theqoo = BeautifulSoup(req, 'html.parser')
    #dogge
    req = requests.get('http://dkbnews.donga.com/Board?p=1&tcode=bbs_dkbnews&s=date&key=&query=').text
    soup_dogge = BeautifulSoup(req, 'html.parser')
    #namsung
    req1= requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=ggolit').text
    soup_namsung1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://nsbu.co.kr/bbs/board.php?bo_table=celeb').text
    soup_namsung2 = BeautifulSoup(req2, 'html.parser')
    #flash1
    req1= requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=star&page=2&page=1').text.encode(encoding_map['iso-8859-1'])
    soup_flash1 = BeautifulSoup(req1, 'html.parser')
    #flash2
    req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
    soup_flash2 = BeautifulSoup(req2, 'html.parser')
    #dream1
    req1= requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_star&is_image=Y').text
    soup_dream1 = BeautifulSoup(req1, 'html.parser')
    #dream2
    req2 = requests.get('http://newsbbs.dreamx.com/list.do?bid=cnt_humor&is_image=Y').text
    soup_dream2 = BeautifulSoup(req2, 'html.parser')
    #bobe2
    req1= requests.get('http://www.bobaedream.co.kr/list?code=girl&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=Subject&s_key=&level_no=&vdate=&type=list&page=1')
    req1 =req1.text.encode(encoding_map['iso-8859-1'])
    soup_bobe2 = BeautifulSoup(req1, 'html.parser')
    #fomos1
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=5').text
    soup_fomos1 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=6').text
    soup_fomos2 = BeautifulSoup(req2, 'html.parser')
    #fomos2
    req1= requests.get('http://www.fomos.kr/talk/article_list?bbs_id=3').text
    soup_fomos3 = BeautifulSoup(req1, 'html.parser')
    req2 = requests.get('http://www.fomos.kr/talk/article_list?bbs_id=4').text
    soup_fomos4 = BeautifulSoup(req2, 'html.parser')
    #ilbe
    req1= requests.get('http://www.ilbe.com/ilbe').text
    soup_ilbe = BeautifulSoup(req1, 'html.parser')

    
    ## json에 저장
    #instiz
    for title in soup_instiz.select('#subject a'): 
                    a = title.get('href')
                    b=a.replace(".." , "instiz.net")
                    data[0][title.text] = b
    #clien
    n=0
    for title in soup_clien.select('.list-title .list-subject'): 
        if n == 0:
            n+=1
            continue
        else:
            a = title.get('href')
            if not a==None:
                    a='clien.net' + a
                    str=" ".join(title.text.strip().split())
                    data[1][str] = a
    #fmkorea
    for title in soup_fmkorea.select('.hx'): 
                    a = title.get('href')
                    data[2][title.text.strip()] = a
    #ou
    for title in soup_ou.select('.subject a'): 
                    a = title.get('href')
                    a='todayhumor.co.kr' + a
                    data[3][title.text] = a
    #pan
    for title in soup_pan.select('dt a'): 
                    a = title.get('href')
                    data[4][title.text] = a
    #slr
    for title in soup_slr.select('.sbj a'): 
                    a = title.get('href')
                    a='slrclub.com'+a
                    data[5][title.text] = a
    #mlb
    for title in soup_mlb.select('.t_left a'): 
                    a = title.get('href')
                    data[6][title.text] = a
    #inben
    for title in soup_inben.select('a.sj_ln'): 
                    a = title.get('href')
                    data[7][title.text] = a
    #ruri
    for title in soup_ruri.select('.subject a'): 
                    a = title.get('href')
                    data[8][title.text] = a
     #utde
    for title in soup_utde.select('a.brn3, a.brn2, a.brn1'): 
                    a = title.get('href')
                    a='web.humoruniv.com/board/humor/'+a
                    str=" ".join(title.text.strip().split())
                    data[9][str] = a
    #bobe
    for title in soup_bobe.select('a.bsubject'): 
                    a = title.get('href')
                    a='bobaedream.co.kr'+a
                    data[10][title.text] = a
    #ygosu
    for title in soup_ygosu.select('.tit a'): 
                    a = title.get('href')
                    data[11][title.text] = a
     #drip
    n=0
    for title in soup_drip.select('td.title a'): 
                if n == 0:
                      n+=1
                      continue
                else:
                     a = title.get('href')
                     data[12][title.text.strip()] = a
    #theqoo
    j=0 
    n=1
    x=1
    m=2
    for title in soup_theqoo.select('td.title a'): 
            if j < 8 :
                     j+=1
                     continue
            else:
                    if  n == m:
                            a=title.get('href')
                            a='theqoo.net'+a.replace('_comment','') 
                            n+=1
                            x+=1
                            m=2*x
                            data[13][title.text] = a
                            continue
                    else:
                            n+=1
                            continue
    #dogge
    for title in soup_dogge.select('.txt a'): 
                    a = title.get('href')
                    a ='http://dkbnews.donga.com/Board'+a
                    data[14][title.text.strip()] = a
    #namsung
    n=0
    for title in soup_namsung1.select('.list-subject a'): 
                    if n < 10:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                    else:
                          break                   
    for title in soup_namsung2.select('.list-subject a'): 
                     if n < 19:
                        a = title.get('href')
                        n+=1
                        data[15][title.text.strip()]=a
                     else:
                          break
    #flash1
    n=0
    for title in soup_flash1.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[16][title.text]=a
     #flash2
    n=0
    for title in soup_flash2.select('.subject a'): 
                    if n == 0:
                        n+=1
                        continue
                    else:
                        a = title.get('href')
                        a = a.replace('..','flash24.dreamx.com/g4')
                        data[17][title.text]=a
    #dream1
    n=1
    x=1
    m=2
    for title in soup_dream1.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[18][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #dream2
    n=1
    x=1
    m=2
    for title in soup_dream2.select('.bbs_list_list a'): 
                        if  n == m:
                                a=title.get('href')
                                a='newsbbs.dreamx.com'+a
                                n+=1
                                x+=1
                                m=2*x
                                data[19][title.text.strip()]=a
                                continue
                        else:
                                n+=1
                                continue
    #bobe2
    for title in soup_bobe2.select('.pl14 a.bsubject'): 
                    a=title.get('href')
                    a='bobaedream.co.kr'+a
                    data[20][title.text.strip()]=a
    #fomos1
    n=0
    for title in soup_fomos1.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos2.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[21][title.text.strip()]=a
                        else:
                                break
    #fomos2
    n=0
    for title in soup_fomos3.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
    n=0
    for title in soup_fomos4.select('.ranking a'): 
                        if n < 10:
                                n+=1
                                a=title.get('href')
                                a='www.fomos.kr'+a
                                data[22][title.text.strip()]=a
                        else:
                                break
     #ilbe
    n=0
    for title in soup_ilbe.select('.title a'): 
                    if n == 0:
                            n+=1
                            continue
                    else:
                            a=title.get('href')
                            data[23][title.text.strip()]=a


     #한꺼번에 DB 에  insert 하기 위한 함수
    
    def allsave(x):
            crawling = CrawlingData()
            list = [
                       [crawling.instiz, crawling.link_instiz], [crawling.clien, crawling.link_clien], [crawling.fmkorea, crawling.link_fmkorea],
                       [crawling.ou, crawling.link_ou] ,[crawling.pan, crawling.link_pan],[crawling.slr, crawling.link_slr],[crawling.mlb, crawling.link_mlb],
                       [crawling.inben, crawling.link_inben],[crawling.ruri, crawling.link_ruri],[crawling.utde, crawling.link_utde],[crawling.bobe, crawling.link_bobe],
                       [crawling.ygosu, crawling.link_ygosu],[crawling.drip, crawling.link_drip],[crawling.theqoo, crawling.link_theqoo],
                       [crawling.dogge, crawling.link_dogge],[crawling.namsung, crawling.link_namsung],[crawling.flash1, crawling.link_flash1],
                       [crawling.flash2, crawling.link_flash2],[crawling.dream1, crawling.link_dream1],[crawling.dream2, crawling.link_dream2],
                       [crawling.bobe2, crawling.link_bobe2],[crawling.fomos1, crawling.link_fomos1], [crawling.fomos2, crawling.link_fomos2],
                       [crawling.ilbe, crawling.link_ilbe]
                   ]
            for  i in range(len(data)):
                    n=0
                    for t,l in data[i].items():
                        if n == x:
                            list[i][0],list[i][1]= t,l
                            print(list[i][0],list[i][1])
                            break
                        else:
                            n+=1
                            continue
            
            CrawlingData(instiz=list[0][0],link_instiz=list[0][1], clien=list[1][0],link_clien=list[1][1], fmkorea=list[2][0],link_fmkorea=list[2][1],
                                  ou=list[3][0],link_ou=list[3][1], pan=list[4][0],link_pan=list[4][1], slr=list[5][0],link_slr=list[5][1], mlb=list[6][0],link_mlb=list[6][1],
                                  inben=list[7][0],link_inben=list[7][1], ruri=list[8][0],link_ruri=list[8][1], utde=list[9][0],link_utde=list[9][1],
                                  bobe=list[10][0],link_bobe=list[10][1], ygosu=list[11][0],link_ygosu=list[11][1], drip=list[12][0],link_drip=list[12][1],
                                  theqoo=list[13][0],link_theqoo=list[13][1], dogge=list[14][0],link_dogge=list[14][1], namsung=list[15][0],link_namsung=list[15][1],
                                  flash1=list[16][0],link_flash1=list[16][1], flash2=list[17][0],link_flash2=list[17][1], dream1=list[18][0],link_dream1=list[18][1],
                                  dream2=list[19][0],link_dream2=list[19][1], bobe2=list[20][0],link_bobe2=list[20][1], fomos1=list[21][0],link_fomos1=list[21][1],
                                  fomos2=list[22][0],link_fomos2=list[22][1], ilbe=list[23][0],link_ilbe=list[23][1],
                                    ).save() 
            
       ##DB에 저장
    for x in range(len(data[0])):
                    allsave(x)
                    print('-----------')
                    
    
while True:
    print('start parsing')
    delete()
    parse()
    print('parsing ends')
    print('sleep in 40s')
    time.sleep(60)
# Out:
# start parsing
# 이것만 생각하면 9월 한달 개꿀 instiz.net/pt?no=4734191&page=1&srt=3&k=&srd=1
# 모공 [릴레이28일차] 삼성 장충기 문자 보고가시죠. clien.net/service/board/park/11163597?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 국민대..X집남..충격적인..사실... http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767862443
# 홍준표 지지자 아버지, 문재인 지지 딸과 다툼 끝에 집에 방화 시도... todayhumor.co.kr/board/view.php?table=bestofbest&no=361032&s_no=361032&page=1
# 부산여중생 가해자 친구들 친목ㄷㄷ http://pann.nate.com/talk/338661583
# 부산여중생 사건에 입연 매갈..JPG slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259850
# 메이저리그 근황 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ.gif http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008361418&m=view
#  [유머] 자동차 이상과 현실 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808734
# 어메이징 27살 공기관직원 일확천금의 꿈.jpg http://bbs.ruliweb.com/best/board/300143/read/34659339
# 비정상회담에 나타난 '진짜' 정상.jpg [74] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706718
# 그것이 알고 싶다에 제보 했습니다. bobaedream.co.kr/view?code=best&No=133045&vdate=
# 호불호 bj   http://www.ygosu.com/community/real_article/yeobgi/1244199/?page=0&frombest=Y
# 2017년 상반기 개드립 갔었던 만화.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138310728
# 실망했다고 초밥집에 후기 남긴 이후..jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562567072
# 킬라그램 친형 팰라그램.jpg이슈포토 http://dkbnews.donga.com/Board?no=15982&m=view&tcode=bbs_dkbnews
# 일반인 스러운 FC2녀  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34321
# 최설화 인스타 근황 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73827&page=1
# 성진국 수영 대회 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82422
# 경례 하는 쯔위 ~ newsbbs.dreamx.com/view.do?list_id=697880&page=1&bid=cnt_star
# 밤에보면 무서울듯...gif newsbbs.dreamx.com/view.do?list_id=697881&page=1&bid=cnt_humor
# 아이유 bobaedream.co.kr/view?code=girl&No=850032&bm=1
# 권나라 강제노출.gif www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257902
# 가면 벗기전까진 상상도 못했던 복면가왕 (4) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257896
# (속보)히딩크가 한국 국대 감독 원한다는 기사 떴다 ㅋㅋㅋㅋ.JPg http://www.ilbe.com/10009024070
# -----------
# 요즘 소름돋는다고 난리난 타로챗봇 instiz.net/pt?no=4733809&page=1&srt=3&k=&srd=1
# 모공 내 가슴을 때리고 머리에 남은 어느 문빠의 한마디.facebook clien.net/service/board/park/11161684?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 이동국 vs 고요한 인스타 상황비교 ㅋㅋㅋㅋ http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767784236
# 청와대 항의방문 갔다가 '입 삐죽' 자유당  todayhumor.co.kr/board/view.php?table=bestofbest&no=361031&s_no=361031&page=1
# 과거 더러운 연예인빠는 애들아 이래도? http://pann.nate.com/talk/338658609
# [전문가분들 출동 ㄱㄱ] 여객기 조종석 밖으로 셀카 촬영..진위 논란 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259849
# 지금 천조국에서 난리난 사진.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008360239&m=view
#  [유머] 가난은 한꺼번에 찾아온다 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808599
# 소년법 폐지에 대한 한 댓글의 의견 . jpg http://bbs.ruliweb.com/best/board/300143/read/34659164
# 휴식시간의 장인.jyp [35] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706719
# 박정희 “초등학생 성폭행하고 일본군 자원입대” bobaedream.co.kr/view?code=best&No=133039&vdate=
# 호불호 처자.jpg  http://www.ygosu.com/community/real_article/yeobgi/1244196/?page=0&frombest=Y
# 빨래에서 고양이 지린내 나는 만화 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138314055
# 금수저 특징 삼다수로 라면 끓여먹음 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562548814
# [주번나] 윤사랑 비키니 자태.jpg이슈포토 http://dkbnews.donga.com/Board?no=15981&m=view&tcode=bbs_dkbnews
# 코스녀의 몸매 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34320
# 치명적인 한승연 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73826&page=1
# 이런 오피 누나 좋아~ flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82421
# 여자친구 갓지 newsbbs.dreamx.com/view.do?list_id=697878&page=1&bid=cnt_star
# 미스 맥심걸 정영현 newsbbs.dreamx.com/view.do?list_id=697879&page=1&bid=cnt_humor
# 디애나 소나무 bobaedream.co.kr/view?code=girl&No=850031&bm=1
# 현재 여초에서 초난리난 국민대 ㅈ집남 (4) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258104
# 슈퍼비가 타블로를 싫어하게 된 이유(16) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257924
# 나라땅 팔아먹는 간큰 김치년 보소 ㅋㅋㅋㅋ http://www.ilbe.com/10008893860
# -----------
# 자살 안하고 버틴게 용하다는 한 웹툰 여주의 가정 instiz.net/pt?no=4734784&page=1&srt=3&k=&srd=1
# 모공 청와대 부산경찰파면청원 clien.net/service/board/park/11163556?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 속보) 히딩크, 한국 국가대표 감독 맡을 의사 있다.(낚시 아님 ㅇㅇ) http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767891213
# 문재인 정부 출범 넉달, 국회에 생긴 큰 변화 todayhumor.co.kr/board/view.php?table=bestofbest&no=361030&s_no=361030&page=1
# 추가)시댁여러분.손주는 며느리닮으면 안됩니까? http://pann.nate.com/talk/338667557
# 비행기 셀카 [有] slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259848
# 외국에서 난리난 사진 http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008360791&m=view
#  [유머] 대한민국 축구 한장 요약 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808544
# 어린아이에게 가차없는 매정한 의사선생님 . jpg http://bbs.ruliweb.com/best/board/300143/read/34659049
# 갈수밖에 없는 회식.jpg [55] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706759
# [혐주의] 소년법 폐지 반대하는 의원 bobaedream.co.kr/view?code=best&No=133040&vdate=
# "히딩크, 한국 국대 맡을 의사있다".jpg  http://www.ygosu.com/community/real_article/yeobgi/1244203/?page=0&frombest=Y
# 게임을 너무 못해서 화제가 된 인물 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138276077
# 노키즈존이 되는 과정 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562519108
# 패리스힐튼 개집.jpg이슈포토 http://dkbnews.donga.com/Board?no=15980&m=view&tcode=bbs_dkbnews
# 너무 파인 수영복 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34318
# 소나무 디애나 우월한 비율 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73825&page=1
# 모델 변정하 색기 장난아니네 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82420
# 여자친구 귀를 기울이면 티저 움짤들 newsbbs.dreamx.com/view.do?list_id=697876&page=1&bid=cnt_star
# 난장판 인천공항 newsbbs.dreamx.com/view.do?list_id=697877&page=1&bid=cnt_humor
# 승옥 bobaedream.co.kr/view?code=girl&No=850030&bm=1
# 2017 섹시백 대상 수상자 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257947
# 라붐 율희 뭔일 터진듯???(1) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257921
# 근데 이새끼 볼수록 병신같은새끼네 ㄹㅇ...jpg http://www.ilbe.com/10008907127
# -----------
# [단독] "성관계하면 풀어줄게"…부산 여중생 집단폭행 새 증언 instiz.net/pt?no=4734708&page=1&srt=3&k=&srd=1
# 모공 마광수 교수의 인생 조언 clien.net/service/board/park/11161481?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 대학교 2학기 시작.....최악의 조 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767850872
# 박정희 “초등학생 성폭행하고 일본군 자원입대” todayhumor.co.kr/board/view.php?table=bestofbest&no=361029&s_no=361029&page=1
# 임신한 와이프가 먹는게 얄밉다고 하는 남편 http://pann.nate.com/talk/338658383
# 한국에서만 먹는다는 해산물 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259847
# 친구가 성매매 업소에 중독 됐네요.. http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008361664&m=view
#  [유머] 월드컵 9회연속 진출!! http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808538
# 22세 신예선수가 한국축구의 영웅으로 http://bbs.ruliweb.com/best/board/300143/read/34657059
# 욕쟁이 천사 [59] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706704
# G4 출고 인증 합니다 행님들 bobaedream.co.kr/view?code=best&No=133038&vdate=
# 결국 카토 피규어 주문했다...jpg  http://www.ygosu.com/community/real_article/animation/199272/?page=0&frombest=Y
# 어린아이에게 가차없는 매정한 의사선생님.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138303957
# 자취버전 중국집 볶음밥 레시피.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562472188
# [후방주의] 기어다니는 ㅊㅈ.gif이슈포토 http://dkbnews.donga.com/Board?no=15979&m=view&tcode=bbs_dkbnews
# 아름답네요 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34317
# 런온서울 2017 김연아 레깅스핏 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73824&page=1
# 골반 지리는 일반인 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82419
# 브레이브걸스 예진 근황 newsbbs.dreamx.com/view.do?list_id=697873&page=1&bid=cnt_star
# 전세계 언어 사용자수 비율 newsbbs.dreamx.com/view.do?list_id=697875&page=1&bid=cnt_humor
# 이한별 bobaedream.co.kr/view?code=girl&No=850029&bm=1
# (후방주의) 요즘 핫하다는 영국 모델녀(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257950
# 다가진 빈지노 ㄷㄷㄷ(2) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258027
# 조이라이드  만화.manhwa http://www.ilbe.com/10008896601
# -----------
# 매우 희귀한 확률로 겪는다는 스탕달 증후군 instiz.net/pt?no=4734382&page=1&srt=3&k=&srd=1
# 모공 [펌] 한국의 개신교 사상 최악의 원톱 사건. clien.net/service/board/park/11163260?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 실망했다고 초밥집에 후기 남긴 이후.. http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767755724
# 흔한 라면 전단지 .jpg todayhumor.co.kr/board/view.php?table=bestofbest&no=361028&s_no=361028&page=1
# (글추가)남편이 지적장애가 있는걸까요? 꼭 봐주세요. http://pann.nate.com/talk/338657662
# 신정환 복귀 예능 jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259845
# 부산 여중생 폭행사건 만평.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008361337&m=view
#  [유머] [해충갤펌] 갓한민국 현상황 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808439
# 키작은 남자들 조금이라도 커보이는 비법.jpg http://bbs.ruliweb.com/best/board/300143/read/34658077
# 라디오스타로 이미지 폭망한 연예인 甲 [82] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706796
# 부산 폭행한년 카톡 bobaedream.co.kr/view?code=best&No=133042&vdate=
# 요즘 청와대 청원하는게 유행임? feat.아이성은엄마를따라야한다  http://www.ygosu.com/community/real_article/yeobgi/1244174/?page=0&frombest=Y
# 게임 못한다고 욕먹는 해외 저널리스트 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138303618
# 한국, 9회 연속 월드컵 진출…세계 6번째 대기록 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562453674
# [주번나] 비키니 입은 운전녀.jpg이슈포토 http://dkbnews.donga.com/Board?no=15978&m=view&tcode=bbs_dkbnews
# 바바 후미카 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34315
# 황보미 前 SBS 아나운서 인스타 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73823&page=1
# 치어리더 안지현 이기적인 각선미 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82416
# 경리 newsbbs.dreamx.com/view.do?list_id=697871&page=1&bid=cnt_star
# 안젤리나를 위협하는 새로운 러시아녀 newsbbs.dreamx.com/view.do?list_id=697872&page=1&bid=cnt_humor
# 연아 bobaedream.co.kr/view?code=girl&No=850028&bm=1
# 가슴골을 가리고 인사하는건 예의가 아니다.....(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257980
# 컨셉이 아니라 유라는 진짜임.gif www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=257884
# 짱깨가 점령한 대림동 근황...jpg http://www.ilbe.com/10008775314
# -----------
# 백현 인스타_(f.루머 피드백) instiz.net/pt?no=4734130&page=1&srt=3&k=&srd=1
# 모공 진출당했네요 clien.net/service/board/park/11162771?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 여직원 나라땅 팔아 11억원 횡령....jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767784322
# 이게 오유냐 1人 시위 3일차. todayhumor.co.kr/board/view.php?table=bestofbest&no=361027&s_no=361027&page=1
# 마산 또 없어졌네요 http://pann.nate.com/talk/338658632
# 국대 축구 주장의 위엄 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259844
# 남궁민 수트핏.JPG http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008360821&m=view
#  [유머] ??? : 입벌려 월드컵 들어간다. http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808431
# (소녀전선) 공포의 굿즈 공모전.JPG http://bbs.ruliweb.com/best/board/300143/read/34657865
# 마술사 최현우의 무서운 경험담.jpg [45] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706819
# 부산 여중생 폭행사건에 대해서...간곡히 고개숙여 부탁드립니.. bobaedream.co.kr/view?code=best&No=133034&vdate=
# 잠잠 하더니 슬금슬금 기어나오는..  http://www.ygosu.com/community/real_article/yeobgi/1244193/?page=0&frombest=Y
# 신정환 예능 복귀 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138310107
# 한국 월드컵 본선 진출 당함!! theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562440913
# 신정환 복귀 예능 예고.jpg이슈포토 http://dkbnews.donga.com/Board?no=15977&m=view&tcode=bbs_dkbnews
# 크롭 사장님 몸매  댓글 : 6 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34314
# 개그우먼 흔한 몸매 이한별 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73822&page=1
# 옷태가 잘나오네요 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82415
# 골반이랑 엉태가 너무 좋아ㅠㅠ newsbbs.dreamx.com/view.do?list_id=697869&page=1&bid=cnt_star
# 50구경 저격소총 newsbbs.dreamx.com/view.do?list_id=697870&page=1&bid=cnt_humor
# 쯔위 bobaedream.co.kr/view?code=girl&No=850023&bm=1
# 얼굴도 몸매도 야하게 생긴 누나.gif www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257948
# 내부자들 감독 신작 마약왕 라인업 ㄷㄷㄷ(10) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258006
# 김도연 카톡 탈퇴했다and정유미 초딩때사진 http://www.ilbe.com/10008972686
# -----------
# 결혼하면서 신랑이 데려온 강아지가 낯을 가려요 instiz.net/pt?no=4733771&page=1&srt=3&k=&srd=1
# 모공 신태용 감독 욕하는건 솔직히 너무 하네요. clien.net/service/board/park/11162980?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 지금은 없어진 306 보충대 사진 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767297668
# 전우용 역사학자 트윗, <사기꾼이 지배한 시대엔 사기꾼이 성공합니다> todayhumor.co.kr/board/view.php?table=bestofbest&no=361026&s_no=361026&page=1
# (추가)애엄마 분들 이런 이유로 애를 안낳는건 이기적... http://pann.nate.com/talk/338662914
# ㅋㅋㅋ코스트코에서 물 돈주고 사도 거지라니 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259843
# 문재인을 볼때마다 느끼는건데요. http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008359090&m=view
#  [유머] 진짜 갓겜 출시 됨 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808377
# '게임도 못하는 새끼는 게임 기자를 해서는 안 된다' http://bbs.ruliweb.com/best/board/300143/read/34657713
# 당신의 개를 1억원에 사겠습니다.jpg [139] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706754
# JTBC 축구 독점 중계 좀 하지마라 저질이다. bobaedream.co.kr/view?code=best&No=133033&vdate=
# 하이킥 레전드편.jpg   http://www.ygosu.com/community/real_article/yeobgi/1244163/?page=0&frombest=Y
# [미국북동부 낚시 여행기] 둘째 날, 드디어 낚시!!  b] http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138306840
# 국민대 좆집남 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562303049
# 그리운 마리텔.jpg이슈포토 http://dkbnews.donga.com/Board?no=15976&m=view&tcode=bbs_dkbnews
# 속옷 착용샷 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34313
# 유승옥 실물 느낌 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73821&page=1
# 피트니스 여신 김아름 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82414
# 크롭사장 전보람 newsbbs.dreamx.com/view.do?list_id=697867&page=1&bid=cnt_star
# 맛있는 녀석들 홀쭉한 시절의 추억 newsbbs.dreamx.com/view.do?list_id=697868&page=1&bid=cnt_humor
# 찬미 bobaedream.co.kr/view?code=girl&No=850022&bm=1
# av계 리빙 레전드 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257984
# 비쥬얼 평균이 거의 완벽에 가까운 걸그룹(15) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258080
# 부산 욕좀 그만해라 한국최고 바닷가 해운대 가봤냐 http://www.ilbe.com/10008982519
# -----------
# 삼성의 기술력ㅋㅋㅋㅋㅋㅋㅋㅋㅋ.jpg instiz.net/pt?no=4733901&page=1&srt=3&k=&srd=1
# 모공 文 대통령, “지금은 북한과 대화 말할 때 아냐” clien.net/service/board/park/11161702?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 슈퍼비가 타블로 싫어하는 이유.jpg http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767854009
# 딸내미땜에 빵터진 아재의 유모아 todayhumor.co.kr/board/view.php?table=bestofbest&no=361025&s_no=361025&page=1
# 제가 커피숍 진상이래요~ 참나... 기가막혀.. http://pann.nate.com/talk/338663569
# 천하의 쓰레기 기능 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259841
# 강정호가 도미니카로 가는방법.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008371672&m=view
#  [유머] 주인을 기다리는 멍멍이 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808311
# 마침내 붓싼경찰도 예정대로 파괴해버린 무한도전.jpg http://bbs.ruliweb.com/best/board/300143/read/34657537
# 사건축소에 급급한 부산경찰 [62] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706792
# 한국 드라마 현실고증 甲 bobaedream.co.kr/view?code=best&No=133035&vdate=
# 꼴페미교사  정의구현해주시는 어머니 일침 ㅋㅋㅋ  http://www.ygosu.com/community/real_article/yeobgi/1244181/?page=0&frombest=Y
# 9.9m] 리베로의 매력 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138305956
# 위너 김진우팬이 지하철에 광고 걸어줬는데 난리남 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562270387
# 순대 처음 본 이탈리아 사람 반응.jpg이슈포토 http://dkbnews.donga.com/Board?no=15975&m=view&tcode=bbs_dkbnews
# 맥심어워즈 늘씬한 뒤태 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34312
# 아이유 겨드랑이 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73820&page=1
# 자슴감 넘치는 셀카녀 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82413
# 수영하는 고은아 newsbbs.dreamx.com/view.do?list_id=697865&page=1&bid=cnt_star
# 전설의 저금통 개봉기 newsbbs.dreamx.com/view.do?list_id=697866&page=1&bid=cnt_humor
# 하영 bobaedream.co.kr/view?code=girl&No=850021&bm=1
# 좋아 죽는 경리.gif(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257891
# 이광수 방송인생 최대의 위험발언 www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258060
# 짱깨드라마만도 못한 김치드라마ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ http://www.ilbe.com/10008966563
# -----------
# 여자들도 군대 가야한다 청와대 4일만에 8만명 서명 instiz.net/pt?no=4735330&page=1&srt=3&k=&srd=1
# 모공 "여중생 폭행 CCTV 공개 말라" 압력…경찰 축소 수사 의혹 clien.net/service/board/park/11161486?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 고양이보다 강아지 키워야하는 이유 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767814383
# 마트에서 아이들이 사달라고 조를 때 todayhumor.co.kr/board/view.php?table=bestofbest&no=361024&s_no=361024&page=1
# 애 엄마가 담배피는게 죽을죄인가요 http://pann.nate.com/talk/338657969
# 가슴이 너무 아려오네요... ;; slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259840
# 노회찬 라임 수준.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008367397&m=view
#  [유머] 이거 누가 그랬냐 ? http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808302
# 축구하다가 동생을 봤다 http://bbs.ruliweb.com/best/board/300143/read/34657128
# 어제자 최여진 발언.jpg [125] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706802
# 거짓말하는 부산 경찰 인스타그램 bobaedream.co.kr/view?code=best&No=133032&vdate=
# 결경이 나쁜손  ㅗㅜㅑ http://www.ygosu.com/community/real_article/yeobgi/1244154/?page=0&frombest=Y
# 컨트롤 조무사.jpgif http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138305499
# [단독] "성관계하면 풀어줄게"…부산 여중생 집단폭행 새 증언 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562228031
# 고양이도 사람차별 한다.jpg이슈포토 http://dkbnews.donga.com/Board?no=15974&m=view&tcode=bbs_dkbnews
# 패션쇼 비키니 모델의 무브먼트 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34311
# 오마이걸 지호 핫한 엉덩이 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73819&page=1
# 피트니스 코리아 처자들 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82412
# 러블리즈 newsbbs.dreamx.com/view.do?list_id=697862&page=1&bid=cnt_star
# 350억짜리 시계 newsbbs.dreamx.com/view.do?list_id=697863&page=1&bid=cnt_humor
# 은하 bobaedream.co.kr/view?code=girl&No=850020&bm=1
# 후방주의) 성진국 면요리 ㅓㅜㅑ(1) www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=257907
# 실제론 서로 번호도 모르는 파워 비즈니스 사이(4) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258045
# 소개팅 상대 집에서 똥싼 여성의 최후 http://www.ilbe.com/10008826934
# -----------
# 라면물 많이 잡아서 싱거워 보일 때 꿀팁 instiz.net/pt?no=4733654&page=1&srt=3&k=&srd=1
# 모공 文대통령 "흡수통일 아닌 남북 번영하는 경제공동체 추구" clien.net/service/board/park/11163244?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# [스쿼카] 엠마누엘 프티 "아 이새끼들 어린애같이 그만 굴지?" http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767199437
# 러시아에 도착한 문재인 대통령과 부인 김정숙 여사 todayhumor.co.kr/board/view.php?table=bestofbest&no=361023&s_no=361023&page=1
# 이불밖은 위험해 생각보다 재밌는데? http://pann.nate.com/talk/338657767
# 자게이의 출신고등학교 총 조사 txt. slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259839
# 린제이 로한 근황.JPG http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008360737&m=view
#  [유머] 한국 축구 노답이라고 생각하는 사람?? http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808300
# 아저씨 축구 좀 해요? http://bbs.ruliweb.com/best/board/300143/read/34657110
# 일본인이 되는 방법.jpg [39] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706813
# 자한당이 어제 청와대에 간 이유 bobaedream.co.kr/view?code=best&No=133036&vdate=
# 제발 선수들 탈압박 연습 좀 http://www.ygosu.com/community/real_article/soccer/223357/?page=0&frombest=Y
# [미국북동부 낚시 여행기] 첫 날, Salmon river로~   b] http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138304890
# 소중이노세범이라는 전설의 짤 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562208525
# 아이유가 기억하는 김연아.jpg이슈포토 http://dkbnews.donga.com/Board?no=15973&m=view&tcode=bbs_dkbnews
# 혼자서 난리남  댓글 : 5 http://nsbu.co.kr/bbs/board.php?bo_table=ggolit&wr_id=34269
# 신수지 '우아한 홀터넥 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73818&page=1
# bj 서아 공격을 부르는 궁디 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82411
# 후덕한 브레이브걸스 유정 newsbbs.dreamx.com/view.do?list_id=697860&page=1&bid=cnt_star
# 카메라맨 주차장 까지 따라갈 기세 newsbbs.dreamx.com/view.do?list_id=697861&page=1&bid=cnt_humor
# 시라이시 마이 bobaedream.co.kr/view?code=girl&No=850019&bm=1
# 배우 백진희가 남긴 레전드 작품 www.fomos.kr/talk/article_view?bbs_id=5&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D5&indexno=258100
# 평생 혼자 살고 싶은 최여진의 가정사(2) www.fomos.kr/talk/article_view?bbs_id=3&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D3&indexno=258017
# 부산여중생 가해자년 근황 http://www.ilbe.com/10008961494
# -----------
# 미국에서 지금 난리난 사진.twt instiz.net/pt?no=4734281&page=1&srt=3&k=&srd=1
# 모공 국민이 부르면 돌아보는 대통령님♡ clien.net/service/board/park/11164311?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 덩케르크의 영국 공군 조종사 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767419243
# 술래 잡기 todayhumor.co.kr/board/view.php?table=bestofbest&no=361022&s_no=361022&page=1
# 기차] 1사람, 2좌석 어때요? http://pann.nate.com/talk/338657673
# 남학생은 이 여 선배를 'X집'라고 저장했다 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259838
# 문재인 정부가 또.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008372215&m=view
#  [유머] 캐릭터를 누렁이로 선택하시겠습니까? http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808298
# 소년법은 소년법이 아니라 일진법이다.jpg http://bbs.ruliweb.com/best/board/300143/read/34655984
# 안경의 중요성.jpg [28] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706749
# ■ 부산경찰 홍보조무사 주작질 하다 딱 걸린 사건.jpg bobaedream.co.kr/view?code=best&No=133041&vdate=
# 오늘자 데일리룩  http://www.ygosu.com/community/real_article/fashion/51969/?page=0&frombest=Y
# 비켜 ㅄ아.gif http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138304658
# 청와대 문재인 시계 77만원 플미 붙여서 중고나라에 판 기자 얼굴.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562174425
# 이준기 팩폭.jpg이슈포토 http://dkbnews.donga.com/Board?no=15972&m=view&tcode=bbs_dkbnews
# 양주 언냐를 움켜잡는 결경이 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28348
# 아이유 망사 원피스 섹시해유? flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73817&page=1
# 요즘 스크린골프 알바인가요 ? flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82410
# 청순 태연 newsbbs.dreamx.com/view.do?list_id=697858&page=1&bid=cnt_star
# 루리웹 인증녀 건담처자 newsbbs.dreamx.com/view.do?list_id=697857&page=1&bid=cnt_humor
# 레이싱 모델 한채이 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850009&bm=1
# 스베누 황효진 사장 순수했던 리즈시절 위엄	(8) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257876
# 비뇨기과 실장의 커플 환자 썰	(7) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258062
# 속보 리오넬메시 귀화 http://www.ilbe.com/10008964045
# -----------
# 어른눈에만 사이다로 보이는 장면 instiz.net/pt?no=4734856&page=1&srt=3&k=&srd=1
# 모공 서울 광진구 구의원들의 명단 입니다. clien.net/service/board/park/11163137?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 보복운전한 미친년의 최후! http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767777881
# 루리웹 일침 수준 todayhumor.co.kr/board/view.php?table=bestofbest&no=361021&s_no=361021&page=1
# (후기)아픈 홀시엄니 모시자는거 단칼에 거절함 http://pann.nate.com/talk/338662413
# 내 똥차에 타면 많이 물어보는것 두가지 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259837
# 민폐행동이다 vs 아니다.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008362636&m=view
#  [유머] RPG 3대 유형 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808116
# 얘들아 우리 임신하지말자 본때를 보여주자 . jpg http://bbs.ruliweb.com/best/board/300143/read/34655893
# (금수저인증) 서민들은 꿈도 꾸지못할 일상 [93] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706782
# cbs 기레기 기자 근황 bobaedream.co.kr/view?code=best&No=133029&vdate=
# 세계 6대 축구명가 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  http://www.ygosu.com/community/real_article/yeobgi/1244167/?page=0&frombest=Y
# RPG 3대 증후군 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138303111
# 장시간 스마트폰 사용으로 인한 손가락 변형 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562117298
# 남자들의 끝말잇기.jpg이슈포토 http://dkbnews.donga.com/Board?no=15971&m=view&tcode=bbs_dkbnews
# 모모.. ㅗㅜㅑ  댓글 : 1 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28346
# '야구여친' 연상은 아나, 여친룩 시구 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73816&page=1
# 이사장님네 직원 란지 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82409
# 하트 장인 ~ newsbbs.dreamx.com/view.do?list_id=697856&page=1&bid=cnt_star
# 면회 newsbbs.dreamx.com/view.do?list_id=697854&page=1&bid=cnt_humor
# 레이싱 모델 김시연 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850008&bm=1
# ASL 시즌4 24강 조 편성(5) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=257915
# 대통령 시계 팔아먹는 분들의 정체(8) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257898
# 누나는 제 좆집이에요.jpg http://www.ilbe.com/10008810272
# -----------
# 면접 시 성희롱 관련 질문 모범답안 instiz.net/pt?no=4735262&page=1&srt=3&k=&srd=1
# 모공 [펌글] 젊은남성들에게 대의를 강요하지마라 clien.net/service/board/park/11161438?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# [팩트체크] 손흥민은 실제로 국대에서 부진할까? http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767815249
# 히말라야 산 중의 티벳불교사원(곰파)을 가 보았다. (스압,데이터주의) todayhumor.co.kr/board/view.php?table=bestofbest&no=361020&s_no=361020&page=1
# 아주버님네 애를 키워달래요. http://pann.nate.com/talk/338669066
# GLE 350D 쿠페 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259836
# 탄두중량 해제의 진짜 핵심을 다들 모르시는 듯......???????? http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008359816&m=view
#  [유머] 한국과자.gif http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=808049
# 학교폭력을 저지른 아들과 학교에 불려온 아버지 http://bbs.ruliweb.com/best/board/300143/read/34655891
# 공무원의 복수.jpg [61] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706828
# 청소년 만화.jpg bobaedream.co.kr/view?code=best&No=133037&vdate=
# 여성전용 택배함...  http://www.ygosu.com/community/real_article/yeobgi/1244142/?page=0&frombest=Y
# 대한민국 무패행진 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138291957
# 김유정 사랑니빼고 얼굴 붓기 차이 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=562026774
# 여친이랑 덴마크 가면 안되는 이유.jpg이슈포토 http://dkbnews.donga.com/Board?no=15970&m=view&tcode=bbs_dkbnews
# 라붐 피지컬 대결  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28333
# 영화배우   터리사 콘토스타블로스, "볼륨감" 넘치는 몸매 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73815&page=1
# 여친 호불호 데이트 패션 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82408
# 눈에 뭐 들어가 아픈 아이린, 걱정에 동공지진 온 사막… newsbbs.dreamx.com/view.do?list_id=697853&page=1&bid=cnt_star
# 원더우먼 바디페인팅 newsbbs.dreamx.com/view.do?list_id=697851&page=1&bid=cnt_humor
# 레이싱 모델 김하음 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850007&bm=1
# 몸매가 너무 야한 BJ 도아 ㅓㅜㅑ www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258248
# 중고등학교때 없던 이쁜애들이 길에 많은 이유(2) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258092
# 필리핀 보홀 다이빙, 오슬롭 고래상어투어. alone http://www.ilbe.com/10008824467
# -----------
# 강릉 가해자 ㅅㅁㅈ 카톡 프로필 히스토리.jpg instiz.net/pt?no=4734736&page=1&srt=3&k=&srd=1
# 모공 79명의 생산직 노동자가 떼 죽음을 당했다.jpg clien.net/service/board/park/11164561?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 나혼자산다 PD 인생 최고의 선택 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767832664
# 아파트 슈퍼하시는 분한테 썅노무ㅅㄲ, ㄱ ㅅ ㄲ 들어서 멘붕이네요 todayhumor.co.kr/board/view.php?table=bestofbest&no=361019&s_no=361019&page=1
# [청원해요] 아이 성은 어머니를 따라야합니다 http://pann.nate.com/talk/338661327
# 길 음주운전해서.. 징역 8월에 실형 구형 된다네요~ slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259835
# 여자랑 첫데이트 코스로 등산+고깃집 어떤가요? http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008361574&m=view
#  [유머] 분노조절을 잘하는 직업 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807913
# 여배우의 은퇴 http://bbs.ruliweb.com/best/board/300143/read/34655058
# 메갈교사가 또.... [71] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706827
# 베스트 갑시다] 대전 여중생 성폭행 동영상 협박 결국.. bobaedream.co.kr/view?code=best&No=133028&vdate=
# 군중심리 ~  http://www.ygosu.com/community/real_article/yeobgi/1244165/?page=0&frombest=Y
# 결정해! 회식이중요해 내가 중요해?! http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138302324
# 혼자 포토샵 실무 공부하는 덬들에게 추천하는 강좌 블로그 강좌들 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561972957
# 10월 2일 임시공휴일!.jpg이슈포토 http://dkbnews.donga.com/Board?no=15969&m=view&tcode=bbs_dkbnews
# 쯔위를 찌르는 모모 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28332
# 보트위에서 휴식중인 오인혜 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73814&page=1
# 드뎌 국내에 들어온 celine farach flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82407
# 옷 정리하는 유아 newsbbs.dreamx.com/view.do?list_id=697852&page=1&bid=cnt_star
# 산에 가다 만난 그녀 newsbbs.dreamx.com/view.do?list_id=697849&page=1&bid=cnt_humor
# 레이싱 모델 송이나 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850006&bm=1
# 홀스의 골드를 본 소풍반응 ㅋㅋ www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258234
# 보배드림 레전드 매물떴네요(7) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258023
# 페미교사 정의구현해주시는 어머니잼^^ http://www.ilbe.com/10008954858
# -----------
# 교통사고 카톡대화 레전설.jpg instiz.net/pt?no=4734650&page=1&srt=3&k=&srd=1
# 모공 위례별초 페미니즘 교사 규탄 회견에서 갓침.txt clien.net/service/board/park/11164587?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 현시점 세계 최고 명장 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767707840
# 서경덕 내 이럴줄 알았다... todayhumor.co.kr/board/view.php?table=bestofbest&no=361018&s_no=361018&page=1
# 여자들 군대 가면 이건 꼭 지켜라 http://pann.nate.com/talk/338665161
# 사기당했는데..이렇게 문자왔네요.. 도움좀 주세욥 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259834
# 죄송한데 저 남친 있어요.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008361463&m=view
#  [유머] 씨름소녀를 만난 강호동 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807838
# 붓싼 경찰이 보호해 주는 학생 클라스. http://bbs.ruliweb.com/best/board/300143/read/34654975
# 티비플 근황(망하고 소라넷) [87] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706773
# 이명박근혜표 생계형 방산비리 bobaedream.co.kr/view?code=best&No=133043&vdate=
# 다금바리에 대해서 알아보자.jpg  http://www.ygosu.com/community/real_article/food/27924/?page=0&frombest=Y
# 금수저 인증한다.jpg http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138302276
# 무한도전 스태프들도 미쳐있던 시기 jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561939632
# [펌] 상대방을 미치게 하는 방법.jpg이슈포토 http://dkbnews.donga.com/Board?no=15968&m=view&tcode=bbs_dkbnews
# 몸푸는 CLC 장승연 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28329
# 살인자의 기억법 VIP 시사회 스타들패션 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73813&page=1
# 외모 몸매 쩌는데 비해 생각보다 안뜨는 처자 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82406
# 결별한 연예계 커플 newsbbs.dreamx.com/view.do?list_id=697850&page=1&bid=cnt_star
# 홍대에서 연예인인 척을 해보았다 newsbbs.dreamx.com/view.do?list_id=697847&page=1&bid=cnt_humor
# 레이싱 모델 윤미진 님 패션 ^^ bobaedream.co.kr/view?code=girl&No=850005&bm=1
# 보조배터리를 모르는 서새봄 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258230
# 테사기테사기 거리는 스타1 리마스터 유저들 ...(25) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258107
# 피자 안쏜 졸렬한 15랩 새끼 글 올렸다 http://www.ilbe.com/10008909862
# -----------
# 이시각 강릉폭행 가해자 카톡프로필.jpg instiz.net/pt?no=4734716&page=1&srt=3&k=&srd=1
# 모공 마광수 - 자살자를 위하여 clien.net/service/board/park/11161345?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 한국의 월드컵 진출 일등공신 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767687353
# 김정숙 여사, 러 순방 첫날 '헤이그 특사' 이상설 선생 추모 todayhumor.co.kr/board/view.php?table=bestofbest&no=361017&s_no=361017&page=1
# ++)강릉 피해자 폭행영상(제발 봐주세요) http://pann.nate.com/talk/338658980
# 대표팀 염기훈 선수가 한말... slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259833
# 미해군이랑 붙어서 이길 나라는 중,러 뿐이죠? http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008366440&m=view
#  [유머] 씬스틸러 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807837
# 국민들이 만만하냐 개돼지로 보여?! . jpg http://bbs.ruliweb.com/best/board/300143/read/34655358
# 12만원으로 1500만원 만드는법.jpg [20] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706737
# 부산여중생 가해자 근황 bobaedream.co.kr/view?code=best&No=133024&vdate=
# 근데 신태용도 참 좆같겠다 http://www.ygosu.com/community/real_article/soccer/223344/?page=0&frombest=Y
# 이쯤에서 다시보는 일진판사 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138288924
# 해외 육아 팁 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561874438
# 한편의 시같은 연세대학교 5행시.jpg이슈포토 http://dkbnews.donga.com/Board?no=15967&m=view&tcode=bbs_dkbnews
# 탈아이돌 여배우클라스 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28328
# 막바지 여름휴가 즐기고있는 이다해 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73812&page=1
# 청바지 몸매가 이뻐보이는 아카네 아키바 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82405
# 꼬리를 드러낸 시바견 사나 newsbbs.dreamx.com/view.do?list_id=697848&page=1&bid=cnt_star
# 토사구팽 newsbbs.dreamx.com/view.do?list_id=697845&page=1&bid=cnt_humor
# 임나영 움짤 모음 bobaedream.co.kr/view?code=girl&No=850003&bm=1
# [배그] 연막왕 콩진호 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258183
# 비트코인 근황(3) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=257883
# 부산가서 부산남자보고 느낀점 http://www.ilbe.com/10008937579
# -----------
# 컵라면 봉지 뜯을때 조심해라 instiz.net/pt?no=4733537&page=1&srt=3&k=&srd=1
# 모공 부산경찰 홈피의 헬잘알.jpg clien.net/service/board/park/11161176?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 우즈벡 골대.gif http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767419309
# 김어준공장장의 팩트폭격 todayhumor.co.kr/board/view.php?table=bestofbest&no=361016&s_no=361016&page=1
# (감사)형제회비 모아놓고 나 없을 때 여행간 식구들 http://pann.nate.com/talk/338662360
# 100만원짜리 청소기 금형 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259831
# 황재균 "한국 복귀팀? 협상 태도를 우선시" http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008363653&m=view
#  [유머] 오마이갓 보틀! http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807760
# 나 금수저인증한다 ㅋㅋ 유게인들아 날보고 열폭해라! http://bbs.ruliweb.com/best/board/300143/read/34654919
# "성관계하면 풀어줄게"…부산 여중생 집단폭행 새 증언 [62] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706803
# 정치를 그만둔 유시민 표정이 밝아진 이유 bobaedream.co.kr/view?code=best&No=133030&vdate=
# 화장실몰카 근황  http://www.ygosu.com/community/real_article/yeobgi/1244160/?page=0&frombest=Y
# 화장실 몰ca 근황 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138299525
# 다이어트=샐러드? NO theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561839077
# 비와이의 자신감.jpg이슈포토 http://dkbnews.donga.com/Board?no=15966&m=view&tcode=bbs_dkbnews
# 딱 보기 좋은 은하 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28326
# 역시 다리 기럭지는 한채영 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73811&page=1
# 남친 좋아보이는 허윤미 포즈 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82404
# 레드벨벳 웬디가 newsbbs.dreamx.com/view.do?list_id=697846&page=1&bid=cnt_star
# 방학 장례식.jpg newsbbs.dreamx.com/view.do?list_id=697842&page=1&bid=cnt_humor
# 허벅지가 돋보이는 아이돌 bobaedream.co.kr/view?code=girl&No=849998&bm=1
# 초승달 배그 켠왕 엔딩 www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258236
# 최근 임요환의 드랍쉽.gif(4) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258238
# 고독사 미니어쳐.jpg http://www.ilbe.com/10008889917
# -----------
# 내 연예인이 이러면 눈물날 상황 instiz.net/pt?no=4733477&page=1&srt=3&k=&srd=1
# 모공 학교폭력은 알면서도 방관한 선생도 처벌해야합니다. clien.net/service/board/park/11161109?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# 미국인은 전부 총을 가지고 있나요? http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=766769400
# 동작에 반응하는  CCTV todayhumor.co.kr/board/view.php?table=bestofbest&no=361015&s_no=361015&page=1
# [2탄] 회사 유부녀와 바람난 예비신랑 파혼당함 (자작... http://pann.nate.com/talk/338657947
# G70 프라이빗 후기 .jpg slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259830
# 디스코 팡팡의 매력.gif http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008360692&m=view
#  [유머] 주인님, 편지가 왔어요!! http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807738
# 공포의고속도로 http://bbs.ruliweb.com/best/board/300143/read/34653645
# 믿고 걸러야 할 인간.jpg [51] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706839
# 쓸 땐 쓰는 김생민씨 bobaedream.co.kr/view?code=best&No=133026&vdate=
# 슈퍼비가 타블로를 싫어하게 된 이유  http://www.ygosu.com/community/real_article/yeobgi/1244159/?page=0&frombest=Y
# 목사니ㅁ ㅣ의 편지 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138296802
# 자식한테 팩폭당해서 입다문 부모충ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ.jpg theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561828448
# 부산 가해자 중딩들의 의리.jpg이슈포토 http://dkbnews.donga.com/Board?no=15965&m=view&tcode=bbs_dkbnews
# 수영장의 손나  댓글 : 2 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28319
# 전설의 우희 벅지 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73810&page=1
# 플레이보이 1호 모델’ 이연화의 남다른 볼륨 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82403
# 사회생활하는 임나연 newsbbs.dreamx.com/view.do?list_id=697843&page=1&bid=cnt_star
# 이웃집이랑 결혼했어.jpg newsbbs.dreamx.com/view.do?list_id=697840&page=1&bid=cnt_humor
# 시구하는 유지  gif bobaedream.co.kr/view?code=girl&No=849992&bm=1
# 배그 12시간 켠왕 도중에 아들한테 갱당한 풍... www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=258302
# 2017년 휴게소 음식 TOP 10(2) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258084
# 한국 축구 개ㅆㅅㅌㅊ노ㅋㅋㅋㅋ http://www.ilbe.com/10008859930
# -----------
# 아이돌과 배우의 차이 instiz.net/pt?no=4734818&page=1&srt=3&k=&srd=1
# 모공 ‘장외투쟁’ 한국당, “나가서 죽겠다” 제발 그렇게 해줘! clien.net/service/board/park/11164320?po=0&od=T33&sk=&sv=&category=&groupCd=board_all&articlePeriod=default
# ???: 앞으로 내이름에 그새끼 붙이지마라 http://www.fmkorea.com/index.php?mid=best&listStyle=list&document_srl=767556745
# 부산 사상경찰서에 항의 전화 해봤는데, , ,  todayhumor.co.kr/board/view.php?table=bestofbest&no=361014&s_no=361014&page=1
# +추가)나 부산여중생 얘기하다가 남친이랑 헤어졌다;; http://pann.nate.com/talk/338659481
# 베트남 전 실제사진 有 slrclub.com/bbs/vx2.php?id=best_article&category=1&no=259829
# X 치는 소리에 빡친 이웃주민.jpg http://mlbpark.donga.com/mp/b.php?b=bullpen&id=201709050008362114&m=view
#  [유머] 지옥보다 못한 한국 http://www.inven.co.kr/board/powerbbs.php?come_idx=2097&my=chu&category=유머&iskin=webzine&l=807736
# 사건축소에 급급한 부산경찰 http://bbs.ruliweb.com/best/board/300143/read/34653466
# 이광수 방송인생 최대의 위험발언.jpg [30] web.humoruniv.com/board/humor/read.html?table=pds&st=day&pg=0&number=706722
# 자위 딸딸이당이  주장하는 bobaedream.co.kr/view?code=best&No=133021&vdate=
# 설현 누가 한물 갔다고 했냐  http://www.ygosu.com/community/real_article/yeobgi/1244148/?page=0&frombest=Y
# 무릎꿇은 학부모 http://www.dogdrip.net/index.php?mid=dogdrip&page=1&sort_index=voted_count&order_type=desc&document_srl=138297676
# 현재 천조국 커뮤니티에서 난리난 한국 기자 theqoo.net/index.php?mid=tbest&filter_mode=normal&document_srl=561797633
# 유병재가 최근 가장 기뻤을 때.jpg이슈포토 http://dkbnews.donga.com/Board?no=15964&m=view&tcode=bbs_dkbnews
# 옷입는 태연  댓글 : 6 http://nsbu.co.kr/bbs/board.php?bo_table=celeb&wr_id=28318
# 하의실종 이주연 flash24.dreamx.com/g4/bbs/board.php?bo_table=star&wr_id=73809&page=1
# 국내에선 볼 수 없는… 섹시 절정 치어리딩 flash24.dreamx.com/g4/bbs/board.php?bo_table=photo&wr_id=82402
# 젖은 현아 newsbbs.dreamx.com/view.do?list_id=697841&page=1&bid=cnt_star
# 이연복 셰프 이름에 얽힌 슬픈 과거 newsbbs.dreamx.com/view.do?list_id=697838&page=1&bid=cnt_humor
# 정채연 bobaedream.co.kr/view?code=girl&No=849991&bm=1
# 요즘 아프리카 음주 방송 수위 ㄷㄷㄷ.gif(6) www.fomos.kr/talk/article_view?bbs_id=6&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D6&indexno=256255
# 지금은 없어진 306 보충대 사진(7) www.fomos.kr/talk/article_view?bbs_id=4&lurl=%2Ftalk%2Farticle_list%3Fbbs_id%3D4&indexno=258088
# 한국인  1만명  강제 추방 ㅋㅋ http://www.ilbe.com/10008916444
# -----------
# parsing ends
# sleep in 40s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4730275401f1> in <module>()
#     569     print('parsing ends')
#     570     print('sleep in 40s')
# --> 571     time.sleep(60)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

req2 = requests.get('http://flash24.dreamx.com/g4/bbs/board.php?bo_table=photo').text.encode(encoding_map['iso-8859-1'])
soup_flash2 = BeautifulSoup(req2, 'html.parser')

    #ruri
for title in soup_flash2.select('.subject a'): 
                    a = title.get('href')
                    print(title.text)
                    print(a)
# Out:
# 게시판 이용안내 및 게시물 삭제 안내
# ../bbs/board.php?bo_table=photo&wr_id=47065
# 코스트코녀 뒤태 앞태
# ../bbs/board.php?bo_table=photo&wr_id=82391
# 홍대에서 흔히 보는 처자 스키니핏
# ../bbs/board.php?bo_table=photo&wr_id=82390
# 모델 김우현 일상
# ../bbs/board.php?bo_table=photo&wr_id=82389
# 오피스텔에서 혼자 사는 아이
# ../bbs/board.php?bo_table=photo&wr_id=82388
# 문세림 대항마 봄수연 몸매
# ../bbs/board.php?bo_table=photo&wr_id=82387
# 바람직한 가정부 리나
# ../bbs/board.php?bo_table=photo&wr_id=82386
# 아낌없이 벗어던진 로드걸 한소율
# ../bbs/board.php?bo_table=photo&wr_id=82385
# 올여름 핫했던 비키니 모델 박다현
# ../bbs/board.php?bo_table=photo&wr_id=82384
# 튜닝이 필요없는 허윤미 볼륨
# ../bbs/board.php?bo_table=photo&wr_id=82383
# 김주희 세끈한 힙업
# ../bbs/board.php?bo_table=photo&wr_id=82382
# 요가 선생님 요염한 자세
# ../bbs/board.php?bo_table=photo&wr_id=82381
# 아재쇼 하나경 몸매 대단했지
# ../bbs/board.php?bo_table=photo&wr_id=82380
# 찰진 줄무늬 원피스 ㅊㅈ
# ../bbs/board.php?bo_table=photo&wr_id=82379
# 제복 끝판왕 후기녀
# ../bbs/board.php?bo_table=photo&wr_id=82378
# 비키니녀 .. 오빠 바나나 따줘
# ../bbs/board.php?bo_table=photo&wr_id=82377
# 이정도면 얼마나 당겨입은거야?
# ../bbs/board.php?bo_table=photo&wr_id=82376
# 하면서 정든다는 커플요가
# ../bbs/board.php?bo_table=photo&wr_id=82375
# 필라테스녀 몸부심
# ../bbs/board.php?bo_table=photo&wr_id=82374
# 극한직업 회장 여비서
# ../bbs/board.php?bo_table=photo&wr_id=82373
# 미스김 커피 한잔 부탁해! 하악~
# ../bbs/board.php?bo_table=photo&wr_id=82372
# 이게바로 길거리 공연의 매력
# ../bbs/board.php?bo_table=photo&wr_id=82371
# 실제 보면 완전설레일것같은 레이싱걸 처자
# ../bbs/board.php?bo_table=photo&wr_id=82370
# 2017 SPOEX 처자
# ../bbs/board.php?bo_table=photo&wr_id=82369
# 탈모가 걱정인 모델
# ../bbs/board.php?bo_table=photo&wr_id=82368
# 코스프레좋아한다는 처자
# ../bbs/board.php?bo_table=photo&wr_id=82367
